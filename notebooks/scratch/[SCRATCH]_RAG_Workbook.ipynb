# %%
import os
import fitz

# %%
# Path to the dataset folder
DATASET_PATH = r"data/downloaded_pdfs/Dataset"

def extract_text_from_pdfs(folder_path):
    texts = []
    metadata = []
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".pdf"):
                pdf_path = os.path.join(root, file)
                folder_name = os.path.basename(root)
                print(f"Extracting text from {pdf_path}...")
                
                doc = fitz.open(pdf_path)
                for page_num, page in enumerate(doc, start=1):
                    text = page.get_text()
                    # if text.strip():
                    texts.append(text.strip())
                    metadata.append({
                        "source": pdf_path,
                        "folder": folder_name,
                        "title": file,
                        "page": page_num
                    })
    return texts, metadata

# %%
documents, metadatas = extract_text_from_pdfs(DATASET_PATH)
# Out:
# Extracting text from data/downloaded_pdfs/Dataset/Services/MAIRDOES/3-CC2024-MAIRDOE-ENROLLMENT.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/MAIRDOES/1-CC2024-MAIRDOE-NEW.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/MAIRDOES/2-CC2024-MAIRDOE-RENEWAL.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/MAIRDOES/4-CC2024-MAIRDOE-STOCK-REPORT.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/12-CC2024-DL-CERTIFICATION.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/15-CC2024-MSC-TRX.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/14-CC2024-DL-CODES.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/1-CC2024-SP.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-Vol.-1-2nd-Edition.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/13-CC2024-DL-FEE.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/10-CC2024-DL-CC-P-NP.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/5-CC2024-MSC.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/4-CC2024-DL-OFW.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/11-CC2024-DL-ENHANCE.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-vol.-2-2nd-Edition.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/8-CC2024-DL-ADD-CODE.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/7-CC2024-DL-CC-NP-P.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/6-CC2024-DL-DP.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/9-CC2024-DL-CONVERSION.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/3-CC2024-CL.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/2-CC2024-DL-NP.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Driver’s License/.ipynb_checkpoints/FDM-Vol.-1-2nd-Edition-checkpoint.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/5-CC2024-MVI.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/1-CC2024-INITIAL-REG.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/8-CC2024-MV-RESTAMP.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/11-CC2024-MV-CONDUCTION-VERIFICATION.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/2-CC2024-MV-ENCODE.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/7-CC2024-MV-VERIFICATION.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/4-CC2024-MV-MSC-TRX.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/6-CC2024-MV-STORAGE.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/3.1-CC2024-MVUC.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/9-CC2024-MV-CONFIRMATION.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/4.1-CC2024-MV-FEE.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/3-CC2024-MV-RENEW.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Motor Vehicle Registration/10-CC2024-MV-CONDUCTION-STICKER.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/3-CC2024-ALARM.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/4-CC2024-LIFT-ALARM.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/6-CC2024-APP-CERT.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/1-CC2024-SETTLEMENT.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/9-CC2024-IMPOUND.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/5-CC2024-ALARM-TAS.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/10-CC2024-RELEASING.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/2-CC2024-FINES.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Law Enforcement/7-CC2024-DRC.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO102_CDE_Road_and_Traffic_Rules_Signs-Signals-Markings.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO105-CDE-General-Information-10.22.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO101-CDE-Road-Safety-10.22.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO103b-CDE-Spll-Laws-MC-and-TC-10.22.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO102_CDE_Road_and_Traffic_Rules_Expressway.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO104-CDE-Other-Regulatons-10.21.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO102_CDE_Road_and_Traffic_Rules_Rules-on-the-road.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/(CDE PROGRAM) Comprehensive Driver’s Education Program/RO103a-CDE-Spl-Laws-10.22.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Services/Affiliates/CitiSend Incident Reporting App/CitiSend Incident Reporting App.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms/DS_IT_App-Form.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms/PMVIC_Form.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms/MAIDRS_Application_Accreditation.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms/PETC_Application_Authorization_IT_Service_Provider.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms/MAIDRs_Application_Accreditation_Renewal.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms/PETC_Application_Renewal.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/About Us/RESOURCES/Downloadable Forms
pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_12132021_LicenseFee_10yr.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_05042024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_06082012.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_08132012.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_03242023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_03222023-MV-Rollout.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_12092022_Plate_Series.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo-04082020newmv.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_02172023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_08052022.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_05142024-Apprehension.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo-10302024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_11142013.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_03222023-Stock-Report.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_10262023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo-re-DIY-CSR-and-Sales-Report-1_3.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_04212023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_01042022.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_21022024-IT-Service-Provider.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_07012021-Lic_Reg-Ext_Validity.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_10032023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_Aug242021.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_11242023-Plates.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_11112022.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_01162024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_09012022.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_10252021_Suspension.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_04252023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/MEMO_11092012.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_09222023.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/praos_18feb2015.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_01062023-MCPA.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/memo_10082021_extension-validity.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_28022024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo-R4A-11142024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo-06142024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo-R3-11142024.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/Memo_06092023-Process-MV.pdf...
# Extracting text from data/downloaded_pdfs/Dataset/Issuances/Memo/memo_conduction_sticker.pdf...

# %%
docs = documents

# %%
len(docs)
# Out:
# 3506

# %%
from llama_index.core import Document
from llama_index.core.node_parser import TokenTextSplitter

documents = [Document(text=docs[t], metadata=metadatas[t]) for t in range(len(docs))]
splitter = TokenTextSplitter(
    chunk_size=512,
    chunk_overlap=20,
    separator=" ",
)
nodes = splitter.get_nodes_from_documents(documents)

# %%
oc = fitz.open('data/downloaded_pdfs/Dataset/Issuances/Republic Act/RA-4136.pdf')
oc[0].get_text()
# Out:
# ''

# %%
for node in nodes:
    if node.metadata['source']== 'data/downloaded_pdfs/Dataset/Issuances/Republic Act/RA-4136.pdf':
        print(node)
# Out:
# Node ID: 9d79f4dd-c36c-49a2-9ddc-814d96403017
# Text:
# Node ID: 6c314cf7-be2d-4d5c-8d02-74ebd6d7571a
# Text:
# Node ID: 0e12206a-52d1-4aa6-8f88-39e19332dd4b
# Text:
# Node ID: e609eb95-9656-40c9-bf21-88f55951f3f7
# Text:
# Node ID: 9c907fca-0bdc-470d-9b94-6855faa5489f
# Text:
# Node ID: 4ca7c75c-7832-4bb2-8fe2-ac6c59c24033
# Text:
# Node ID: cbc9d961-f5d3-470d-af35-071baf8f6bc4
# Text:
# Node ID: 2c6bdac7-813a-4864-b0b3-b7d2aa2a7e2a
# Text:
# Node ID: 6afac422-190a-42a4-b44f-25a09ff3b919
# Text:
# Node ID: 2b393d80-a5fa-4434-9af6-f7a62337c920
# Text:
# Node ID: 8b7b5d07-1d13-4411-b36d-6a44157ec811
# Text:
# Node ID: 68edb3d2-7533-4235-9e50-a2486e4e9f7f
# Text:
# Node ID: e85a6ec2-6b68-46d7-98f4-fe79d1f37149
# Text:
# Node ID: da3ccf1c-fcb3-4fab-8317-0b7120877068
# Text:
# Node ID: 9241b2e2-b846-45bb-a53a-50482e01f6e8
# Text:
# Node ID: 11112f42-2d33-4672-b68b-9c2c355a7ba1
# Text:
# Node ID: af170151-4f33-412c-8868-ba414d607859
# Text:
# Node ID: 385b1dcf-6837-4b53-87c3-179f28ad0f19
# Text:

# %%
def generate_embeddings(nodes, client, model):
    # Generate embeddings for documents using Ollama
    for doc in nodes:
        response = client.embeddings(prompt=doc.text, model=model)
        doc.embedding = response["embedding"]
    return nodes

# %%
from ollama import Client
#  -0.3076818287372589,
#  0.5699064135551453,
#  0.4598441421985626,
#  -0.8323535323143005,
#  0.18736036121845245,
#  0.078702911734581,
#  -0.47661957144737244,
#  0.7173497676849365,
#  -0.3707261383533478,
#  0.41161391139030457,
#  -0.3024907112121582,
#  0.3169729709625244,
#  0.26255467534065247,
#  -0.649101734161377,
#  -0.13915367424488068,
#  0.41716793179512024,
#  0.367281436920166,
#  0.05493384227156639,
#  0.6414390206336975,
#  -0.09136637300252914,
#  -0.34012171626091003,
#  -0.13102826476097107,
#  0.5746752619743347,
#  0.5639314651489258,
#  0.9078749418258667,
#  0.028616949915885925,
#  -0.45304393768310547,
#  0.4123586118221283,
#  ...]

# %%
import numpy as np
import faiss
from llama_index.core.retrievers import BaseRetriever
from llama_index.core.schema import TextNode, NodeWithScore

class FAISSVectorStoreRetriever(BaseRetriever):
    def __init__(self, faiss_index, documents, embeddings):
        """
        Initialize the FAISS retriever.
        :param faiss_index: The FAISS index containing precomputed embeddings.
        :param documents: List of document chunks.
        :param embeddings: Precomputed embeddings corresponding to the document chunks.
        """
        self.faiss_index = faiss_index
        self.documents = documents
        self.embeddings = embeddings
    
    def _retrieve(self, query_embedding, top_k=5):
        """
        Retrieve the top-k nearest neighbors using the FAISS index.
        :param query_embedding: The embedding of the query.
        :param top_k: Number of top results to retrieve.
        """
        distances, indices = self.faiss_index.search(query_embedding, top_k)
        retrieved_docs = [
            NodeWithScore(node=self.documents[idx], score=1 - dist)
            for idx, dist in zip(indices[0], distances[0])
            if idx != -1
        ]
        return retrieved_docs

# %%
embeddings = np.array([np.array(node.embedding) for node in nodes])
normalized_embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

# %%
normalized_embeddings
# Out:
# array([[ 0.02990641, -0.02049577,  0.02144916, ...,  0.00137737,
#         -0.02079806,  0.01479261],
#        [ 0.02842975,  0.00793104, -0.00212581, ..., -0.04173804,
#         -0.02449265,  0.02197738],
#        [-0.00497755,  0.03766523, -0.01356215, ..., -0.02030472,
#         -0.02340788, -0.00385419],
#        ...,
#        [ 0.00414736,  0.01393432,  0.01429416, ...,  0.01305378,
#          0.00785751, -0.01734604],
#        [-0.02822733,  0.03010949,  0.05656858, ...,  0.04565517,
#         -0.00194257,  0.00101682],
#        [ 0.00743732, -0.02455021,  0.03684381, ...,  0.02517157,
#          0.01407912, -0.01194485]])

# %%
embedding_dim = normalized_embeddings[0].shape[0]
faiss_index = faiss.IndexFlatIP(embedding_dim)  # Inner-product similarity
faiss_index.add(normalized_embeddings)

# %%
retriever = FAISSVectorStoreRetriever(faiss_index, nodes, embeddings)

# %%
query = "What do you call a public utility vehicle that is operating with suspended or cancelled CPC?"

# %%
response = client.embeddings(prompt=query, model="mxbai-embed-large")
query_embedding = np.array([response["embedding"]])
query_embedding /= np.linalg.norm(query_embedding, axis=1, keepdims=True)

# %%
query_embedding
# Out:
# array([[-0.01295556, -0.01045785,  0.00355195, ...,  0.02388491,
#          0.05192703, -0.02185194]])

# %%
top_k_docs = retriever._retrieve(query_embedding, top_k=15)

# %%
# Output retrieved documents
for doc in top_k_docs:
    print(f"Retrieved Document: {doc.node.text}, Score: {doc.score}\n")
# Out:
# Retrieved Document: I'
# cancelled
# CPC
# and
# the
# · Decision/Order. of
# suspension
# .or
# cancellation
# ·is
# executory; and
# e.. A
# PUV
# with
# expired CPC and
# without a pending
# application
# for
# extension
# , of '
# validity . timely '
# filed before ·:the
# Board.
# , I
# ! .
# i i
# ! :
# !
# Revocation of ALL CPCs (ehtire fleet) of the
# operator;
# ·. Disqualification ofibe -Operator, and, in case of a
# :corporation, alL · its stockholders and directors, to
# operate any kind of public land transportation;
# Blackl!sting of ALL authorized units (entire fleet) of
# the operator from being used as public utility vehicle;
# and
# Revocation of the registration of ALL authorized
# units (e~tire fle~t) of the operator.
# I
# .
# .
# ,
# .
# . ,
# In 'determining the >frequency of offenses, the L TFRB and its
# R~~Bs will'courit offenses against operators and not cigainst a
# P<3f1icLilar
# motor vehiCle
# or
# CPC.
# Hence, the
# second
# apprehen_sioh CDf a vehicle. belonging to the same operator,
# regafdless ~ of Whether the ' first
# and
# second
# vehicle
# a _PP fe~ended are included in the same or different CPCs, shall
# bel.oo.unted as second (2"d) offense.
# ·
# 'If ~~1
# 1
# pri:ate motor . vehicle . ~perating as a POV but. without
# pr~J:ler at,Jthority from the LTFRB is cipprehended, the L TFRB
# or !lFRBs Shall, in . addition to the · abovementioned fines,
# irnw
# _. ' counding,. and
# _- ·penalty, disqualify. the -registered owner, and,
# in f~Se Of a corporation_, all its stockholders and, Score: 0.220725417137146
#
# Retrieved Document: when
# apprehended
# vehicle is with
# private/green
# plate);
#
# 2. Blacklisting
# of
# the apprehended
# vehicle and all
# other authorized
# units included in
# the
# CPC
# from
# being used as a
# public
# utility
# vehicle; and
#
# 3. Revocation
# of
# the registration of
# the apprehended
# vehicle and all
# other authorized
# units included in
# the franchise., Score: 0.26225554943084717
#
# Retrieved Document: and LGUs;
# z) Public Utility VehiC!e (PUV) Fleet refers to a group or a number of units of road
# vehicles owned, leased and/or operated by a priv.ate single juridical entity,
# corpmate or otherwise, such as an operator, established to provide
# sarne/simHar/contiguous/interconnected transport and/or logistics services t at
# have been awarded/granted the valid Certificate of Public Convenience pe1·rnit,
# or authorization; and
# aa)Self~Generating Charging Stations refer to charg.ing stations which source
# electridty from the grid and also from on-site installed generation facilities with
# reference to Section 7 of the EVIDA-!RR.
# EV I DA -I R F~, Score: 0.28370946645736694
#
# Retrieved Document: fleet) of the
# operator from being used as PUV
# -  Revocation of the registration of ALL authorized units
# (entire fleet) of the operator
#                   1,000,000.00
#                          6,000.00
#  NONE
# 4-1
#                      200,000.00
#                        50,000.00
#                      200,000.00
#                      120,000.00
# - Impoundment for three (3) months
# Status of CPC
# - Revocation of the ENTIRE CPC where the apprehended
# vehicle belongs (except when apprehended vehicle is with
# private/green plate)
# - Blacklisting of the apprehended vehicle and all other
# authorized units included in the CPC from being used as a
# PUV
# - Revocation of the registration of the apprehended vehicle
# and all other authorized units included in the franchise
#  NONE
# LETAS FINES AND PENALTIES
# 216, Score: 0.28574442863464355
#
# Retrieved Document: 84
#
#
# TYPE OF VIOLATION
# PENALTIES FOR
# 2ND OFFENSE
#
#
# d. A
# PUV
# with
# suspended
# or
# cancelled CPC and
# Decision/Order
# of
# the suspension or
# cancellation
# is
# executory; and
#
#
# e. A PUV with expired
# CPC and without a
# pending application
# for
# extension
# of
# validity timely filed
# before the Board.
#
#
# 1. Revocation of ALL CPCs (entire fleet) of
# the operator;
#
# 2. Disqualification of the operator, and, in
# case of a corporation, all its stockholders
# and directors, to operate any kind of public
# land transportation;
#
# 3. Blacklisting of ALL authorized units (entire
# fleet) of the operator from being used as
# public utility vehicle; and
#
# 4. Revocation of the registration of ALL
# authorized units (entire fleet) of the
# operator.
#
# In determining the frequency of offenses, the
# LTFRB and its RFRBs will count offenses
# against operators and not against a particular
# motor vehicle or CPC. Hence, the second
# apprehension of a vehicle belonging to the
# same operator, regardless of whether the first
# and second vehicle apprehended are included
# in the same or different CPCs, shall be
# counted as second (2nd) offense.
#
# If a private motor vehicle operating as a PUV
# but without proper authority from the LTFRB is
# apprehended, the LTFRB or RFRBs shall, in
# addition
# to
# the
# abovementioned
# fines,
# impounding,
# and
# penalty,
# disqualify
# the
# registered
# owner,
# and,
# in
# case
# of
# a
# corporation, all its stockholders and directors,
# to
# operate
# any
# kind
# of
# public
# land
# transportation., Score: 0.30144941806793213
#
# Retrieved Document: 15,000.00 Cancellation of CPC where the unit is authorized
# Violation of color scheme or design/ Adoption or new
# color design without authority from the Board (PUB and
# TX only)
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30) days
# 3rd Offense and subsequent Offense
#        15,000.00 Cancellation of CPC where the unit is authorized
# Unregistered or unauthorized trade/business name (PUB
# and TX only)
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30) days
# 3rd Offense and subsequent Offense
#        15,000.00 Cancellation of CPC where the unit is authorized
# 4-12
# 4-15
# 4-16
# 4-11
# 4-8
# 4-4
#  NONE
#  NONE
#     1,000.00
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#  NONE
#     1,000.00
#     1,000.00
#     1,000.00
#  NONE
# LETAS FINES AND PENALTIES
# 217, Score: 0.3081514239311218
#
# Retrieved Document: create a presumption
# that the ·subject motor vehicle is beyond the mandatory fifteen (15) year age
# limitofbusesand trucks, and shall be a ground for the suspension, cancella:tio.n,
# orrevocatio11.ofthe CPC and.or the Certificate.ofRegistration (CR) of the motor·
# vehicle .unless pro-ve11 otherwise.
# C. Imported used PUBS or TFH carrying various kinds of cargo., as defined under
# Executive 0Fder (EO) 156 series .of 2002, may be allowed registration by the
# LTO, but shall not be allowed registration as public utility vehicles and thus, shall
# not he granted a CPC.
# ·
# D. Land Transportation Office and the Land Transp.or.tatioJl Franchising and
# Regulatory Boardshe:tll issue tbe appFC~priate }Cint Memorandum C.ircular within
# 30 ,days from the effectivity. of this Or.deF, to.:implement the man$te of this
# policy within their respective jurisdiction, taking irito consideration a
# reasonable .~ti~
# period for the smooth and proper implementation of this
# Departmerrt Order~ t v, Score: 0.3098006248474121
#
# Retrieved Document: TYPE OF VIOLATION
# 1.
# Colorum Violation - A
# motor
# vehide
# is
# considered operatin_g
# as "co/arum" under
# any of the foflowing
# circumstances:
# a. A private motor
# vehicle operating
# as a PU\/ but
# without
# proper
# authority from the
# LTFRB;
# b. A PUV operating
# outside
# cif
# its·
# approved route or
# area
# without a
# prior permit from
# the
# Board
# or
# outside
# the
# exceptions
# provided
# under
# existing
# memorandum
# circulars;
# c. A PUV operating
# differently from its
# authorized
# denomination
# (ex.
# those
# approved
# as
# school
# service
# but operating as
# UV express, or
# those
# approved
# as
# tourist
# bus
# transport
# but
# operating as city
# or provincial bus);
# and
# d. A
# PUV
# with
# suspended
# or
# Ii
# ii
# .
# ' '
# IV ·
# :[.,
# VIOLATIONS 'IN CONNECTION'
# WITH FRANCHISE
# .11
# TYPE OF
# VEHICLE
# BUS
# TRUCKS
# J.EEPNEY
# VANS
# SEDAN
# MC
# I '
# •l
# I!
# I
# P~NALTIES FOR FIR~T (1 ST) OFFENSE
# Ff NE
# P1 Million
# I
# I ' i '
# l
# i
# P200,000
# PS0,000
# I
# P200,000
# P120,000 ·
# Minimu
# m •
# lmpoun
# ding
# Period
# (unit)
# 3
# i ii
# I '
# 11
# status of CPC
# I. Ii
# I ' !;
# 1.1 i Revocation of the
# EN_TIRE
# months .. Certificate · of Public Conveni·ence
# ("CPC") where the apprehended
# vehicle
# belongs
# (except
# when
# apprehended
# vehicle
# is
# with
# . pt
# ate/green plate);
# ·
# · 2.: i Blacklisting of the apprehended
# v1~icle and all, Score: 0.3143782615661621
#
# Retrieved Document: disposal, and handling of wastes;
# n) Fleet refers to a group of road vehicles owned, !eased and/or operated by a
# single juridical entity, whether government or private, corporate or otherwise, in
# the pursuit of its mandate, business or organizational objectives;
# o) Green routes refer to public tra nsportation routes identified and designated in
# the Local Public Transpo1i F~oute Plans (LPTf~P) and F(oute f~ationaliza ti on
# Plans (RRPs) approved by the DOT1-, and the Land Trans portation Franchising
# and Regulatory Board (L TFRB), and shall likewise include service areas in the
# tricycle route plans identified and approved by the lGUs. to be exclusively
# traversed by all electric public utility vehicles (PUVs);
# p) 1--lybrid-EVs (1-IEVs) refers lo a vehicle with both a rechargeable energy storage
# system and cl fueled power source for propulsion with reference to Section S of
# the EVIDA-IF~R;
# r--
# eiF---:---;-;"VV c EN 1 ~- ~
# .
# C' f1U
# "' tn;
# •' l<ltQ "l ~I
# •IJ ¥•~ 1 51~A I >t rlfL ..fi 'L~;
# •• 0"' '"•'1' c 1"~ k ule> •'O f<. ou'•"O" >
# \
# TDJ
# OCT 2 4 2022
# r~ !
# ~V IE.TI~IE _1v:
# EVIDA-lRR
# Page .3 cf 21 ,,
# /
# - ~- -·-, Score: 0.31677520275115967
#
# Retrieved Document: been tested and found to be compliant with the standards and specification
# of the DOT r and DTI, and that it has been set to the appropriate speed limit.
# c.
# Closed Van refers to a large motor vehicle, usually with an enclosed cargo
# space, designed to carry goods for commercial purposes, or engaged in
# services of transporting personal effects;
# d.
# Covered Vehicle refers to any closed van, hauler or cargo truck, PUV,
# shuttle service, or tanker truck as defined under this section and such other
# vehicles as may hereinafter be determined and included by the Department
# of
# Transportation
# and
# Communications,
# now
# the
# Department
# of
# Transportation (DOTr), for the purpose of applying the provisions of this Act;
# excluding taxicabs, and public utility jeepneys (PUJs), without prejudice to
# the review by the DOTr after one (1) year on the necessity of their inclusion
# in the coverage of this Act;
# e.
# Hauler or Cargo Truck refers to a motor vehicle designed for transporting
# heavy or oversized loads or cargoes;
# f.
# LEO refers to law enforcement officers or deputized agents of the L TO and
# L TFRB to enforce the provisions of this Act;
# g.
# Motor Vehicle refers to any vehicle propelled by any power other than
# muscular power using the public. highways or roads, but excepting road
# rollers, trolley cars, street sweepers, sprinklers, lawn mowers, bulldozers,
# graders, fork-lifts, amphibian trucks, and cranes· if not used on public
# highways and vehicles run only on rails or tracks, and tractors, trailers and
# traction engines of all kinds used exclusively for agricultural purposes as
# defined under R.A. No. 4136 Article II Section 3.a.;
# h.
# Public Roads refer to roads designated by the national government or local
# government units as roads for public use such-as, but not limited to, national
# highways, provincial roads, city, municipal and barangay streets;
# '
# i.
# Public Utility Vehicle (PUV} refers to a motor vehicle considered as a public
# transport conveyance or common carrier duly registered with the Land
# Transportation Office, Score: 0.32074642181396484
#
# Retrieved Document: DRIVER  MV OWNER/
# OPERATOR
#  DRIVER
#  MV
# OWNER
#  DRIVER
#  OPERATOR
# FINES
#  PRIVATE
#  FOR HIRE
# DOTC JAO NO.
# 2014-01
# VIOLATIONS
# ACCESSORY PENALTY /
# OTHER REQUIREMENTS /
# REMARKS
# No panel route (PUJ, PUB, UV)
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30) days
# 3rd Offense and subsequent Offense
#        15,000.00 Cancellation of CPC where the unit is authorized
# Failure
# to
# display
# the
# International
# Symbol
# of
# Accessibility inside the units and/or failure to designate
# seats specifically for the use of Persons with Disability or
# Failure or refusal to transport PWDs (PUJ, PUB, TTS, UV)
# 1st Offense
#        50,000.00
# 2nd Offense
#        75,000.00 Impoundment of unit for at least forty-five (45) days. An
# impounding fee of 500.00 per day.
# 3rd Offense and subsequent Offense
#      100,000.00 Cancellation of CPC where the unit is authorized
# Impounding Fee
#        100.00
# Storage Fee
#  15.00/day
# 4-17
#  NONE
#  NONE
#  NONE
#  NONE
# 4-24
#     1,000.00
#     1,000.00
# A Temporary Operator’s Permit (TOP) shall authorize a driver to operate a motor vehicle for a period of seventy-two (72) hours only. Further, all apprehensions are deemed admitted unless contested by
# filing a written contest within five (5) days from date of apprehension. However, failure of the driver to pay the corresponding penalty within fifteen (15) days shall cause the automatic suspension of his
# driver’s license for a period of thirty (30) days from the date of apprehension in addition to the fines and penalties, Score: 0.3217029571533203
#
# Retrieved Document: 52
#
# Republic Act No. 10916
#
# PUBLIC UTILITY VEHICLE (PUV) refers to a motor vehicle
# considered as a public transport conveyance or common carrier
# duly registered with the Land Transportation Office (LTO) and
# granted a franchise by the Land Transportation Franchising and
# Regulatory Board (LTFRB).
#
# SHUTTLE SERVICE refers to any motor vehicle provided by
# government or private company or establishment whether owned
# or leased from another entity to transport its employees to and
# from the work premises or clients between designated origin and
# destination and carrying not less than four (4) passengers.
#
# TANKER TRUCK refers to a motor vehicle designated for
# transporting or carrying gas, oil or liquid, flammable, combustible,
# corrosive or hazardous materials or substances in bulk such as
# molasses or water.
#
# MANDATORY INSTALLATION OF SPEED LIMITER
#
# No covered vehicle shall be allowed to run in any road, street or
# highway in the Philippines without a standard speed limiter in
# accordance with the standards and specifications approved by the
# DOTr.
#
#
# NO SPEED LIMITER, NO REGISTRATION
#
# No covered vehicle shall be registered by the LTO whether for
# initial or renewal of registration, or issued franchise by the LTFRB
# without the standard speed limiter certified by the DTI installed and
# set in the vehicle.
#
#
#
# SETTING OF STANDARDS
#
# The DOTr shall, in accordance with acceptable international
# standards, determine the specifications of the speed limiters that
# may be allowed to be installed in the covered vehicles. The LTO or
# the LTFRB, shall supervise and inspect the setting of speed limiter
# corresponding to the maximum allowed in the route plied by a
# particular covered vehicle., Score: 0.32626450061798096
#
# Retrieved Document: 83
#
# VIOLATIONS IN CONNECTION WITH FRANCHISE
#
# TYPE OF VIOLATION
# TYPE OF
# VEHICLE
# PENALTIES FOR FIRST
# (1ST) OFFENSE
# FINE
# Minimum
# Impounding
# Period
# (until)
# STATUS of CPC
# 1. Colorum Violation - A
# motor
# vehicle
# is
# considered operating
# as "colorum" under
# any of the following
# circumstances:
#
# a. A
# private
# motor
# vehicle operating as
# a PUV but without
# proper authority from
# the LTFRB;
#
#
# b. A
# PUV
# operating
# outside
# of
# its
# approved route or
# area without a prior
# permit
# from
# the
# Board or outside the
# exceptions provided
# under
# existing
# memorandum
# circulars;
#
#
# c. A
# PUV
# operating
# differently from its
# authorized
# denomination
# (ex.
# those approved as
# school service but
# operating
# as
# UV
# express,
# or
# those
# approved as tourist
# bus
# transport
# but
# operating as city or
# provincial bus); and
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# BUS
#
#
# TRUCKS
#
#
# JEEPNEY
#
#
# VANS
#
#
# SEDAN
#
#
# MC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Php
# 1 Million
#
# Php
# 200,000.00
#
# Php
# 50,000.00
#
# Php
# 200,000.00
#
# Php
# 120,000.00
#
# Php
# 6,000.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      3
#     Months
# 1. Revocation
# of
# the
# ENTIRE
# Certificate
# of
# Public
# Convenience
# ("CPC")
# where
# the apprehended
# vehicle
# belongs
# (except
# when
# apprehended
# vehicle is with
# private/green
# plate);, Score: 0.3270012140274048
#
# Retrieved Document: -registered owner, and,
# in f~Se Of a corporation_, all its stockholders and direci:ors, to
# 0 . erate an ·. kind Qf
# ublicland trans . ortation.
# .
# 2. Refusal tq .render _ 1 -. IOffense - fine of PS,000.09
# service - do._
# t t;ie ,.·"' I ,1
# _
# ,
# •
# public or convey< 2n°I ©ffense :....fine of p10,ooo.oo and impounding of unit for for
# passenger ..
# •to 4hijf ·(30) days
# ·
# .
# ·
# ·
# destmatmin
# l
# '
# ·
# 3i'cl f 1and . subsequent Offomses .- . fine .o! . P15poo.oo and
# carncellatron of CPC where the urnt 1s authorized
# 3. Overcharging/Urrde 1 !Offense-fine of PS,000:00 ..
# rcharging of fare *
# I i
# 2n.d q fiense - fine o.f P10,000.00 and impounding of unit for
# thir*"(30) days
# 3rd. bnd J su,bsequent Offenses 7' fine of P15,000.0D and
# caf'Jlce'llation of CPC where the unit is authorized
# 4. Failure .to provide .1 s. ~
# - ffense '....:ftne of.P._5,000.80 ·
# proper,
# bo-?y .
# · I .,.,i,
# .
# ·
# r::iarking~
# 2nd <j:>ffense - fine of Pi0,000.00 and impounding of unit for
# .thirit ·· 30 da s :
# ·
# i
# "
# · 18, Score: 0.32836222648620605
#
# Retrieved Document: 3. p ,":a.JSW ~
# l&:•
# ~~~ bf: 'TM: H~Tf(Jmrl.
# O ri'!f'Nls1 Rf.1 IVE REWS'lm
# CON AR)
# J1Mt41STRATIVE RULES & RNl{~
# ~1~&~JV Et> .
# ~--IJY_Jj;,,.,,.,..,.__..,,,
# D.
# Professional Driver's License (POL) - is an authority embodied in a
# form prescribed by the L TO to a person to operate a private or public utility
# vehicle.
# E.
# Conductor's License - is an authority embodied in a form prescribed by
# the L TO to a person to assist the driver of a public utility vehicle to collect
# fares and/or to ensure the safety of the passengers and/or cargo while the
# said vehicle is in operation.
# F.
# Motor Vehicle (MV) - refers to any vehicle propelled by any power other
# than muscular power using the public highways but excepting road rollers,
# trolley cars, street-sweepers, sprinklers, lawn mowers, bulldozers,
# graders, forklifts, amphibian trucks and cranes if not used on public
# highways, vehicles which run only on rails or tracks, and tractors, trailers
# and traction engines of all kinds used exclusively for agricultural products.
# G.
# Private MV - refers to MV owned by individuals and juridical persons for
# private use.
# H.
# Public Utility/For-Hire (PUV) - refers to a vehicle with a valid Certificate
# of Public Convenience (CPC) issued by the Land Transportation
# Franchising and Regulatory Board (L TFRB) or City/Municipal Tricycle
# Operators Permit (MTOP) issued by the Local Government unit where the
# route of operation is indicated.
# I.
# Restriction Code (RC) - is a specification in the driver's license as to the
# type of MV a licensed driver is allowed to operate.
# J.
# Accredited Physician - refers to any practicing doctor of medicine duly
# licensed to practice medicine in the Philippines, who examines applicants, Score: 0.3312963843345642

# %%
def summarize_each_chunk(nodes, client, model, query, if_docs=False):
    if if_docs:
        chunks = [doc.text for doc in nodes]
    else:
        chunks = [doc.node.text for doc in nodes]
    summaries = []
    
    for i, chunk in enumerate(chunks):
        prompt = f"""
        Based on the query: "{query}", summarize the following text in at most one paragraph. 
        Preserve key points that are relevant to the query and remove redundant or unrelated information.
        And lastly do not answer the query itself, just focus on summarization.
        Do not add new information, focus only on the text provided.
        
        Text:
        {chunk}
        
        Summary (relevant to the query):
        """
        
        response = client.generate(model=model, prompt=prompt)
        
        summary = response['response'].strip()
        summaries.append(summary)
        # print(f"Chunk {i+1} Summary (Relevant to Query):\n{summary}\n")

    return summaries

# %%
summaries = summarize_each_chunk(top_k_docs, client, model='llama3.2:1b', query=query)

# %%
summaries
# Out:
# ['The text refers to an action taken by the LTFRB that results in the suspension or cancellation of public utility vehicle (PUV) CPCs for operators who have expired CPCs, without pending applications for extension. The resulting CPC revocation affects not only the operating vehicles but also their registration, and any subsequent vehicles registered under a suspended CPC are considered "second offenses" and subject to further penalties.',
#  'The summary can be: A public utility vehicle operating with suspended or cancelled CPC is subject to private/green plate; blacklist, revocation of registration for other units.',
#  'The public utility vehicle refers to a group or number of road vehicles operated by private entities, such as operators established for providing transport and logistics services, with or without special permits or authorization.\n\nHere is the summary:\n\nPublic Utility Vehicles are those that operate under suspended or cancelled Public Convenience Permits (PSPs).',
#  'Here is a summary of the text in one paragraph, focusing on key points relevant to the query:\n\nA public utility vehicle (PUV) operating under suspended or cancelled Community Protection Clause (CPC) has its entire fleet and registration revoked. Additionally, three specific vehicles involved with the CPC have their registrations impounded for 3 months each, followed by revocation of their entire franchise if they are not already revoked.',
#  'The text describes penalties for operating suspended or cancelled Public Utility Vehicles (PUV) with suspended or cancelled Customer Protection Certificates (CPC), including fines, revocation of CPCs, disqualification from public transportation, and revocation of vehicle registration.',
#  'The key points related to public utility vehicles operating with suspended or cancelled CPC are:\n\n- A public utility vehicle that operates with suspended CPC must adhere to color scheme and design standards set by the Board.\n- Violations of these standards result in the unit being impounded for 30 days.\n- Repeated offenses can lead to further penalties, including cancellation of CPC.',
#  'The text states that public utility vehicles operating with suspended or cancelled CPCs will be subject to suspension, cancellation, or revocation of their Certificate of Registration (CR) unless they provide adequate evidence. This is due to being beyond the mandatory 15-year age limit for buses and trucks, as well as not meeting specific criteria for imported used PUBS or TFH vehicles.',
#  'A motor vehicle is considered operating as a public utility vehicle (PUV) under various circumstances, including:\n\n- Operating without proper authority from LTFRB\n- Traveling outside approved route or area without permit\n- Engaging in different activities than authorized designation (e.g., school service but operating as UV express)\n- Having suspended or cancelled CPC.',
#  'Here is a one-paragraph summary of the text:\n\nA public utility vehicle operating with suspended or cancelled CPC refers to a group of road vehicles owned and/or operated by a single juridical entity, which may be government, corporate, or private. This group includes green routes and exclusively traversed tricycle routes designated in local transportation plans. A fleet also includes specially designed electric hybrid-electric (1-IEV) vehicles that combine rechargeable energy storage with fuel power.',
#  'Here is a summary of the provided text in one paragraph:\n\nA Public Utility Vehicle (PUV) operating with suspended or cancelled CPC, refers to a closed van designed to carry goods for commercial purposes. It encompasses various types of vehicles including hauler or cargo trucks and motor vehicles used exclusively for agricultural purposes. The terms are defined within this Act to apply specific regulations and provisions.',
#  'The public utility vehicle is operating with suspended or cancelled CPC (Public Contract Code), indicating that it does not meet accessibility requirements. The vehicle has been fined for violating these regulations, including failing to display the International Symbol of Accessibility and transporting passengers without adequate seating or disabilities accommodations.',
#  'The text does not provide any information on public utility vehicles operating with suspended or cancelled CPC. The query appears to be unrelated to the provided text, which discusses various types of motor vehicles and regulatory requirements for their installation and use in the Philippines.',
#  'Based on the provided text, a public utility vehicle that is operating with suspended or cancelled CPC is considered a colorum violation. The penalties for this type of violation include a fine of PHP 1 million, revocation of the ENTIRE Certificate of Public Convenience ("CPC"), and minimum impounding period of up to 6 months.',
#  '- Public utility vehicles operating with suspended or cancelled CPC are subject to various fines and penalties.\n \n- Specific offenses include refusal to render a traffic offense, service charges, impounding of units for passenger infractions, and overcharging/offering extra services where authorized. \n- Failure to provide warning is also considered an offense.',
#  'Based on the provided text, "public utility vehicle" is referred to as a motor vehicle. It is operating with suspended or cancelled Certificate of Public Convenience (CPC).']

# %%
def generate_response_with_notice(summaries, query, client, model="llama3.2"):
    # Combine summaries into context block
    context = "\n".join(summaries)
    
    # Create prompt to answer based on summarized text
    prompt = f"""
    Use the following summarized information to answer the query accurately and concisely. 
    DO NOT USE BACKGROUND KNOWLEDGE OUTSIDE THE CONTEXT PROVIDED.
    If the information is not sufficient to fully address the query, respond ONLY with:
    "The available information is insufficient to provide a complete answer to this query."

    Summarized Context:
    {context}
    
    Query:
    {query}
    
    Response:
    """
    
    # Send the prompt to Ollama
    response = client.generate(
        model=model,
        prompt=prompt
    )
    
    return response['response'].strip()

# %%
generate_response_with_notice(summaries, query, client)
# print(generate_response_with_notice([docs.node.text for docs in top_k_docs], query, client))
# Out:
# 'A public utility vehicle operating with suspended or cancelled Community Protection Clause (CPC) is referred to as "colorum".'

# %% [markdown]
# # Parse Embeddings

# %%
from llama_index.retrievers.bm25 import BM25Retriever
import Stemmer

# %%
bm25_retriever = BM25Retriever.from_defaults(
    nodes=nodes,
    similarity_top_k=5,
    stemmer=Stemmer.Stemmer("english"),
    language="english",
)

# %%
retrieved_nodes = bm25_retriever.retrieve(query)

# %%
# Output retrieved documents
for doc in retrieved_nodes:
    print(f"Retrieved Document: {doc.node.text}, Score: {doc.score}\n")
# Out:
# Retrieved Document: 84
#
#
# TYPE OF VIOLATION
# PENALTIES FOR
# 2ND OFFENSE
#
#
# d. A
# PUV
# with
# suspended
# or
# cancelled CPC and
# Decision/Order
# of
# the suspension or
# cancellation
# is
# executory; and
#
#
# e. A PUV with expired
# CPC and without a
# pending application
# for
# extension
# of
# validity timely filed
# before the Board.
#
#
# 1. Revocation of ALL CPCs (entire fleet) of
# the operator;
#
# 2. Disqualification of the operator, and, in
# case of a corporation, all its stockholders
# and directors, to operate any kind of public
# land transportation;
#
# 3. Blacklisting of ALL authorized units (entire
# fleet) of the operator from being used as
# public utility vehicle; and
#
# 4. Revocation of the registration of ALL
# authorized units (entire fleet) of the
# operator.
#
# In determining the frequency of offenses, the
# LTFRB and its RFRBs will count offenses
# against operators and not against a particular
# motor vehicle or CPC. Hence, the second
# apprehension of a vehicle belonging to the
# same operator, regardless of whether the first
# and second vehicle apprehended are included
# in the same or different CPCs, shall be
# counted as second (2nd) offense.
#
# If a private motor vehicle operating as a PUV
# but without proper authority from the LTFRB is
# apprehended, the LTFRB or RFRBs shall, in
# addition
# to
# the
# abovementioned
# fines,
# impounding,
# and
# penalty,
# disqualify
# the
# registered
# owner,
# and,
# in
# case
# of
# a
# corporation, all its stockholders and directors,
# to
# operate
# any
# kind
# of
# public
# land
# transportation., Score: 9.71440315246582
#
# Retrieved Document: I'
# cancelled
# CPC
# and
# the
# · Decision/Order. of
# suspension
# .or
# cancellation
# ·is
# executory; and
# e.. A
# PUV
# with
# expired CPC and
# without a pending
# application
# for
# extension
# , of '
# validity . timely '
# filed before ·:the
# Board.
# , I
# ! .
# i i
# ! :
# !
# Revocation of ALL CPCs (ehtire fleet) of the
# operator;
# ·. Disqualification ofibe -Operator, and, in case of a
# :corporation, alL · its stockholders and directors, to
# operate any kind of public land transportation;
# Blackl!sting of ALL authorized units (entire fleet) of
# the operator from being used as public utility vehicle;
# and
# Revocation of the registration of ALL authorized
# units (e~tire fle~t) of the operator.
# I
# .
# .
# ,
# .
# . ,
# In 'determining the >frequency of offenses, the L TFRB and its
# R~~Bs will'courit offenses against operators and not cigainst a
# P<3f1icLilar
# motor vehiCle
# or
# CPC.
# Hence, the
# second
# apprehen_sioh CDf a vehicle. belonging to the same operator,
# regafdless ~ of Whether the ' first
# and
# second
# vehicle
# a _PP fe~ended are included in the same or different CPCs, shall
# bel.oo.unted as second (2"d) offense.
# ·
# 'If ~~1
# 1
# pri:ate motor . vehicle . ~perating as a POV but. without
# pr~J:ler at,Jthority from the LTFRB is cipprehended, the L TFRB
# or !lFRBs Shall, in . addition to the · abovementioned fines,
# irnw
# _. ' counding,. and
# _- ·penalty, disqualify. the -registered owner, and,
# in f~Se Of a corporation_, all its stockholders and, Score: 8.324019432067871
#
# Retrieved Document: Implementing Rules and Regulations of  R.A. No. 11313
# R.A. No. 6725 - An Act Strengthening the Prohibition on Discrimination against Women  with respect
# to terms and conditions of employment
# R.A. No. 7877 - An Act Declaring Sexual Harassment Unlawful In The Employment,   Education Or
# Training Environment, And For Other Purposes
# R.A. No. 9262 - An Act Defining Violence Against Women And Their Children, Providing for Protective
# Measures For Victims, Prescribing Penalties Therefore, and for Other Purposes
# GENDER and DEVELOPMENT
# Gender-Based Sexual Harassment in Public Utility Vehicle (PUV)
# The license of a driver and the operators CPC may be suspended or
# revoked by LTO and LTFRB if Gender-Based Sexual Harassment (GBSH)
# is committed during the operation of Public Utility Vehicle., Score: 7.4380621910095215
#
# Retrieved Document: ··,. .
# 5. No
# franchise/Certificate
# of
# Public
# Convenience
# or
# evidence
# of
# franchise presented
# during
# apprehension
# or
# carried inside the
# motor vehicle *
# 6. Fraud and falsities
# such
# as
# presentation of fake
# and spurious CPC,
# OR/CR,
# plates,
# stickers and tags*
# 7. Employing reckless,
# I
# I
# 3rd arid sub~equent OffenseJ -
# fi~e .of P15,000.00 and
# cancellation bf CPC where the Jnit is authorized
# 1 s i Offense -
# ~~e of PS, ODO.OD \
# 2nd Offense --: fine of P10,000.00 and impounding of unit for
# thirty (30) days
# I
# 3rd and ~ub~equent OffenseJ -
# fine of P15,000.00 and
# cancellation of CPC where the uhit is authorized
# I
# I
# Revocation/Cancellation of the !franchise/Certificate 6f Public
# .Convenience, after due notice Of hearing pursuant to L TFRB
# Memorandum :Circular No. 20131003
# I
# I ' i
# insolent,
# discourteous
# arrogant Elrivers
# 1s
# 1 Offense -
# fii~e of.P5,_000.00 I.
# or 2nd Offense _ ;fine of PiQ,000.00 and impounding bf unit for
# thirty (30) days ·
# ·
# 8. Allowing
# an
# unauthorized driver
# to
# drive PUV or
# allowing a driver to
# drive PUV without
# bringing
# his/her
# driver's license
# 9. Operating the
# unit/s with defective
# parts and
# accessories*
# 10. Failure to provide
# fare
# discount
# to
# those entitled under
# existing laws and
# pertinent
# 3rd and subsequent Offenses i-
# fine . of P15,000.00 and
# cancellation of CPC where the ur11it is authorized
# 1s
# 1 Offense- fine, of P5,000.00 I
# 2nd, Score: 6.895213603973389
#
# Retrieved Document: DRIVER  MV OWNER/
# OPERATOR
#  DRIVER
#  MV
# OWNER
#  DRIVER
#  OPERATOR
# FINES
#  PRIVATE
#  FOR HIRE
# DOTC JAO NO.
# 2014-01
# VIOLATIONS
# ACCESSORY PENALTY /
# OTHER REQUIREMENTS /
# REMARKS
# No franchise/CPC or evidence of franchise presented
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30) days
# 3rd Offense and subsequent Offense
#        15,000.00 Cancellation of CPC
# 1j40
# 4-6
# Fraud and falsities of fake and spurious CPC, OR/CR, plates,
# stickers and tags
#  NONE
#  NONE
#     1,000.00
#  Please refer
# to the
# appropriate
# fine
# Revocation/Cancellation of the franchise/CPC
# (Note: Without prejudice to the imposition of the applicable
# fine for the specific violation( s)  committed)
# Operating the unit/s with defective parts and accessories
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30) days
# 3rd Offense and subsequent Offense
#        15,000.00 Cancellation of CPC
# Failure to provide fare discount
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30) days
# 3rd Offense and subsequent Offense
#        15,000.00 Cancellation of CPC
# Fast, tampered, defective taximeter or operating without
# or with an old seal taximeter
# 1st Offense
#          5,000.00
# 2nd Offense
#        10,000.00 Impoundment of unit for thirty (30), Score: 6.5228095054626465

# %%
summaries_2 = summarize_each_chunk(retrieved_nodes, client, model='llama3.2:1b', query=query)

# %%
# generate_response_with_notice(summaries_2, query, client)
generate_response_with_notice([docs.node.text for docs in retrieved_nodes], query, client)
# Out:
# 'A Public Utility Vehicle (PUV) that is operating with a suspended or cancelled Certificate of Public Convenience (CPC) is considered to be "Operating Without Franchise" and also may be subject to penalties as listed under violation 7, including fines ranging from P5,000.00 to P15,000.00, depending on the number of offenses.'

# %% [markdown]
# # Hybrid

# %%
results = {'faiss': top_k_docs, 'bm25':retrieved_nodes}

# %%
from llama_index.core.retrievers import QueryFusionRetriever
x = QueryFusionRetriever
ranked_results = QueryFusionRetriever._reciprocal_rerank_fusion(x, results)

# %%
print(ranked_results[0].text)
# Out:
# 84
#
#
# TYPE OF VIOLATION
# PENALTIES FOR
# 2ND OFFENSE
#
#
# d. A
# PUV
# with
# suspended
# or
# cancelled CPC and
# Decision/Order
# of
# the suspension or
# cancellation
# is
# executory; and
#
#
# e. A PUV with expired
# CPC and without a
# pending application
# for
# extension
# of
# validity timely filed
# before the Board.
#
#
# 1. Revocation of ALL CPCs (entire fleet) of
# the operator;
#
# 2. Disqualification of the operator, and, in
# case of a corporation, all its stockholders
# and directors, to operate any kind of public
# land transportation;
#
# 3. Blacklisting of ALL authorized units (entire
# fleet) of the operator from being used as
# public utility vehicle; and
#
# 4. Revocation of the registration of ALL
# authorized units (entire fleet) of the
# operator.
#
# In determining the frequency of offenses, the
# LTFRB and its RFRBs will count offenses
# against operators and not against a particular
# motor vehicle or CPC. Hence, the second
# apprehension of a vehicle belonging to the
# same operator, regardless of whether the first
# and second vehicle apprehended are included
# in the same or different CPCs, shall be
# counted as second (2nd) offense.
#
# If a private motor vehicle operating as a PUV
# but without proper authority from the LTFRB is
# apprehended, the LTFRB or RFRBs shall, in
# addition
# to
# the
# abovementioned
# fines,
# impounding,
# and
# penalty,
# disqualify
# the
# registered
# owner,
# and,
# in
# case
# of
# a
# corporation, all its stockholders and directors,
# to
# operate
# any
# kind
# of
# public
# land
# transportation.

# %%
# Output retrieved documents
for doc in ranked_results[:5]:
    print(f"Retrieved Document: {doc.node.text}, Score: {doc.score}\n")
# Out:
# Retrieved Document: 84
#
#
# TYPE OF VIOLATION
# PENALTIES FOR
# 2ND OFFENSE
#
#
# d. A
# PUV
# with
# suspended
# or
# cancelled CPC and
# Decision/Order
# of
# the suspension or
# cancellation
# is
# executory; and
#
#
# e. A PUV with expired
# CPC and without a
# pending application
# for
# extension
# of
# validity timely filed
# before the Board.
#
#
# 1. Revocation of ALL CPCs (entire fleet) of
# the operator;
#
# 2. Disqualification of the operator, and, in
# case of a corporation, all its stockholders
# and directors, to operate any kind of public
# land transportation;
#
# 3. Blacklisting of ALL authorized units (entire
# fleet) of the operator from being used as
# public utility vehicle; and
#
# 4. Revocation of the registration of ALL
# authorized units (entire fleet) of the
# operator.
#
# In determining the frequency of offenses, the
# LTFRB and its RFRBs will count offenses
# against operators and not against a particular
# motor vehicle or CPC. Hence, the second
# apprehension of a vehicle belonging to the
# same operator, regardless of whether the first
# and second vehicle apprehended are included
# in the same or different CPCs, shall be
# counted as second (2nd) offense.
#
# If a private motor vehicle operating as a PUV
# but without proper authority from the LTFRB is
# apprehended, the LTFRB or RFRBs shall, in
# addition
# to
# the
# abovementioned
# fines,
# impounding,
# and
# penalty,
# disqualify
# the
# registered
# owner,
# and,
# in
# case
# of
# a
# corporation, all its stockholders and directors,
# to
# operate
# any
# kind
# of
# public
# land
# transportation., Score: 0.030952380952380953
#
# Retrieved Document: I'
# cancelled
# CPC
# and
# the
# · Decision/Order. of
# suspension
# .or
# cancellation
# ·is
# executory; and
# e.. A
# PUV
# with
# expired CPC and
# without a pending
# application
# for
# extension
# , of '
# validity . timely '
# filed before ·:the
# Board.
# , I
# ! .
# i i
# ! :
# !
# Revocation of ALL CPCs (ehtire fleet) of the
# operator;
# ·. Disqualification ofibe -Operator, and, in case of a
# :corporation, alL · its stockholders and directors, to
# operate any kind of public land transportation;
# Blackl!sting of ALL authorized units (entire fleet) of
# the operator from being used as public utility vehicle;
# and
# Revocation of the registration of ALL authorized
# units (e~tire fle~t) of the operator.
# I
# .
# .
# ,
# .
# . ,
# In 'determining the >frequency of offenses, the L TFRB and its
# R~~Bs will'courit offenses against operators and not cigainst a
# P<3f1icLilar
# motor vehiCle
# or
# CPC.
# Hence, the
# second
# apprehen_sioh CDf a vehicle. belonging to the same operator,
# regafdless ~ of Whether the ' first
# and
# second
# vehicle
# a _PP fe~ended are included in the same or different CPCs, shall
# bel.oo.unted as second (2"d) offense.
# ·
# 'If ~~1
# 1
# pri:ate motor . vehicle . ~perating as a POV but. without
# pr~J:ler at,Jthority from the LTFRB is cipprehended, the L TFRB
# or !lFRBs Shall, in . addition to the · abovementioned fines,
# irnw
# _. ' counding,. and
# _- ·penalty, disqualify. the -registered owner, and,
# in f~Se Of a corporation_, all its stockholders and, Score: 0.029906956136464335
#
# Retrieved Document: 3. p ,":a.JSW ~
# l&:•
# ~~~ bf: 'TM: H~Tf(Jmrl.
# O ri'!f'Nls1 Rf.1 IVE REWS'lm
# CON AR)
# J1Mt41STRATIVE RULES & RNl{~
# ~1~&~JV Et> .
# ~--IJY_Jj;,,.,,.,..,.__..,,,
# D.
# Professional Driver's License (POL) - is an authority embodied in a
# form prescribed by the L TO to a person to operate a private or public utility
# vehicle.
# E.
# Conductor's License - is an authority embodied in a form prescribed by
# the L TO to a person to assist the driver of a public utility vehicle to collect
# fares and/or to ensure the safety of the passengers and/or cargo while the
# said vehicle is in operation.
# F.
# Motor Vehicle (MV) - refers to any vehicle propelled by any power other
# than muscular power using the public highways but excepting road rollers,
# trolley cars, street-sweepers, sprinklers, lawn mowers, bulldozers,
# graders, forklifts, amphibian trucks and cranes if not used on public
# highways, vehicles which run only on rails or tracks, and tractors, trailers
# and traction engines of all kinds used exclusively for agricultural products.
# G.
# Private MV - refers to MV owned by individuals and juridical persons for
# private use.
# H.
# Public Utility/For-Hire (PUV) - refers to a vehicle with a valid Certificate
# of Public Convenience (CPC) issued by the Land Transportation
# Franchising and Regulatory Board (L TFRB) or City/Municipal Tricycle
# Operators Permit (MTOP) issued by the Local Government unit where the
# route of operation is indicated.
# I.
# Restriction Code (RC) - is a specification in the driver's license as to the
# type of MV a licensed driver is allowed to operate.
# J.
# Accredited Physician - refers to any practicing doctor of medicine duly
# licensed to practice medicine in the Philippines, who examines applicants, Score: 0.016666666666666666
#
# Retrieved Document: -registered owner, and,
# in f~Se Of a corporation_, all its stockholders and direci:ors, to
# 0 . erate an ·. kind Qf
# ublicland trans . ortation.
# .
# 2. Refusal tq .render _ 1 -. IOffense - fine of PS,000.09
# service - do._
# t t;ie ,.·"' I ,1
# _
# ,
# •
# public or convey< 2n°I ©ffense :....fine of p10,ooo.oo and impounding of unit for for
# passenger ..
# •to 4hijf ·(30) days
# ·
# .
# ·
# ·
# destmatmin
# l
# '
# ·
# 3i'cl f 1and . subsequent Offomses .- . fine .o! . P15poo.oo and
# carncellatron of CPC where the urnt 1s authorized
# 3. Overcharging/Urrde 1 !Offense-fine of PS,000:00 ..
# rcharging of fare *
# I i
# 2n.d q fiense - fine o.f P10,000.00 and impounding of unit for
# thir*"(30) days
# 3rd. bnd J su,bsequent Offenses 7' fine of P15,000.0D and
# caf'Jlce'llation of CPC where the unit is authorized
# 4. Failure .to provide .1 s. ~
# - ffense '....:ftne of.P._5,000.80 ·
# proper,
# bo-?y .
# · I .,.,i,
# .
# ·
# r::iarking~
# 2nd <j:>ffense - fine of Pi0,000.00 and impounding of unit for
# .thirit ·· 30 da s :
# ·
# i
# "
# · 18, Score: 0.01639344262295082
#
# Retrieved Document: 83
#
# VIOLATIONS IN CONNECTION WITH FRANCHISE
#
# TYPE OF VIOLATION
# TYPE OF
# VEHICLE
# PENALTIES FOR FIRST
# (1ST) OFFENSE
# FINE
# Minimum
# Impounding
# Period
# (until)
# STATUS of CPC
# 1. Colorum Violation - A
# motor
# vehicle
# is
# considered operating
# as "colorum" under
# any of the following
# circumstances:
#
# a. A
# private
# motor
# vehicle operating as
# a PUV but without
# proper authority from
# the LTFRB;
#
#
# b. A
# PUV
# operating
# outside
# of
# its
# approved route or
# area without a prior
# permit
# from
# the
# Board or outside the
# exceptions provided
# under
# existing
# memorandum
# circulars;
#
#
# c. A
# PUV
# operating
# differently from its
# authorized
# denomination
# (ex.
# those approved as
# school service but
# operating
# as
# UV
# express,
# or
# those
# approved as tourist
# bus
# transport
# but
# operating as city or
# provincial bus); and
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# BUS
#
#
# TRUCKS
#
#
# JEEPNEY
#
#
# VANS
#
#
# SEDAN
#
#
# MC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Php
# 1 Million
#
# Php
# 200,000.00
#
# Php
# 50,000.00
#
# Php
# 200,000.00
#
# Php
# 120,000.00
#
# Php
# 6,000.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      3
#     Months
# 1. Revocation
# of
# the
# ENTIRE
# Certificate
# of
# Public
# Convenience
# ("CPC")
# where
# the apprehended
# vehicle
# belongs
# (except
# when
# apprehended
# vehicle is with
# private/green
# plate);, Score: 0.016129032258064516

# %%
ranked_results
# Out:
# [NodeWithScore(node=TextNode(id_='242f37c6-372d-4dd8-9d39-dbb4810183f5', embedding=None, metadata={'source': 'data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-vol.-2-2nd-Edition.pdf', 'folder': 'Driver’s License', 'title': 'FDM-vol.-2-2nd-Edition.pdf', 'page': 88}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='afc82b49-c914-4b8d-ba7d-9849d58bb9d6', node_type='4', metadata={'source': 'data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-vol.-2-2nd-Edition.pdf', 'folder': 'Driver’s License', 'title': 'FDM-vol.-2-2nd-Edition.pdf', 'page': 88}, hash='2bf87684384342ab87d5717f621b0505e927d7c4c9aa6a0468dbea6690d40b3d')}, metadata_template='{key}: {value}', metadata_separator='\n', text='84 \n \n \nTYPE OF VIOLATION \nPENALTIES FOR \n2ND OFFENSE \n \n \nd. A \nPUV \nwith \nsuspended \nor \ncancelled CPC and \nDecision/Order \nof \nthe suspension or \ncancellation \nis \nexecutory; and \n \n \ne. A PUV with expired \nCPC and without a \npending application \nfor \nextension \nof \nvalidity timely filed \nbefore the Board. \n \n \n1. Revocation of ALL CPCs (entire fleet) of \nthe operator; \n \n2. Disqualification of the operator, and, in \ncase of a corporation, all its stockholders \nand directors, to operate any kind of public \nland transportation; \n \n3. Blacklisting of ALL authorized units (entire \nfleet) of the operator from being used as \npublic utility vehicle; and \n \n4. Revocation of the registration of ALL \nauthorized units (entire fleet) of the \noperator. \n \nIn determining the frequency of offenses, the \nLTFRB and its RFRBs will count offenses \nagainst operators and not against a particular \nmotor vehicle or CPC. Hence, the second \napprehension of a vehicle belonging to the \nsame operator, regardless of whether the first \nand second vehicle apprehended are included \nin the same or different CPCs, shall be \ncounted as second (2nd) offense. \n \nIf a private motor vehicle operating as a PUV \nbut without proper authority from the LTFRB is \napprehended, the LTFRB or RFRBs shall, in \naddition \nto \nthe \nabovementioned \nfines, \nimpounding, \nand \npenalty, \ndisqualify \nthe \nregistered \nowner, \nand, \nin \ncase \nof \na \ncorporation, all its stockholders and directors, \nto \noperate \nany \nkind \nof \npublic \nland \ntransportation.', mimetype='text/plain', start_char_idx=0, end_char_idx=1524, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.030952380952380953),
#  NodeWithScore(node=TextNode(id_='42393330-a391-4829-a5d2-d0f414da71bc', embedding=None, metadata={'source': 'data/downloaded_pdfs/Dataset/Issuances/Administrative Order/JAO-2014-01.pdf', 'folder': 'Administrative Order', 'title': 'JAO-2014-01.pdf', 'page': 18}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='58373942-8c79-44ef-8d57-2a174cd8dde6', node_type='4', metadata={'source': 'data/downloaded_pdfs/Dataset/Issuances/Administrative Order/JAO-2014-01.pdf', 'folder': 'Administrative Order', 'title': 'JAO-2014-01.pdf', 'page': 18}, hash='3e4c530deba2af5ba00956abebe712e7e5842e745a35e5bd849a4e4f60e5a94b'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='b919d771-fa57-4198-b285-e051cf2b6866', node_type='1', metadata={}, hash='5ea01a67b7cb831fca4bee11db5d01134e653c1b59c75a236bbf655bbdee35df')}, metadata_template='{key}: {value}', metadata_separator='\n', text='I\' \ncancelled \nCPC \nand \nthe \n· Decision/Order. of \nsuspension \n.or \ncancellation \n·is \nexecutory; and \ne.. A \nPUV \nwith \nexpired CPC and \nwithout a pending \napplication \nfor \nextension \n, of \' \nvalidity . timely \' \nfiled before ·:the \nBoard. \n, I \n! . \ni i \n! : \n! \nRevocation of ALL CPCs (ehtire fleet) of the \noperator; \n·. Disqualification ofibe -Operator, and, in case of a \n:corporation, alL · its stockholders and directors, to \noperate any kind of public land transportation; \nBlackl!sting of ALL authorized units (entire fleet) of \nthe operator from being used as public utility vehicle; \nand \nRevocation of the registration of ALL authorized \nunits (e~tire fle~t) of the operator. \nI \n. \n. \n, \n. \n. , \nIn \'determining the >frequency of offenses, the L TFRB and its \nR~~Bs will\'courit offenses against operators and not cigainst a \nP<3f1icLilar \nmotor vehiCle \nor \nCPC. \nHence, the \nsecond \napprehen_sioh CDf a vehicle. belonging to the same operator, \nregafdless ~ of Whether the \' first \nand \nsecond \nvehicle \na _PP fe~ended are included in the same or different CPCs, shall \nbel.oo.unted as second (2"d) offense. \n· \n\'If ~~1\n1\npri:ate motor . vehicle . ~perating as a POV but. without \npr~J:ler at,Jthority from the LTFRB is cipprehended, the L TFRB \nor !lFRBs Shall, in . addition to the · abovementioned fines, \nirnw\n_. \' counding,. and\n_- ·penalty, disqualify. the -registered owner, and, \nin f~Se Of a corporation_, all its stockholders and', mimetype='text/plain', start_char_idx=0, end_char_idx=1456, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.029906956136464335),
#  NodeWithScore(node=TextNode(id_='59bb1d43-056d-4d6b-bc27-d23af1595ff8', embedding=[0.30273398756980896, -0.131648987531662, 0.5046448707580566, 0.18276771903038025, 0.07998254895210266, -0.10669530928134918, 0.054414376616477966, -0.3928024470806122, 0.1095304936170578, 0.6574401259422302, 0.5196061730384827, 0.10583775490522385, 0.5775172710418701, -0.16009248793125153, -0.4784364104270935, 0.4626983106136322, 0.296850323677063, 0.21131274104118347, -0.7548626065254211, -0.05094200372695923, -0.6617733836174011, 0.5807099938392639, -0.45740896463394165, -0.17099440097808838, -0.478863388299942, 0.18856672942638397, 0.494836688041687, 0.0024439767003059387, 0.08618433028459549, 0.9553097486495972, 0.14628629386425018, 0.13535615801811218, 0.4333694875240326, 0.20272952318191528, 0.08700107783079147, 0.655362606048584, 0.812764048576355, -0.20539937913417816, 0.2767205238342285, -0.02572576329112053, 0.5109169483184814, 0.4566354751586914, 0.1777641475200653, -0.19212085008621216, -
164405823, -1.1252926588058472, -0.5385255217552185, 0.6793150305747986, 0.5251370668411255, -0.2995609939098358, 0.18496766686439514, -0.45906710624694824, 0.0300663523375988, -0.9720690846443176, -0.7855622172355652, -0.23581084609031677, -0.3279542922973633, -0.6094790697097778, 0.31876450777053833, 0.6580443382263184, -0.050493255257606506, 0.16068248450756073, 0.4547562599182129, -0.4166150689125061, 0.2474956214427948, -0.10627857595682144, 0.15828143060207367, -0.30087438225746155, 1.2649593353271484, -0.20342662930488586, 0.37224745750427246, -0.472789645195007 ...
#  NodeWithScore(node=TextNode(id_='11224799-2b72-45a8-af1a-b8443f845107', embedding=None, metadata={'source': 'data/downloaded_pdfs/Dataset/Issuances/Administrative Order/JAO-2014-01.pdf', 'folder': 'Administrative Order', 'title': 'JAO-2014-01.pdf', 'page': 19}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e535448b-5247-4abe-a5c1-40fc81fb1ae8', node_type='4', metadata={'source': 'data/downloaded_pdfs/Dataset/Issuances/Administrative Order/JAO-2014-01.pdf', 'folder': 'Administrative Order', 'title': 'JAO-2014-01.pdf', 'page': 19}, hash='ac8e06d09a24f39eca59ccd76dd5953711eb62e873be63b838bbad92368ad0f4'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='307eef33-cc8a-4957-94a0-82ed15a59de2', node_type='1', metadata={}, hash='4ca3c5d346adb1eac1df7f0b7601f0bfc9c8faeb62b1bf70448c161efafdcefb')}, metadata_template='{key}: {value}', metadata_separator='\n', text="··,. . \n5. No \nfranchise/Certificate \nof \nPublic \nConvenience \nor \nevidence \nof \nfranchise presented \nduring \napprehension \nor \ncarried inside the \nmotor vehicle * \n6. Fraud and falsities \nsuch \nas \npresentation of fake \nand spurious CPC, \nOR/CR, \nplates, \nstickers and tags* \n7. Employing reckless, \nI \nI \n3rd arid sub~equent OffenseJ -\nfi~e .of P15,000.00 and \ncancellation bf CPC where the Jnit is authorized \n1 s i Offense -\n~~e of PS, ODO.OD \\ \n2nd Offense --: fine of P10,000.00 and impounding of unit for \nthirty (30) days \nI \n3rd and ~ub~equent OffenseJ -\nfine of P15,000.00 and \ncancellation of CPC where the uhit is authorized \nI \nI \nRevocation/Cancellation of the !franchise/Certificate 6f Public \n.Convenience, after due notice Of hearing pursuant to L TFRB \nMemorandum :Circular No. 20131003 \nI \nI ' i \ninsolent, \ndiscourteous \narrogant Elrivers \n1s\n1 Offense -\nfii~e of.P5,_000.00 I. \nor 2nd Offense _ ;fine of PiQ,000.00 and impounding bf unit for \nthirty (30) days · \n· \n8. Allowing \nan \nunauthorized driver \nto \ndrive PUV or \nallowing a driver to \ndrive PUV without \nbringing \nhis/her \ndriver's license \n9. Operating the \nunit/s with defective \nparts and \naccessories* \n10. Failure to provide \nfare \ndiscount \nto \nthose entitled under \nexisting laws and \npertinent \n3rd and subsequent Offenses i-\nfine . of P15,000.00 and \ncancellation of CPC where the ur11it is authorized \n1s\n1 Offense- fine, of P5,000.00 I \n2nd", mimetype='text/plain', start_char_idx=0, end_char_idx=1431, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0
131591796875, -0.03713502734899521, 0.1458522081375122, 0.5148107409477234, 1.0271650552749634, -0.4958687722682953, 0.43538355827331543, 0.0228160098195076, 0.6009535789489746, -0.6588813662528992, 0.015958433970808983, 0.5624281764030457, -0.6226775050163269, 0.4245555102825165, 0.6104151010513306, -0.009546108543872833, 0.03328416496515274, 0.05976615846157074, 0.3706003725528717, -0.026430565863847733, 0.40808284282684326, 1.1414278745651245, 0.5901088118553162, 0.35894253849983215, 0.005302117206156254, 0.5089852809906006, 0.17604157328605652, 1.0716090202331543, -0.04994700476527214, 0.6359434723854065, 0.6211733222007751, 0.5091897249221802, -0.31506597995758057, 0.4465246796607971, -0.5360687971115112, -0.10530032217502594, 0.5450215935707092, 0.2296430468559265, -0.07871484011411667, 0.5638790726661682, 0.7396554350852966, -0.2571883499622345, -0.20761963725090027, 0.3105708360671997, -0.750137209892273, 0.004808902740478516, 0.8767131567001343, 0.34813204407691956, -0.42655104398727417, 0.2693358063697815, -0.5175014138221741, 0.2553655505180359, -1.1048836708068848, -0.4019768536090851, 0.45754578709602356, 0.5409946441650391, -0.8110607862472534, 0.01823381334543228, 0.42914479970932007, -0.37470680475234985, -0.18835881352424622, 1.2231718301773071, 0.7139193415641785, 0.26877495646476746, 0.06238727271556854, 0.10746599733829498, 0.450726717710495, 1.2077311277389526, 0.14285744726657867, -0.45148763060569763, -0.12217103689908981, -0.1246953010559082, -1.086 ...

# %%
summaries_3 = summarize_each_chunk(ranked_results[:5], client, model='llama3.2:1b', query=query)

# %%
# generate_response_with_notice(summaries_3, query, client)
generate_response_with_notice([docs.node.text for docs in ranked_results[:5]], query, client)
# Out:
# 'A Public Utility Vehicle (PUV) that is operating with a Suspended or Cancelled Certificate of Public Convenience (CPC) is referred to as "Colorum". \n\n Colorum refers to a PUV that operates without the proper authority and license from the Land Transportation Franchising and Regulatory Board (LTFRB), such as an expired, suspended, or cancelled CPC.'

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %%
def gen_query(query, top_k, client, mode='dense', summary=False, model="llama3.2"):
    response = client.embeddings(prompt=query, model="mxbai-embed-large")
    query_embedding = np.array([response["embedding"]])
    query_embedding /= np.linalg.norm(query_embedding, axis=1, keepdims=True)

    top_k_docs = retriever._retrieve(query_embedding, top_k=top_k)

    # summaries = summarize_each_chunk(top_k_docs, client, model='llama3.2:1b', query=query)
    retrieved_nodes = bm25_retriever.retrieve(query)
    # summaries_2 = summarize_each_chunk(retrieved_nodes, client, model='llama3.2:1b', query=query)

    results = {'faiss': top_k_docs, 'bm25':retrieved_nodes}
    x = QueryFusionRetriever
    ranked_results = QueryFusionRetriever._reciprocal_rerank_fusion(x, results)

    # summaries_3 = summarize_each_chunk(ranked_results[:top_k], client, model='llama3.2:1b', query=query)
    # answer = generate_response_with_notice(summaries_3, query, client)
    if mode == 'dense':
        print('using FAISS')
        ans_nodes =top_k_docs
    elif mode == 'sparse':
        print('using BM25')
        ans_nodes = retrieved_nodes
    else:
        print('using Hybrid')
        ans_nodes = ranked_results[:top_k]

    context = set([get_document_by_chunk_metadata(docs).text for docs in ans_nodes])
    if summary:
        print('using summaries')
        context_nodes = remove_duplicate_documents([get_document_by_chunk_metadata(docs) for docs in ans_nodes])
        summaries = summarize_each_chunk(context_nodes, client, model='llama3.2:latest', query=query,if_docs=True)
        context = summaries

    answer = generate_response_with_notice(context, query, client, model=model)

        # Format the references
    references = []
    for i, doc in enumerate(ranked_results[:top_k], start=1):
        metadata = doc.metadata
        source_info = f"Source {i}: {metadata['title']} (Page {metadata['page']}, Folder: {metadata['folder']})"
        references.append(source_info)

    return answer, "\n".join(references)

# %%
import gradio as gr

# %%
# Gradio interface with slider for top_k
iface = gr.Interface(
    fn=lambda query, top_k: gen_query(query=query, top_k=top_k, client=client),  # Pass top_k dynamically
    inputs=[
        gr.Textbox(label="Enter your query"),
        gr.Slider(1, 20, value=5, step=1, label="Top K Results")  # Slider for top_k (1 to 20)
    ],
    outputs=[
        gr.Textbox(label="Answer", lines=6),
        gr.Textbox(label="References", lines=10),
    ],
    title="RAG System with LLaMA 3.2",
    description="Ask questions and get answers with references from PDF documents. Adjust Top-K to control the number of retrieved chunks."
)

iface.launch()
def on_close():
    iface.set_on_close(on_close)
    iface.launch()
    iface.close()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# using FAISS
# using FAISS
# using FAISS

# %%
ranked_results[0].metadata
# Out:
# {'source': 'data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-vol.-2-2nd-Edition.pdf',
#  'folder': 'Driver’s License',
#  'title': 'FDM-vol.-2-2nd-Edition.pdf',
#  'page': 88}

# %%
import pandas as pd

# %%
# Load the Excel file
file_path = 'data/LTO_EXAM.csv'
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())



# Few-shot examples
FEW_SHOTS = """
Example 1:
Question: What should you do in case your vehicle breaks down on an expressway? Check all that apply.
A. Open your trunk and hood
B. Stand on the expressway and flag down passing drivers for help
C. Call for help using a mobile phone or an expressway phone
D. Park as far to the right as possible
E. Put your hazard warning light on
Please answer only in letters
Correct Answer: [A, B, C, D, E]

Example 2:
Question: What will happen when your front tire blows out?
A. The back end will sway towards the side of the blowout
B. The back end will sway away from the blowout
C. The front end will pull towards the side of the blowout
D. The front end will pull to the opposite side of the blowout
Please answer only in letters
Correct Answer: [C]

Example 3:
Question: What should you do when an ambulance comes up behind you flashing red lights and/or sounding its siren?
A. Stop as soon as you can
B. Maintain your speed, let the ambulance driver will find a way around you
C. Speed up so that you don't hold the ambulance
D. Pull over to the right and slow down or even stop if necessary
Please answer only in letters
Correct Answer: [D]
"""

# Generate prompts dynamically
def generate_prompt(row):
    options = []
    for choice in ['A', 'B', 'C', 'D', 'E']:
        # Check for NaN or blank values
        if pd.notna(row[choice]) and row[choice] != '':
            options.append(f"{choice}. {row[choice]}")
    
    # Construct the prompt with few-shot examples
    prompt = f"\nActual Question: {row['Question']}\n" + "\n".join(options)
    prompt += "\nPlease answer only in letters and put them inside a bracket '[]'. If the question contains the statement 'Check all that apply' then addd comma separator if there are multiple answers ONLY IF ALLOWED."
    
    return prompt

# Apply function to each row
df['Prompt'] = df.apply(generate_prompt, axis=1)

# for i, prompt in enumerate(df['Prompt']):
#     if i >= 3:  # Skip the first three examples
#         print(prompt)
#         print('-' * 50)
# Out:
#                                             Question  \
# 0  What should you do in case your vehicle breaks...
# 1   What will happen when your front tire blows out?
# 2  What should you do when an ambulance comes up ...
# 3  While driving the hood of your car lifts up bl...
# 4  In case of an accident, the first duty of the ...
#
#                                                    A  \
# 0                           Open your trunk and hood
# 1  The back end will sway towards the side of the...
# 2                            Stop as soon as you can
# 3  Look through the gap underneath the hood or ou...
# 4  pick-up the injured person and take him to the...
#
#                                                    B  \
# 0  Stand on the expressway and flag down passing ...
# 1       The back end will sway away from the blowout
# 2  Maintain your speed, let the ambulance driver ...
# 3         Brake suddenly so you don't leave the road
# 4        report the accident to the nearest hospital
#
#                                                    C  \
# 0  Call for help using a mobile phone or an expre...
# 1  The front end will pull towards the side of th...
# 2      Speed up so that you don't hold the ambulance
# 3  Pull to the side of the road and refasten the ...
# 4  report the accident to the nearest police station
#
#                                                    D  \
# 0               Park as far to the right as possible
# 1  The front end will pull to the opposite side o...
# 2  Pull over to the right and slow down or even s...
# 3  Turn your headlights on and look out of the si...
# 4                                                NaN
#
#                                   E      Answer
# 0  Put your hazard warning light on  A, C, D, E
# 1                               NaN           C
# 2                               NaN           D
# 3                               NaN         A,C
# 4                               NaN           A

# %%
from tqdm import tqdm

# %%
qr_range = (23,43)

# %%
df["AI"] = np.nan

# %%
ai_answer = []
for i in tqdm(range(*qr_range)):
    ai_answer.append(gen_query(df.loc[i,"Prompt"], top_k=20, client=client, mode='dense', model="llama3.1:8b", summary=False))
# Out:
#   0%|                                                                                                                                                                                          | 0/20 [00:00<?, ?it/s]
# using FAISS
#   5%|████████▉                                                                                                                                                                         | 1/20 [00:00<00:15,  1.21it/s]
# using FAISS
#  10%|█████████████████▊                                                                                                                                                                | 2/20 [00:01<00:14,  1.24it/s]
# using FAISS
#  15%|██████████████████████████▋                                                                                                                                                       | 3/20 [00:02<00:13,  1.27it/s]
# using FAISS
#  20%|███████████████████████████████████▌                                                                                                                                              | 4/20 [00:03<00:12,  1.32it/s]
# using FAISS
#  25%|████████████████████████████████████████████▌                                                                                                                                     | 5/20 [00:03<00:11,  1.32it/s]
# using FAISS
#  30%|█████████████████████████████████████████████████████▍                                                                                                                            | 6/20 [00:04<00:10,  1.30it/s]
# using FAISS
#  35%|██████████████████████████████████████████████████████████████▎                                                                                                                   | 7/20 [00:05<00:09,  1.32it/s]
# using FAISS
#  40%|███████████████████████████████████████████████████████████████████████▏                                                                                                          | 8/20 [00:06<00:09,  1.29it/s]
# using FAISS
#  45%|████████████████████████████████████████████████████████████████████████████████                                                                                                  | 9/20 [00:06<00:08,  1.36it/s]
# using FAISS
#  50%|████████████████████████████████████████████████████████████████████████████████████████▌                                                                                        | 10/20 [00:07<00:07,  1.35it/s]
# using FAISS
#  55%|█████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                               | 11/20 [00:08<00:06,  1.46it/s]
# using FAISS
#  60%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                      | 12/20 [00:08<00:05,  1.37it/s]
# using FAISS
#  65%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                              | 13/20 [00:09<00:05,  1.34it/s]
# using FAISS
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                     | 14/20 [00:10<00:04,  1.34it/s]
# using FAISS
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                            | 15/20 [00:11<00:03,  1.33it/s]
# using FAISS
#  80%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                   | 16/20 [00:12<00:03,  1.31it/s]
# using FAISS
#  85%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                          | 17/20 [00:12<00:02,  1.32it/s]
# using FAISS
#  90%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                 | 18/20 [00:13<00:01,  1.28it/s]
# using FAISS
#  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 19/20 [00:14<00:00,  1.27it/s]
# using FAISS
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:15<00:00,  1.32it/s]

# %%
df.loc[qr_range[0]:qr_range[1]-1, "AI"] = [answ[0] for answ in ai_answer]
df.loc[qr_range[0]:qr_range[1]-1, ["Question","Answer","AI"]]
# Out:
#                                              Question Answer  \
# 23  To aobtain one's driver's license, one must be...      B
# 24         A pre-trip inspection should be completed:      C
# 25  It is not conidered safe driving on an express...      C
# 26  When you do not see the wheels of the vehicles...      A
# 27  Your speed while driving at night should keep on:      A
# 28                  When driving at night, you should      C
# 29  How close should another car be before you dim...      A
# 30  If you are backing up in a straight line, turn...      A
# 31  The blind spot is the area to your right or le...      C
# 32  At an intrsection with traffic signals, if you...      A
# 33  When approaching a flooded area and you have t...      C
# 34  While driving with maximum speed and you have ...      C
# 35                           On a wet road, you must:      B
# 36  When planning to overtake a slower vehicle in ...      B
# 37  You are preparing to exit an expressway, when ...      B
# 38  While driving with a maximum speed and you hav...      A
# 39  When driving on mountain roads during daytime,...      C
# 40  What light shall be used when vehicles are par...      B
# 41  When loading or unloading passengers, we usual...      A
# 42  If you are parking uphill without a curb, turn...      A
#
#                                              AI
# 23                                          [C]
# 24                                          [C]
# 25                                          [C]
# 26                                       [A, B]
# 27                                          [A]
# 28                                          [A]
# 29                                          [A]
# 30                                          [B]
# 31                                          [C]
# 32                                          [A]
# 33                                          [C]
# 34                                          [A]
# 35                                          [B]
# 36                                          [B]
# 37                                         [B].
# 38                                          [A]
# 39                                          [A]
# 40  [B] Parking lights or lower-beam headlights
# 41                                          [A]
# 42                                          [A]

# %%
print(df.loc[16,"Prompt"])
# Out:
# Actual Question: Which of the following is the maximum speed limit on expressway for cars?
# A. 60 kph
# B. 80 kph
# C. 100 kph
# Please answer only in letters and put them inside a bracket '[]'. If the question contains the statement 'Check all that apply' then addd comma separator if there are multiple answers ONLY IF ALLOWED.

# %%
# Get top 10 chunks
top_nodes = top_k_docs[:5]

# Collect unique documents
seen_documents = set()
unique_nodes = []

# for node in top_nodes:
#     doc_id = node.metadata['source']  # or 'title' if more appropriate
    
#     if doc_id not in seen_documents:
#         seen_documents.add(doc_id)
#         unique_nodes.append(node)

# %%
top_nodes[0].metadata
# Out:
# {'source': 'data/downloaded_pdfs/Dataset/Issuances/Administrative Order/JAO-2014-01.pdf',
#  'folder': 'Administrative Order',
#  'title': 'JAO-2014-01.pdf',
#  'page': 18}

# %%
print(top_nodes[0].text)
# Out:
# I'
# cancelled
# CPC
# and
# the
# · Decision/Order. of
# suspension
# .or
# cancellation
# ·is
# executory; and
# e.. A
# PUV
# with
# expired CPC and
# without a pending
# application
# for
# extension
# , of '
# validity . timely '
# filed before ·:the
# Board.
# , I
# ! .
# i i
# ! :
# !
# Revocation of ALL CPCs (ehtire fleet) of the
# operator;
# ·. Disqualification ofibe -Operator, and, in case of a
# :corporation, alL · its stockholders and directors, to
# operate any kind of public land transportation;
# Blackl!sting of ALL authorized units (entire fleet) of
# the operator from being used as public utility vehicle;
# and
# Revocation of the registration of ALL authorized
# units (e~tire fle~t) of the operator.
# I
# .
# .
# ,
# .
# . ,
# In 'determining the >frequency of offenses, the L TFRB and its
# R~~Bs will'courit offenses against operators and not cigainst a
# P<3f1icLilar
# motor vehiCle
# or
# CPC.
# Hence, the
# second
# apprehen_sioh CDf a vehicle. belonging to the same operator,
# regafdless ~ of Whether the ' first
# and
# second
# vehicle
# a _PP fe~ended are included in the same or different CPCs, shall
# bel.oo.unted as second (2"d) offense.
# ·
# 'If ~~1
# 1
# pri:ate motor . vehicle . ~perating as a POV but. without
# pr~J:ler at,Jthority from the LTFRB is cipprehended, the L TFRB
# or !lFRBs Shall, in . addition to the · abovementioned fines,
# irnw
# _. ' counding,. and
# _- ·penalty, disqualify. the -registered owner, and,
# in f~Se Of a corporation_, all its stockholders and

# %%
docstore = {}

# Store documents using full metadata as the key
for doc in documents:
    key = tuple(doc.metadata.items())  # Convert metadata to tuple for hashable key
    docstore[key] = doc

# %%
len(docstore)
# Out:
# 2096

# %%
def get_document_by_chunk_metadata(chunk_node):
    # Convert chunk metadata to tuple for matching
    metadata_key = tuple(chunk_node.metadata.items())

    # Retrieve document from docstore
    document = docstore.get(metadata_key)
    return document

# %%
doc_top = get_document_by_chunk_metadata(top_nodes[1])

# %%
doc_top
# Out:
# Document(id_='86a17bbe-f5fd-4d81-a09d-c1724bc212cd', embedding=None, metadata={'source': 'data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-vol.-2-2nd-Edition.pdf', 'folder': 'Driver’s License', 'title': 'FDM-vol.-2-2nd-Edition.pdf', 'page': 87}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text=' \n83 \n \nVIOLATIONS IN CONNECTION WITH FRANCHISE \n \nTYPE OF VIOLATION \nTYPE OF \nVEHICLE \nPENALTIES FOR FIRST \n(1ST) OFFENSE \nFINE \nMinimum \nImpounding \nPeriod \n(until) \nSTATUS of CPC \n1. Colorum Violation - A \nmotor \nvehicle \nis \nconsidered operating \nas "colorum" under \nany of the following \ncircumstances: \n \na. A \nprivate \nmotor \nvehicle operating as \na PUV but without \nproper authority from \nthe LTFRB; \n \n \nb. A \nPUV \noperating \noutside \nof \nits \napproved route or \narea without a prior \npermit \nfrom \nthe \nBoard or outside the \nexceptions provided \nunder \nexisting \nmemorandum \ncirculars; \n \n \nc. A \nPUV \noperating \ndifferently from its \nauthorized \ndenomination \n(ex. \nthose approved as \nschool service but \noperating \nas \nUV \nexpress, \nor \nthose \napproved as tourist \nbus \ntransport \nbut \noperating as city or \nprovincial bus); and \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nBUS \n \n \nTRUCKS \n \n \nJEEPNEY \n \n \nVANS \n \n \nSEDAN \n \n \nMC \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nPhp \n1 Million \n \nPhp \n200,000.00 \n \nPhp \n50,000.00 \n \nPhp \n200,000.00 \n \nPhp \n120,000.00 \n \nPhp \n6,000.00 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n      \n \n \n \n     3       \n    Months \n1. Revocation \nof \nthe \nENTIRE \nCertificate \nof \nPublic \nConvenience \n("CPC") \nwhere \nthe apprehended \nvehicle \nbelongs \n(except \nwhen \napprehended \nvehicle is with \nprivate/green \nplate); \n \n2. Blacklisting \nof \nthe apprehended \nvehicle and all \nother authorized \nunits included in \nthe \nCPC \nfrom \nbeing used as a \npublic \nutility \nvehicle; and \n \n3. Revocation \nof \nthe registration of \nthe apprehended \nvehicle and all \nother authorized \nunits included in \nthe franchise. \n', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')

# %%
def remove_duplicate_documents(doc_list):
    seen_ids = set()
    unique_docs = []

    for doc in doc_list:
        if doc.doc_id not in seen_ids:
            seen_ids.add(doc.doc_id)
            unique_docs.append(doc)

    return unique_docs

# %%
doc_top = get_document_by_chunk_metadata(top_nodes[1])

# %%
doc_top.doc_id
# Out:
# '86a17bbe-f5fd-4d81-a09d-c1724bc212cd'

# %%
remove_duplicate_documents([get_document_by_chunk_metadata(top_nodes[1]) for i in range(2)])
# Out:
# [Document(id_='86a17bbe-f5fd-4d81-a09d-c1724bc212cd', embedding=None, metadata={'source': 'data/downloaded_pdfs/Dataset/Services/Driver’s License/FDM-vol.-2-2nd-Edition.pdf', 'folder': 'Driver’s License', 'title': 'FDM-vol.-2-2nd-Edition.pdf', 'page': 87}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text=' \n83 \n \nVIOLATIONS IN CONNECTION WITH FRANCHISE \n \nTYPE OF VIOLATION \nTYPE OF \nVEHICLE \nPENALTIES FOR FIRST \n(1ST) OFFENSE \nFINE \nMinimum \nImpounding \nPeriod \n(until) \nSTATUS of CPC \n1. Colorum Violation - A \nmotor \nvehicle \nis \nconsidered operating \nas "colorum" under \nany of the following \ncircumstances: \n \na. A \nprivate \nmotor \nvehicle operating as \na PUV but without \nproper authority from \nthe LTFRB; \n \n \nb. A \nPUV \noperating \noutside \nof \nits \napproved route or \narea without a prior \npermit \nfrom \nthe \nBoard or outside the \nexceptions provided \nunder \nexisting \nmemorandum \ncirculars; \n \n \nc. A \nPUV \noperating \ndifferently from its \nauthorized \ndenomination \n(ex. \nthose approved as \nschool service but \noperating \nas \nUV \nexpress, \nor \nthose \napproved as tourist \nbus \ntransport \nbut \noperating as city or \nprovincial bus); and \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nBUS \n \n \nTRUCKS \n \n \nJEEPNEY \n \n \nVANS \n \n \nSEDAN \n \n \nMC \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nPhp \n1 Million \n \nPhp \n200,000.00 \n \nPhp \n50,000.00 \n \nPhp \n200,000.00 \n \nPhp \n120,000.00 \n \nPhp \n6,000.00 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n      \n \n \n \n     3       \n    Months \n1. Revocation \nof \nthe \nENTIRE \nCertificate \nof \nPublic \nConvenience \n("CPC") \nwhere \nthe apprehended \nvehicle \nbelongs \n(except \nwhen \napprehended \nvehicle is with \nprivate/green \nplate); \n \n2. Blacklisting \nof \nthe apprehended \nvehicle and all \nother authorized \nunits included in \nthe \nCPC \nfrom \nbeing used as a \npublic \nutility \nvehicle; and \n \n3. Revocation \nof \nthe registration of \nthe apprehended \nvehicle and all \nother authorized \nunits included in \nthe franchise. \n', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]
