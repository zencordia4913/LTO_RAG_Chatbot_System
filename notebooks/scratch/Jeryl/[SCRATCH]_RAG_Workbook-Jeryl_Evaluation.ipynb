# %% [markdown]
# # LTO RAG Table of Contents
#
# 1. Import Libraries
# 2. Connect to Ollama Server
# 3. Ingestion
# 4. QA Generation
# 5. Embedding and Retrieval<br>
#  **5.A** Dense via FAISS
#  **5.B** FAISS Retrieval Evaluator
#  **5.C** FAISS Retrieval Evaluation
#  **5.D** Sparse Embedding via BM25
#  **5.E** Hybrid Embedding via Reciprocal Rank Fusion
#  **5.F** Hybrid Retrieval Evaluator
#  **5.G** Hybrid Retrieval Evaluation
# 6. Post Retrieval<br>
#  **6.A** Summarization
#  **6.B** Evaluation Generation
# 7. Querying<br>
#  **7.A** Query Transforms
# 8. Query Generation
# 9. TDC Exam Evaluation
# 10. Similarity Evaluation
# 11. Relevancy Evaluation

# %% [markdown]
# # 1. Import Libraries

# %%
import os
import fitz
import re

from ollama import Client
import faiss
import pandas as pd
import numpy as np
import Stemmer
from tqdm import tqdm
import gradio as gr

from llama_index.core import Document
from llama_index.core.node_parser import TokenTextSplitter
from llama_index.core.retrievers import BaseRetriever, QueryFusionRetriever
from llama_index.core.schema import TextNode, NodeWithScore
from llama_index.retrievers.bm25 import BM25Retriever
from llama_index.llms.ollama import Ollama

# %% [markdown]
# # 2. Connect to Ollama Server

# %%
client = Client(
  host='http://localhost:11434',
)

# %% [markdown]
# # 3. Ingestion

# %%
# Path to the dataset folder
DATASET_PATH = '/mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2'

def extract_text_from_pdfs(folder_path):
    texts = []
    metadata = []
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".pdf"):
                pdf_path = os.path.join(root, file)
                folder_name = os.path.basename(root)
                print(f"Extracting text from {pdf_path}...")
                
                doc = fitz.open(pdf_path)
                for page_num, page in enumerate(doc, start=1):
                    text = page.get_text()
                    if text.strip():
                        texts.append(text.strip())
                        metadata.append({
                            "source": pdf_path,
                            "folder": folder_name,
                            "title": file,
                            "page": page_num
                        })
                    else:
                        print(f"WARNING: {file} page {page_num} not processed...")
    return texts, metadata

# %%
docs, metadatas = extract_text_from_pdfs(DATASET_PATH)
# Out:
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/1-CC2024-INITIAL-REG.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/1-CC2024-MAIRDOE-NEW.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/1-CC2024-SETTLEMENT.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/1-CC2024-SP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/10-CC2024-DL-CC-P-NP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/10-CC2024-MV-CONDUCTION-STICKER.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/10-CC2024-RELEASING.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/11-CC2024-DL-ENHANCE.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/11-CC2024-MV-CONDUCTION-VERIFICATION.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/12-CC2024-DL-CERTIFICATION.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/13-CC2024-DL-FEE.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/14-CC2024-DL-CODES.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/15-CC2024-MSC-TRX.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/2-CC2024-DL-NP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/2-CC2024-FINES.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/2-CC2024-MAIRDOE-RENEWAL.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/2-CC2024-MV-ENCODE.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/3-CC2024-ALARM.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/3-CC2024-CL.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/3-CC2024-MAIRDOE-ENROLLMENT.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/3-CC2024-MV-RENEW.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/3.1-CC2024-MVUC.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/4-CC2024-DL-OFW.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/4-CC2024-LIFT-ALARM.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/4-CC2024-MAIRDOE-STOCK-REPORT.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/4-CC2024-MV-MSC-TRX.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/4.1-CC2024-MV-FEE.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/5-CC2024-ALARM-TAS.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/5-CC2024-MSC.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/5-CC2024-MVI.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/6-CC2024-APP-CERT.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/6-CC2024-DL-DP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/6-CC2024-MV-STORAGE.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/7-CC2024-DL-CC-NP-P.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/7-CC2024-DRC.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/7-CC2024-MV-VERIFICATION.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/8-CC2024-DL-ADD-CODE.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/8-CC2024-MV-RESTAMP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/9-CC2024-DL-CONVERSION.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/9-CC2024-IMPOUND.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/9-CC2024-MV-CONFIRMATION.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Annex-G-New-Application-Form-DS.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Annex-H-Renewal-Application-Form-DS.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/ANNEX-I-Inspection-Report.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Annex-K-Application-Form-New-DSI.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Annex-L-Application-Form-Renewal-DSI.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO-2024-001.pdf...
# WARNING: AO-2024-001.pdf page 1 not processed...
# WARNING: AO-2024-001.pdf page 2 not processed...
# WARNING: AO-2024-001.pdf page 3 not processed...
# WARNING: AO-2024-001.pdf page 4 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO-VDM-2024-043.pdf...
# WARNING: AO-VDM-2024-043.pdf page 1 not processed...
# WARNING: AO-VDM-2024-043.pdf page 2 not processed...
# WARNING: AO-VDM-2024-043.pdf page 3 not processed...
# WARNING: AO-VDM-2024-043.pdf page 4 not processed...
# WARNING: AO-VDM-2024-043.pdf page 5 not processed...
# WARNING: AO-VDM-2024-043.pdf page 6 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO-VDM-2024-045.pdf...
# WARNING: AO-VDM-2024-045.pdf page 1 not processed...
# WARNING: AO-VDM-2024-045.pdf page 2 not processed...
# WARNING: AO-VDM-2024-045.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO-VDM-2024-046.pdf...
# WARNING: AO-VDM-2024-046.pdf page 1 not processed...
# WARNING: AO-VDM-2024-046.pdf page 2 not processed...
# WARNING: AO-VDM-2024-046.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_1_1972.pdf...
# WARNING: AO_1_1972.pdf page 1 not processed...
# WARNING: AO_1_1972.pdf page 2 not processed...
# WARNING: AO_1_1972.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2-1980.pdf...
# WARNING: AO_2-1980.pdf page 1 not processed...
# WARNING: AO_2-1980.pdf page 2 not processed...
# WARNING: AO_2-1980.pdf page 3 not processed...
# WARNING: AO_2-1980.pdf page 4 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2000-81.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2016-034.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2017-001.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2017-035.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2019-036.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2021-039.pdf...
# WARNING: AO_2021-039.pdf page 1 not processed...
# WARNING: AO_2021-039.pdf page 2 not processed...
# WARNING: AO_2021-039.pdf page 3 not processed...
# WARNING: AO_2021-039.pdf page 4 not processed...
# WARNING: AO_2021-039.pdf page 5 not processed...
# WARNING: AO_2021-039.pdf page 6 not processed...
# WARNING: AO_2021-039.pdf page 7 not processed...
# WARNING: AO_2021-039.pdf page 8 not processed...
# WARNING: AO_2021-039.pdf page 9 not processed...
# WARNING: AO_2021-039.pdf page 10 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2022-040.pdf...
# WARNING: AO_2022-040.pdf page 1 not processed...
# WARNING: AO_2022-040.pdf page 2 not processed...
# WARNING: AO_2022-040.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_2022-041.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_AVT_2014_023.pdf...
# WARNING: AO_AVT_2014_023.pdf page 1 not processed...
# WARNING: AO_AVT_2014_023.pdf page 2 not processed...
# WARNING: AO_AVT_2014_023.pdf page 3 not processed...
# WARNING: AO_AVT_2014_023.pdf page 4 not processed...
# WARNING: AO_AVT_2014_023.pdf page 5 not processed...
# WARNING: AO_AVT_2014_023.pdf page 6 not processed...
# WARNING: AO_AVT_2014_023.pdf page 7 not processed...
# WARNING: AO_AVT_2014_023.pdf page 8 not processed...
# WARNING: AO_AVT_2014_023.pdf page 9 not processed...
# WARNING: AO_AVT_2014_023.pdf page 10 not processed...
# WARNING: AO_AVT_2014_023.pdf page 11 not processed...
# WARNING: AO_AVT_2014_023.pdf page 12 not processed...
# WARNING: AO_AVT_2014_023.pdf page 13 not processed...
# WARNING: AO_AVT_2014_023.pdf page 14 not processed...
# WARNING: AO_AVT_2014_023.pdf page 15 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_AVT_2014_024.pdf...
# WARNING: AO_AVT_2014_024.pdf page 1 not processed...
# WARNING: AO_AVT_2014_024.pdf page 2 not processed...
# WARNING: AO_AVT_2014_024.pdf page 3 not processed...
# WARNING: AO_AVT_2014_024.pdf page 4 not processed...
# WARNING: AO_AVT_2014_024.pdf page 5 not processed...
# WARNING: AO_AVT_2014_024.pdf page 6 not processed...
# WARNING: AO_AVT_2014_024.pdf page 7 not processed...
# WARNING: AO_AVT_2014_024.pdf page 8 not processed...
# WARNING: AO_AVT_2014_024.pdf page 9 not processed...
# WARNING: AO_AVT_2014_024.pdf page 10 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_AVT_2014_025.pdf...
# WARNING: AO_AVT_2014_025.pdf page 1 not processed...
# WARNING: AO_AVT_2014_025.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_BGC-AO-99004.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_JMT-2023-042.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AO_VDM-2024-044-2.pdf...
# WARNING: AO_VDM-2024-044-2.pdf page 1 not processed...
# WARNING: AO_VDM-2024-044-2.pdf page 2 not processed...
# WARNING: AO_VDM-2024-044-2.pdf page 3 not processed...
# WARNING: AO_VDM-2024-044-2.pdf page 4 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/APL-Form_v3.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Application_Form_for_Unclaimed_DL.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Application_OMVSP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AVT_2015_029.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AVT_2015_030.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/AVT_2015_031.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/CitiSend Incident Reporting App.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO-2021-003.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO-2024-007.pdf...
# WARNING: DO-2024-007.pdf page 1 not processed...
# WARNING: DO-2024-007.pdf page 2 not processed...
# WARNING: DO-2024-007.pdf page 3 not processed...
# WARNING: DO-2024-007.pdf page 4 not processed...
# WARNING: DO-2024-007.pdf page 5 not processed...
# WARNING: DO-2024-007.pdf page 6 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2008-38.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2008_11.pdf...
# WARNING: DO_2008_11.pdf page 1 not processed...
# WARNING: DO_2008_11.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2008_39.pdf...
# WARNING: DO_2008_39.pdf page 1 not processed...
# WARNING: DO_2008_39.pdf page 2 not processed...
# WARNING: DO_2008_39.pdf page 3 not processed...
# WARNING: DO_2008_39.pdf page 4 not processed...
# WARNING: DO_2008_39.pdf page 5 not processed...
# WARNING: DO_2008_39.pdf page 6 not processed...
# WARNING: DO_2008_39.pdf page 7 not processed...
# WARNING: DO_2008_39.pdf page 8 not processed...
# WARNING: DO_2008_39.pdf page 9 not processed...
# WARNING: DO_2008_39.pdf page 10 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2010-32.pdf...
# WARNING: DO_2010-32.pdf page 1 not processed...
# WARNING: DO_2010-32.pdf page 2 not processed...
# WARNING: DO_2010-32.pdf page 3 not processed...
# WARNING: DO_2010-32.pdf page 4 not processed...
# WARNING: DO_2010-32.pdf page 5 not processed...
# WARNING: DO_2010-32.pdf page 6 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2012_10.pdf...
# WARNING: DO_2012_10.pdf page 1 not processed...
# WARNING: DO_2012_10.pdf page 2 not processed...
# WARNING: DO_2012_10.pdf page 3 not processed...
# WARNING: DO_2012_10.pdf page 4 not processed...
# WARNING: DO_2012_10.pdf page 5 not processed...
# WARNING: DO_2012_10.pdf page 6 not processed...
# WARNING: DO_2012_10.pdf page 7 not processed...
# WARNING: DO_2012_10.pdf page 8 not processed...
# WARNING: DO_2012_10.pdf page 9 not processed...
# WARNING: DO_2012_10.pdf page 10 not processed...
# WARNING: DO_2012_10.pdf page 11 not processed...
# WARNING: DO_2012_10.pdf page 12 not processed...
# WARNING: DO_2012_10.pdf page 13 not processed...
# WARNING: DO_2012_10.pdf page 14 not processed...
# WARNING: DO_2012_10.pdf page 15 not processed...
# WARNING: DO_2012_10.pdf page 16 not processed...
# WARNING: DO_2012_10.pdf page 17 not processed...
# WARNING: DO_2012_10.pdf page 18 not processed...
# WARNING: DO_2012_10.pdf page 19 not processed...
# WARNING: DO_2012_10.pdf page 20 not processed...
# WARNING: DO_2012_10.pdf page 21 not processed...
# WARNING: DO_2012_10.pdf page 22 not processed...
# WARNING: DO_2012_10.pdf page 23 not processed...
# WARNING: DO_2012_10.pdf page 24 not processed...
# WARNING: DO_2012_10.pdf page 25 not processed...
# WARNING: DO_2012_10.pdf page 26 not processed...
# WARNING: DO_2012_10.pdf page 27 not processed...
# WARNING: DO_2012_10.pdf page 28 not processed...
# WARNING: DO_2012_10.pdf page 29 not processed...
# WARNING: DO_2012_10.pdf page 30 not processed...
# WARNING: DO_2012_10.pdf page 31 not processed...
# WARNING: DO_2012_10.pdf page 32 not processed...
# WARNING: DO_2012_10.pdf page 33 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2015-013.pdf...
# WARNING: DO_2015-013.pdf page 1 not processed...
# WARNING: DO_2015-013.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2017-009.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2017-010.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2018-008.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DO_2020-010.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/DS_IT_App-Form.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Enforcement_Operations.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/FDM-Vol.-1-2nd-Edition.pdf...
# WARNING: FDM-Vol.-1-2nd-Edition.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/FDM-vol.-2-2nd-Edition.pdf...
# WARNING: FDM-vol.-2-2nd-Edition.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA10586.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA10666.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA10916.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA10930-1.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA10930.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA11235.pdf...
# WARNING: IRR-RA11235.pdf page 1 not processed...
# WARNING: IRR-RA11235.pdf page 2 not processed...
# WARNING: IRR-RA11235.pdf page 3 not processed...
# WARNING: IRR-RA11235.pdf page 4 not processed...
# WARNING: IRR-RA11235.pdf page 5 not processed...
# WARNING: IRR-RA11235.pdf page 6 not processed...
# WARNING: IRR-RA11235.pdf page 7 not processed...
# WARNING: IRR-RA11235.pdf page 8 not processed...
# WARNING: IRR-RA11235.pdf page 9 not processed...
# WARNING: IRR-RA11235.pdf page 10 not processed...
# WARNING: IRR-RA11235.pdf page 11 not processed...
# WARNING: IRR-RA11235.pdf page 12 not processed...
# WARNING: IRR-RA11235.pdf page 13 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA11697.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA11698.pdf...
# WARNING: IRR-RA11698.pdf page 27 not processed...
# WARNING: IRR-RA11698.pdf page 28 not processed...
# WARNING: IRR-RA11698.pdf page 29 not processed...
# WARNING: IRR-RA11698.pdf page 30 not processed...
# WARNING: IRR-RA11698.pdf page 31 not processed...
# WARNING: IRR-RA11698.pdf page 32 not processed...
# WARNING: IRR-RA11698.pdf page 33 not processed...
# WARNING: IRR-RA11698.pdf page 34 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR-RA8794.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/IRR_RA10913.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/issuance_memo_oct_2012.pdf...
# WARNING: issuance_memo_oct_2012.pdf page 1 not processed...
# WARNING: issuance_memo_oct_2012.pdf page 2 not processed...
# WARNING: issuance_memo_oct_2012.pdf page 3 not processed...
# WARNING: issuance_memo_oct_2012.pdf page 4 not processed...
# WARNING: issuance_memo_oct_2012.pdf page 5 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/JAO-2014-01.pdf...
# WARNING: JAO-2014-01.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/JAO-2024-001.pdf...
# WARNING: JAO-2024-001.pdf page 1 not processed...
# WARNING: JAO-2024-001.pdf page 2 not processed...
# WARNING: JAO-2024-001.pdf page 3 not processed...
# WARNING: JAO-2024-001.pdf page 4 not processed...
# WARNING: JAO-2024-001.pdf page 5 not processed...
# WARNING: JAO-2024-001.pdf page 6 not processed...
# WARNING: JAO-2024-001.pdf page 7 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/JAO_2011-01s2011.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/JAO_2014-01.pdf...
# WARNING: JAO_2014-01.pdf page 1 not processed...
# WARNING: JAO_2014-01.pdf page 2 not processed...
# WARNING: JAO_2014-01.pdf page 3 not processed...
# WARNING: JAO_2014-01.pdf page 4 not processed...
# WARNING: JAO_2014-01.pdf page 5 not processed...
# WARNING: JAO_2014-01.pdf page 6 not processed...
# WARNING: JAO_2014-01.pdf page 7 not processed...
# WARNING: JAO_2014-01.pdf page 8 not processed...
# WARNING: JAO_2014-01.pdf page 9 not processed...
# WARNING: JAO_2014-01.pdf page 10 not processed...
# WARNING: JAO_2014-01.pdf page 11 not processed...
# WARNING: JAO_2014-01.pdf page 12 not processed...
# WARNING: JAO_2014-01.pdf page 13 not processed...
# WARNING: JAO_2014-01.pdf page 14 not processed...
# WARNING: JAO_2014-01.pdf page 15 not processed...
# WARNING: JAO_2014-01.pdf page 16 not processed...
# WARNING: JAO_2014-01.pdf page 17 not processed...
# WARNING: JAO_2014-01.pdf page 18 not processed...
# WARNING: JAO_2014-01.pdf page 19 not processed...
# WARNING: JAO_2014-01.pdf page 20 not processed...
# WARNING: JAO_2014-01.pdf page 21 not processed...
# WARNING: JAO_2014-01.pdf page 22 not processed...
# WARNING: JAO_2014-01.pdf page 23 not processed...
# WARNING: JAO_2014-01.pdf page 24 not processed...
# WARNING: JAO_2014-01.pdf page 25 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/LTO-A-176-05152020_Memorandum_Checklist_of_Requirement_for_LTMS_Implementation.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/LTO_road_safety_action_plan.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MAIDRS_Application_Accreditation.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MAIDRs_Application_Accreditation_Renewal.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2669.pdf...
# WARNING: MC-VDM-2024-2669.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 2 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 3 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 4 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 5 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 6 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 7 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 8 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 9 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 10 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 11 not processed...
# WARNING: MC-VDM-2024-2669.pdf page 12 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2670.pdf...
# WARNING: MC-VDM-2024-2670.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2672.pdf...
# WARNING: MC-VDM-2024-2672.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2672.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2673.pdf...
# WARNING: MC-VDM-2024-2673.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2673.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2674.pdf...
# WARNING: MC-VDM-2024-2674.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2674.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2675.pdf...
# WARNING: MC-VDM-2024-2675.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2675.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2676.pdf...
# WARNING: MC-VDM-2024-2676.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2676.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2677.pdf...
# WARNING: MC-VDM-2024-2677.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2677.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2678.pdf...
# WARNING: MC-VDM-2024-2678.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2678.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2679.pdf...
# WARNING: MC-VDM-2024-2679.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2679.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2680.pdf...
# WARNING: MC-VDM-2024-2680.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2680.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2681.pdf...
# WARNING: MC-VDM-2024-2681.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2681.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2682.pdf...
# WARNING: MC-VDM-2024-2682.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2682.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2683.pdf...
# WARNING: MC-VDM-2024-2683.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2683.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2684.pdf...
# WARNING: MC-VDM-2024-2684.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2684.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2685.pdf...
# WARNING: MC-VDM-2024-2685.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2685.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2686.pdf...
# WARNING: MC-VDM-2024-2686.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2686.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2687.pdf...
# WARNING: MC-VDM-2024-2687.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2687.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2688.pdf...
# WARNING: MC-VDM-2024-2688.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2688.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2689.pdf...
# WARNING: MC-VDM-2024-2689.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2689.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2690.pdf...
# WARNING: MC-VDM-2024-2690.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2690.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2691.pdf...
# WARNING: MC-VDM-2024-2691.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2691.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2692.pdf...
# WARNING: MC-VDM-2024-2692.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2692.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2693.pdf...
# WARNING: MC-VDM-2024-2693.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2693.pdf page 2 not processed...
# WARNING: MC-VDM-2024-2693.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2694.pdf...
# WARNING: MC-VDM-2024-2694.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2694.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2695.pdf...
# WARNING: MC-VDM-2024-2695.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2695.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2696.pdf...
# WARNING: MC-VDM-2024-2696.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2696.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2697.pdf...
# WARNING: MC-VDM-2024-2697.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2697.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2698.pdf...
# WARNING: MC-VDM-2024-2698.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2698.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2699.pdf...
# WARNING: MC-VDM-2024-2699.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2699.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2700.pdf...
# WARNING: MC-VDM-2024-2700.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2700.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2701.pdf...
# WARNING: MC-VDM-2024-2701.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2701.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2702.pdf...
# WARNING: MC-VDM-2024-2702.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2702.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2703.pdf...
# WARNING: MC-VDM-2024-2703.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2703.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2704.pdf...
# WARNING: MC-VDM-2024-2704.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2704.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2705.pdf...
# WARNING: MC-VDM-2024-2705.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2705.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2706.pdf...
# WARNING: MC-VDM-2024-2706.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2706.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2707.pdf...
# WARNING: MC-VDM-2024-2707.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2707.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2708.pdf...
# WARNING: MC-VDM-2024-2708.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2709.pdf...
# WARNING: MC-VDM-2024-2709.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2709.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2710.pdf...
# WARNING: MC-VDM-2024-2710.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2710.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2711.pdf...
# WARNING: MC-VDM-2024-2711.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2711.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2712.pdf...
# WARNING: MC-VDM-2024-2712.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2712.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2713.pdf...
# WARNING: MC-VDM-2024-2713.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2713.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2714.pdf...
# WARNING: MC-VDM-2024-2714.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2714.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2715.pdf...
# WARNING: MC-VDM-2024-2715.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2715.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2716.pdf...
# WARNING: MC-VDM-2024-2716.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2716.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2717.pdf...
# WARNING: MC-VDM-2024-2717.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2717.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2718.pdf...
# WARNING: MC-VDM-2024-2718.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2718.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2719.pdf...
# WARNING: MC-VDM-2024-2719.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2719.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2720.pdf...
# WARNING: MC-VDM-2024-2720.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2720.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2721.pdf...
# WARNING: MC-VDM-2024-2721.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 2 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 3 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 4 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 5 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 6 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 7 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 8 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 9 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 10 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 11 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 12 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 13 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 14 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 15 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 16 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 17 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 18 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 19 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 20 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 21 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 22 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 23 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 24 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 25 not processed...
# WARNING: MC-VDM-2024-2721.pdf page 26 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2722.pdf...
# WARNING: MC-VDM-2024-2722.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2722.pdf page 2 not processed...
# WARNING: MC-VDM-2024-2722.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2723.pdf...
# WARNING: MC-VDM-2024-2723.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2723.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2724.pdf...
# WARNING: MC-VDM-2024-2724.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2724.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2725.pdf...
# WARNING: MC-VDM-2024-2725.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2725.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2726.pdf...
# WARNING: MC-VDM-2024-2726.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2726.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2727.pdf...
# WARNING: MC-VDM-2024-2727.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2727.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2728.pdf...
# WARNING: MC-VDM-2024-2728.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2728.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2729.pdf...
# WARNING: MC-VDM-2024-2729.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2729.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2730.pdf...
# WARNING: MC-VDM-2024-2730.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2730.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2731.pdf...
# WARNING: MC-VDM-2024-2731.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2731.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2732.pdf...
# WARNING: MC-VDM-2024-2732.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2732.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2733.pdf...
# WARNING: MC-VDM-2024-2733.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2733.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2734.pdf...
# WARNING: MC-VDM-2024-2734.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2734.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2735.pdf...
# WARNING: MC-VDM-2024-2735.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2735.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2736.pdf...
# WARNING: MC-VDM-2024-2736.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2736.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2737.pdf...
# WARNING: MC-VDM-2024-2737.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2737.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2738.pdf...
# WARNING: MC-VDM-2024-2738.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2738.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2739.pdf...
# WARNING: MC-VDM-2024-2739.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2739.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2740.pdf...
# WARNING: MC-VDM-2024-2740.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2740.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2741.pdf...
# WARNING: MC-VDM-2024-2741.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2741.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2742.pdf...
# WARNING: MC-VDM-2024-2742.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2742.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2743.pdf...
# WARNING: MC-VDM-2024-2743.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2743.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2744.pdf...
# WARNING: MC-VDM-2024-2744.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2744.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2745.pdf...
# WARNING: MC-VDM-2024-2745.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2745.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2746.pdf...
# WARNING: MC-VDM-2024-2746.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2746.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2747.pdf...
# WARNING: MC-VDM-2024-2747.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2747.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2748.pdf...
# WARNING: MC-VDM-2024-2748.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2748.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2749.pdf...
# WARNING: MC-VDM-2024-2749.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2749.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2750.pdf...
# WARNING: MC-VDM-2024-2750.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2750.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2751.pdf...
# WARNING: MC-VDM-2024-2751.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2751.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2752.pdf...
# WARNING: MC-VDM-2024-2752.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2752.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2753.pdf...
# WARNING: MC-VDM-2024-2753.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2753.pdf page 2 not processed...
# WARNING: MC-VDM-2024-2753.pdf page 3 not processed...
# WARNING: MC-VDM-2024-2753.pdf page 4 not processed...
# WARNING: MC-VDM-2024-2753.pdf page 5 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2754.pdf...
# WARNING: MC-VDM-2024-2754.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2754.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2755.pdf...
# WARNING: MC-VDM-2024-2755.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2755.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2756.pdf...
# WARNING: MC-VDM-2024-2756.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2756.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2757.pdf...
# WARNING: MC-VDM-2024-2757.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2757.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2758.pdf...
# WARNING: MC-VDM-2024-2758.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2758.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2759.pdf...
# WARNING: MC-VDM-2024-2759.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2759.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2760.pdf...
# WARNING: MC-VDM-2024-2760.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2760.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2761.pdf...
# WARNING: MC-VDM-2024-2761.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2761.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2762.pdf...
# WARNING: MC-VDM-2024-2762.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2762.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2763.pdf...
# WARNING: MC-VDM-2024-2763.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2763.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2764.pdf...
# WARNING: MC-VDM-2024-2764.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2764.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2765.pdf...
# WARNING: MC-VDM-2024-2765.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2765.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2766.pdf...
# WARNING: MC-VDM-2024-2766.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2766.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2767.pdf...
# WARNING: MC-VDM-2024-2767.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2767.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2768.pdf...
# WARNING: MC-VDM-2024-2768.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2768.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2769.pdf...
# WARNING: MC-VDM-2024-2769.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2769.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2770.pdf...
# WARNING: MC-VDM-2024-2770.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2770.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2771.pdf...
# WARNING: MC-VDM-2024-2771.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2771.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2772.pdf...
# WARNING: MC-VDM-2024-2772.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2772.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2773.pdf...
# WARNING: MC-VDM-2024-2773.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2773.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2774.pdf...
# WARNING: MC-VDM-2024-2774.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2774.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2775.pdf...
# WARNING: MC-VDM-2024-2775.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2775.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2776.pdf...
# WARNING: MC-VDM-2024-2776.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2776.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2777.pdf...
# WARNING: MC-VDM-2024-2777.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2777.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2778.pdf...
# WARNING: MC-VDM-2024-2778.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2778.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2779.pdf...
# WARNING: MC-VDM-2024-2779.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2779.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2780.pdf...
# WARNING: MC-VDM-2024-2780.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2780.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2781.pdf...
# WARNING: MC-VDM-2024-2781.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2781.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2782.pdf...
# WARNING: MC-VDM-2024-2782.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2782.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2783.pdf...
# WARNING: MC-VDM-2024-2783.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2783.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2784.pdf...
# WARNING: MC-VDM-2024-2784.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2784.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2785.pdf...
# WARNING: MC-VDM-2024-2785.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2785.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2786.pdf...
# WARNING: MC-VDM-2024-2786.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2786.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2787.pdf...
# WARNING: MC-VDM-2024-2787.pdf page 1 not processed...
# WARNING: MC-VDM-2024-2787.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MC-VDM-2024-2788.pdf...
# WARNING: MC-VDM-2024-2788.pdf page 1 not processed...
# ...
# WARNING: Memo_10262023-1.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_10262023.pdf...
# WARNING: Memo_10262023.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_10272023.pdf...
# WARNING: Memo_10272023.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_10282021_Extension.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_10282021_Manual_Visual_Inspection.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_11032023.pdf...
# WARNING: Memo_11032023.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11042022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11092012.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_11092023.pdf...
# WARNING: Memo_11092023.pdf page 1 not processed...
# WARNING: Memo_11092023.pdf page 2 not processed...
# WARNING: Memo_11092023.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11102021_CitizenCharter_Licensing-Transaction.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11112022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11142013.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_11172022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_11242023-Plates.pdf...
# WARNING: Memo_11242023-Plates.pdf page 1 not processed...
# WARNING: Memo_11242023-Plates.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_11242023.pdf...
# WARNING: Memo_11242023.pdf page 1 not processed...
# WARNING: Memo_11242023.pdf page 2 not processed...
# WARNING: Memo_11242023.pdf page 3 not processed...
# WARNING: Memo_11242023.pdf page 4 not processed...
# WARNING: Memo_11242023.pdf page 5 not processed...
# WARNING: Memo_11242023.pdf page 6 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11282013.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_11282022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12012021.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12012021_Validity_December012021.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12012022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12022022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12052013.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12052022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_12072023.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12092021_LTMS2.3.0.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12092022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12092022_Plate_Series.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_12112023.pdf...
# WARNING: Memo_12112023.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12122022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12132021_LicenseFee_10yr.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_12132023.pdf...
# WARNING: Memo_12132023.pdf page 1 not processed...
# WARNING: Memo_12132023.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_12162020_APL-MVIR-forms.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_12192023.pdf...
# WARNING: Memo_12192023.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12212021_MVIRS.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_122220_emission-test.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_12232021_Extension_DL.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_12292020-PMVIC-covid19-protocol.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_13032024.pdf...
# WARNING: Memo_13032024.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_18112022.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_19022024.pdf...
# WARNING: Memo_19022024.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_19022024mvuc.pdf...
# WARNING: Memo_19022024mvuc.pdf page 1 not processed...
# WARNING: Memo_19022024mvuc.pdf page 2 not processed...
# WARNING: Memo_19022024mvuc.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_20022024.pdf...
# WARNING: Memo_20022024.pdf page 1 not processed...
# WARNING: Memo_20022024.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_21022024-IT-Service-Provider.pdf...
# WARNING: Memo_21022024-IT-Service-Provider.pdf page 1 not processed...
# WARNING: Memo_21022024-IT-Service-Provider.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_21022024.pdf...
# WARNING: Memo_21022024.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_21032024.pdf...
# WARNING: Memo_21032024.pdf page 1 not processed...
# WARNING: Memo_21032024.pdf page 2 not processed...
# WARNING: Memo_21032024.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_22022024.pdf...
# WARNING: Memo_22022024.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_22022024_2.pdf...
# WARNING: Memo_22022024_2.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_25032024-1.pdf...
# WARNING: Memo_25032024-1.pdf page 1 not processed...
# WARNING: Memo_25032024-1.pdf page 2 not processed...
# WARNING: Memo_25032024-1.pdf page 3 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_25032024-Release.pdf...
# WARNING: Memo_25032024-Release.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_25032024.pdf...
# WARNING: Memo_25032024.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_28022024.pdf...
# WARNING: Memo_28022024.pdf page 1 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_ammend_CitizensCharter.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Aug242021.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Aug302021.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Aug312021.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Bajaj.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_conduction_sticker.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Data-Privacy.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_dealers.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_EXT_SP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_GAOR_PMVIC.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MEMO_Guidelines_Implementation_EOP.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Kiosk.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_MCno.2018-2129.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_MCTopBoxesSaddleBags.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Medical.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Medical_Clarification.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_MMDA.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_MVRS_RSU_27-07-2021.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_MV_ren.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_omvsp_suspend.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Online_Appointment.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_pbb.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_penalty.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_plate_dist.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_quota_cutoff.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/memo_RA10586.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_RA_8750.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Return_Engravers_PropertySection.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_Temp_DL.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/Memo_YrModel-VIN.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/MVIR-Form.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/M_2018-001.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/M_2018-002.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/PETC_Application_Authorization.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/PETC_Application_Authorization_IT_Service_Provider.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/PETC_Application_Renewal.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/PMVIC_Form.pdf...
# WARNING: PMVIC_Form.pdf page 1 not processed...
# WARNING: PMVIC_Form.pdf page 2 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/praos_10_april_2015.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/praos_18feb2015.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-10054.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-10586.pdf...
# WARNING: RA-10586.pdf page 1 not processed...
# WARNING: RA-10586.pdf page 2 not processed...
# WARNING: RA-10586.pdf page 3 not processed...
# WARNING: RA-10586.pdf page 4 not processed...
# WARNING: RA-10586.pdf page 5 not processed...
# WARNING: RA-10586.pdf page 6 not processed...
# WARNING: RA-10586.pdf page 7 not processed...
# WARNING: RA-10586.pdf page 8 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-10666.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-10913.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-10930.pdf...
# WARNING: RA-10930.pdf page 1 not processed...
# WARNING: RA-10930.pdf page 2 not processed...
# WARNING: RA-10930.pdf page 3 not processed...
# WARNING: RA-10930.pdf page 4 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-4136.pdf...
# WARNING: RA-4136.pdf page 1 not processed...
# WARNING: RA-4136.pdf page 2 not processed...
# WARNING: RA-4136.pdf page 3 not processed...
# WARNING: RA-4136.pdf page 4 not processed...
# WARNING: RA-4136.pdf page 5 not processed...
# WARNING: RA-4136.pdf page 6 not processed...
# WARNING: RA-4136.pdf page 7 not processed...
# WARNING: RA-4136.pdf page 8 not processed...
# WARNING: RA-4136.pdf page 9 not processed...
# WARNING: RA-4136.pdf page 10 not processed...
# WARNING: RA-4136.pdf page 11 not processed...
# WARNING: RA-4136.pdf page 12 not processed...
# WARNING: RA-4136.pdf page 13 not processed...
# WARNING: RA-4136.pdf page 14 not processed...
# WARNING: RA-4136.pdf page 15 not processed...
# WARNING: RA-4136.pdf page 16 not processed...
# WARNING: RA-4136.pdf page 17 not processed...
# WARNING: RA-4136.pdf page 18 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-8730.pdf...
# WARNING: RA-8730.pdf page 1 not processed...
# WARNING: RA-8730.pdf page 2 not processed...
# WARNING: RA-8730.pdf page 3 not processed...
# WARNING: RA-8730.pdf page 4 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-8749.pdf...
# WARNING: RA-8749.pdf page 1 not processed...
# WARNING: RA-8749.pdf page 2 not processed...
# WARNING: RA-8749.pdf page 3 not processed...
# WARNING: RA-8749.pdf page 4 not processed...
# WARNING: RA-8749.pdf page 5 not processed...
# WARNING: RA-8749.pdf page 6 not processed...
# WARNING: RA-8749.pdf page 7 not processed...
# WARNING: RA-8749.pdf page 8 not processed...
# WARNING: RA-8749.pdf page 9 not processed...
# WARNING: RA-8749.pdf page 10 not processed...
# WARNING: RA-8749.pdf page 11 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-8750.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RA-8794.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO101-CDE-Road-Safety-10.22.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO102_CDE_Road_and_Traffic_Rules_Expressway.pdf...
# WARNING: RO102_CDE_Road_and_Traffic_Rules_Expressway.pdf page 7 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO102_CDE_Road_and_Traffic_Rules_Rules-on-the-road.pdf...
# WARNING: RO102_CDE_Road_and_Traffic_Rules_Rules-on-the-road.pdf page 29 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO102_CDE_Road_and_Traffic_Rules_Signs-Signals-Markings.pdf...
# WARNING: RO102_CDE_Road_and_Traffic_Rules_Signs-Signals-Markings.pdf page 43 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO103a-CDE-Spl-Laws-10.22.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO103b-CDE-Spll-Laws-MC-and-TC-10.22.pdf...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO104-CDE-Other-Regulatons-10.21.pdf...
# WARNING: RO104-CDE-Other-Regulatons-10.21.pdf page 22 not processed...
# Extracting text from /mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/Dataset2/RO105-CDE-General-Information-10.22.pdf...

# %%
documents = [Document(text=docs[t], metadata=metadatas[t]) for t in range(len(docs))]
splitter = TokenTextSplitter(
    chunk_size=512,
    chunk_overlap=20,
    separator=" ",
)
nodes = splitter.get_nodes_from_documents(documents)

# %%
print(nodes[0])
# Out:
# Node ID: e1efc25c-5c58-44c8-9703-77e65b605179
# Text: WHERE TO SECURE Accredited
# Manufacturer/Assembler/Importer/Rebuilder/Other Entities Accredited
# insurance companies by the Insurance Commission / GSIS PNP-HPG MV
# Clearance Division Owner Land Transportation Management System (LTMS)
# 1. SALES REPORTING AND INITIAL REGISTRATION OF MOTOR VEHICLES One of
# the core mandates of the LTO pursuant to Republ...

# %% [markdown]
# # 4. QA Generation
# Used for Retreival Evaluation:
# 1. Get all document nodes
# 2. Generate question for each node (using llama 3.2)
# 3. Question Answer pairs: Generated Question, Node text

# %%
from llama_index.core.evaluation import (
    generate_question_context_pairs,
    EmbeddingQAFinetuneDataset,
)

ollama_llm = Ollama(model="llama3.1:8b", request_timeout=300)

qa_dataset = generate_question_context_pairs(
    nodes, llm=ollama_llm, num_questions_per_chunk=1
)

queries = qa_dataset.queries.values()
print(list(queries)[2])


# Save
qa_dataset.save_json("pg_eval_dataset.json")
print("Successfully created QA dataset")
# Out:
#   0%|          | 0/2592 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_transports/default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[15], line 8
#       1 from llama_index.core.evaluation import (
#       2     generate_question_context_pairs,
#       3     EmbeddingQAFinetuneDataset,
#       4 )
#       6 ollama_llm = Ollama(model="llama3.1:8b", request_timeout=300)
# ----> 8 qa_dataset = generate_question_context_pairs(
#       9     nodes, llm=ollama_llm, num_questions_per_chunk=1
#      10 )
#      12 queries = qa_dataset.queries.values()
#      13 print(list(queries)[2])
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/core/llama_dataset/legacy/embedding.py:90, in generate_qa_embedding_pairs(nodes, llm, qa_generate_prompt_tmpl, num_questions_per_chunk)
#      86 for node_id, text in tqdm(node_dict.items()):
#      87     query = qa_generate_prompt_tmpl.format(
#      88         context_str=text, num_questions_per_chunk=num_questions_per_chunk
#      89     )
# ---> 90     response = llm.complete(query)
#      92     result = str(response).strip().split("\n")
#      93     questions = [
#      94         re.sub(r"^\d+[\).\s]", "", question).strip() for question in result
#      95     ]
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/core/llms/callbacks.py:431, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     422 event_id = callback_manager.on_event_start(
#     423     CBEventType.LLM,
#     424     payload={
#    (...)
#     428     },
#     429 )
#     430 try:
# --> 431     f_return_val = f(_self, *args, **kwargs)
#     432 except BaseException as e:
#     433     callback_manager.on_event_end(
#     434         CBEventType.LLM,
#     435         payload={EventPayload.EXCEPTION: e},
#     436         event_id=event_id,
#     437     )
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/llms/ollama/base.py:465, in Ollama.complete(self, prompt, formatted, **kwargs)
#     461 @llm_completion_callback()
#     462 def complete(
#     463     self, prompt: str, formatted: bool = False, **kwargs: Any
#     464 ) -> CompletionResponse:
# --> 465     return chat_to_completion_decorator(self.chat)(prompt, **kwargs)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/core/base/llms/generic_utils.py:173, in chat_to_completion_decorator.<locals>.wrapper(prompt, **kwargs)
#     170 def wrapper(prompt: str, **kwargs: Any) -> CompletionResponse:
#     171     # normalize input
#     172     messages = prompt_to_messages(prompt)
# --> 173     chat_response = func(messages, **kwargs)
#     174     # normalize output
#     175     return chat_response_to_completion_response(chat_response)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/core/llms/callbacks.py:173, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     164 event_id = callback_manager.on_event_start(
#     165     CBEventType.LLM,
#     166     payload={
#    (...)
#     170     },
#     171 )
#     172 try:
# --> 173     f_return_val = f(_self, messages, **kwargs)
#     174 except BaseException as e:
#     175     callback_manager.on_event_end(
#     176         CBEventType.LLM,
#     177         payload={EventPayload.EXCEPTION: e},
#     178         event_id=event_id,
#     179     )
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/llama_index/llms/ollama/base.py:306, in Ollama.chat(self, messages, **kwargs)
#     303 tools = kwargs.pop("tools", None)
#     304 format = kwargs.pop("format", "json" if self.json_mode else None)
# --> 306 response = self.client.chat(
#     307     model=self.model,
#     308     messages=ollama_messages,
#     309     stream=False,
#     310     format=format,
#     311     tools=tools,
#     312     options=self._model_kwargs,
#     313     keep_alive=self.keep_alive,
#     314 )
#     316 response = dict(response)
#     318 tool_calls = response["message"].get("tool_calls", [])
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/ollama/_client.py:332, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     288 def chat(
#     289   self,
#     290   model: str = '',
#    (...)
#     297   keep_alive: Optional[Union[float, str]] = None,
#     298 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     299   """
#     300   Create a chat response using the requested model.
#     301
#    (...)
#     330   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     331   """
# --> 332   return self._request(
#     333     ChatResponse,
#     334     'POST',
#     335     '/api/chat',
#     336     json=ChatRequest(
#     337       model=model,
#     338       messages=[message for message in _copy_messages(messages)],
#     339       tools=[tool for tool in _copy_tools(tools)],
#     340       stream=stream,
#     341       format=format,
#     342       options=options,
#     343       keep_alive=keep_alive,
#     344     ).model_dump(exclude_none=True),
#     345     stream=stream,
#     346   )
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     117 def _request_raw(self, *args, **kwargs):
# --> 118   r = self._client.request(*args, **kwargs)
#     119   try:
#     120     r.raise_for_status()
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_transports/default.py:235, in HTTPTransport.handle_request(self, request)
#     221 assert isinstance(request.stream, SyncByteStream)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
# --> 235 with map_httpcore_exceptions():
#     236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File ~/lto_rag_reviewer/LTO_RAG/lib/python3.10/site-packages/httpx/_transports/default.py:89, in map_httpcore_exceptions()
#      86     raise
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused

# %%
# Load
qa_dataset = EmbeddingQAFinetuneDataset.from_json("pg_eval_dataset.json")

# %% [markdown]
# # 5. Embedding and Retrieval

# %% [markdown]
# ## 5.A. Dense via FAISS

# %%
def generate_embeddings(nodes, client, model):
    # Generate embeddings for documents using Ollama
    for doc in tqdm(nodes):
        response = client.embeddings(prompt=doc.text, model=model)
        doc.embedding = response["embedding"]
    return nodes

# %%
class FaissIndexer:
    """
    Faiss-based indexer for efficient similarity search using inner-product (cosine) similarity.

    This class handles the creation and management of a FAISS index from node embeddings.
    
    :ivar faiss_index: The FAISS index for storing and querying embeddings.
    :vartype faiss_index: faiss.IndexFlatIP
    :ivar embedding_dim: Dimensionality of the embeddings.
    :vartype embedding_dim: int
    """

    def __init__(self):
        """
        Initialize the FaissIndexer class.

        :ivar faiss_index: The FAISS index, initialized as None.
        :ivar embedding_dim: The dimension of embeddings, initialized as None.
        """
        self.faiss_index = None
        self.embedding_dim = None

    def normalize_embeddings(self, embeddings):
        """
        Normalize embeddings to have unit L2 norm.

        :param embeddings: Array of embeddings to normalize.
        :type embeddings: np.ndarray
        :return: Normalized embeddings.
        :rtype: np.ndarray
        """
        return embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

    def build_index(self, nodes):
        """
        Build the FAISS index from a list of nodes containing embeddings.

        :param nodes: List of nodes, where each node contains an `embedding` attribute.
        :type nodes: list
        :raises ValueError: If the nodes list is empty or embeddings are inconsistent.
        """
        if not nodes:
            raise ValueError("Nodes list cannot be empty.")
        
        embeddings = np.array([np.array(node.embedding) for node in nodes])
        normalized_embeddings = self.normalize_embeddings(embeddings)

        self.embedding_dim = normalized_embeddings[0].shape[0]
        self.faiss_index = faiss.IndexFlatIP(self.embedding_dim)  # Inner-product similarity
        self.faiss_index.add(normalized_embeddings)

    def get_index(self):
        """
        Get the FAISS index instance.

        :return: The FAISS index used for similarity search.
        :rtype: faiss.IndexFlatIP
        :raises ValueError: If the index has not been built.
        """
        if self.faiss_index is None:
            raise ValueError("Index has not been built yet. Call 'build_index' first.")
        return self.faiss_index

# %%
class FAISSVectorStoreRetriever(BaseRetriever):
    def __init__(self, faiss_index, documents):
        """
        Initialize the FAISS retriever.
        :param faiss_index: The FAISS index containing precomputed embeddings.
        :param documents: List of document chunks.
        :param embeddings: Precomputed embeddings corresponding to the document chunks.
        """
        self.faiss_index = faiss_index
        self.documents = documents

    def _retrieve(self, query_embedding, top_k=5):
        """
        Retrieve the top-k nearest neighbors using the FAISS index.
        :param query_embedding: The embedding of the query.
        :param top_k: Number of top results to retrieve.
        """

        norm_query_embedding = np.array([query_embedding])
        norm_query_embedding /= np.linalg.norm(norm_query_embedding, axis=1, keepdims=True)

        distances, indices = self.faiss_index.search(norm_query_embedding, top_k)
        retrieved_docs = [
            NodeWithScore(node=self.documents[idx], score=1 - dist)
            for idx, dist in zip(indices[0], distances[0])
            if idx != -1
        ]
        return retrieved_docs

# %% [markdown]
# ## 5.B. FAISS Retreival Evaluator

# %%
from typing import List, Tuple, Any
from pydantic import Field, ConfigDict
from llama_index.core.evaluation.retrieval.base import (
    BaseRetrievalEvaluator,
    RetrievalEvalMode,
    RetrievalEvalResult
)
from llama_index.core.evaluation.retrieval.metrics import resolve_metrics
from llama_index.core.response.notebook_utils import display_source_node

class FAISSRetrievalEvaluator(BaseRetrievalEvaluator):
    retriever: "FAISSVectorStoreRetriever" = Field(..., description="FAISS Retriever instance")
    Print_Results: bool = Field(default=False, description="Whether to print retrieved results")

    model_config = ConfigDict(extra="forbid")  

    @classmethod
    def from_metric_names(
        cls,
        metric_names: List[str],
        retriever: "FAISSVectorStoreRetriever",
        Print_Results: bool = False,
        **kwargs: Any,
    ) -> "FAISSRetrievalEvaluator":
        metric_types = resolve_metrics(metric_names)
        metrics = [metric() for metric in metric_types]
        return cls(metrics=metrics, retriever=retriever, Print_Results=Print_Results, **kwargs)

    async def _aget_retrieved_ids_and_texts(
        self,
        query: str,
        mode: RetrievalEvalMode = RetrievalEvalMode.TEXT,
    ) -> Tuple[List[str], List[str]]:
        response = client.embeddings(prompt=query, model="mxbai-embed-large")
        query_embedding = response["embedding"]
        retrieved_docs = self.retriever._retrieve(query_embedding, top_k=15)
        
        # Conditionally print results
        if self.Print_Results:
            for doc in retrieved_docs:
                display_source_node(doc, source_length=1000)  # Directly use doc
        
        retrieved_ids = [doc.id_ for doc in retrieved_docs]  # doc, not doc.node
        retrieved_texts = [doc.text for doc in retrieved_docs]
        return retrieved_ids, retrieved_texts

    async def aevaluate(
        self,
        query: str,
        expected_ids: List[str],
        expected_texts: List[str] = [],
        mode: RetrievalEvalMode = RetrievalEvalMode.TEXT,
        **kwargs: Any,
    ) -> RetrievalEvalResult:
        retrieved_ids, retrieved_texts = await self._aget_retrieved_ids_and_texts(query, mode)
        metric_dict = {}
        
        for metric in self.metrics:
            # Call compute instead of evaluate
            result = metric.compute(
                query=query,
                expected_ids=expected_ids,
                retrieved_ids=retrieved_ids,
                expected_texts=expected_texts,
                retrieved_texts=retrieved_texts,
                **kwargs
            )
            metric_dict[metric.metric_name] = result  # Store the whole RetrievalMetricResult object
            print(f"{metric.metric_name}: {result.score}")  # Print each metric result
        
        # Return RetrievalEvalResult with all required fields
        return RetrievalEvalResult(
            query=query,
            retrieved_ids=retrieved_ids,
            retrieved_texts=retrieved_texts,  # Include retrieved texts
            expected_ids=expected_ids,         # Pass expected ids
            expected_texts=expected_texts,     # Include expected texts
            metric_dict=metric_dict            # Pass full RetrievalMetricResult objects
        )

# %%
nodes_embed = generate_embeddings(nodes, client, "mxbai-embed-large")
# Out:
# 100%|██████████| 2592/2592 [07:30<00:00,  5.76it/s]

# %% [markdown]
# ## 5.C. FAISS Retreival Evaluation

# %%
indexer = FaissIndexer()

indexer.build_index(nodes)  
faiss_index = indexer.get_index()

retriever = FAISSVectorStoreRetriever(faiss_index=indexer.get_index(), documents=nodes_embed)

metrics = ["hit_rate", "mrr", "precision", "recall", "ap", "ndcg"]
evaluator = FAISSRetrievalEvaluator.from_metric_names(
    metric_names=metrics,
    retriever=retriever,
    Print_Results=True
)


sample_id, sample_query = list(qa_dataset.queries.items())[1]
sample_expected = qa_dataset.relevant_docs[sample_id]

print("Sample Problem:")
print(f"sample id: {sample_id}, text: {sample_query}")
print(f"sample exp: {sample_expected}")

print("\nRetrieval results:")

result = await evaluator.aevaluate(
    query=sample_query,
    expected_ids=sample_expected,
)

print("\n")
print(result)
# Out:
# Sample Problem:
# sample id: 2dbe10ff-a3d8-49b1-8d9f-bf6642834340, text: What type of motor vehicles require special registration procedures, and where can they be registered?
# sample exp: ['a647ee3e-c2ec-4d75-8e0c-827748e58bcc']
#
# Retrieval results:
# **Node ID:** c4c26600-9dbd-457f-b4a2-03ac4b22434d<br>**Similarity:** 0.21263229846954346<br>**Text:** Registration of Motor Vehicle<br>
# **Node ID:** 4e6cb4e8-d94a-4500-aa34-79da965f66ed<br>**Similarity:** 0.22287940979003906<br>**Text:** Registration of Motor Vehicle
# Special Permit
# Vehicles exceeding the permissible dimension without special permit
# are not allowed to be operated on public highways.
# Additional Fees
# Any changes on Certificate of Registration or Driver’s License requires
# additional fees otherwise known as miscellaneous transaction.
# Use and Authority of Certificates of Registration
# A photocopy or the original CR are required to be preserved and carried
# in the car by the owner or driver of a motor vehicle<br>
# **Node ID:** 31ea2b44-5427-417a-aab2-2e41e9d4d101<br>**Similarity:** 0.26351630687713623<br>**Text:** 1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# • Requirements for New Registration
#
# • Requirements for Renewal of Registration
#       – for All Classifications
#
# • Motor Vehicle Registration Schedule
#
# • Motor Vehicle User’s Charge
#
# • Charges and Other Fees<br>
# **Node ID:** af1f67cd-dbeb-4925-9643-52809434b103<br>**Similarity:** 0.273284912109375<br>**Text:** 20
#
# 3. Optional Motor Vehicle Special Plate
# Three (3) alpha characters and two (2) numeric characters
#
# TSD 77
#
#   LAST DIGIT vehicle ending 7 must be
# registered in July
#
# 2nd TO THE LAST DIGIT OF THE PLATE
# NUMBER – refers to the week the vehicle
# must be registered. 2nd to the last or middle
# digit of 7 must register between 15th to 21st
# working day or 3rd week of July<br>
# **Node ID:** f1cad40a-af4b-4131-a052-252bdf1025bd<br>**Similarity:** 0.2910946011543274<br>**Text:** and technology;
# J.
# Registration - refers to the act of compliance to the documentary requirements,
# standards and procedures of Republic Act No. 11698 and these Rules in order for a
# vintage vehicle to be classified by the Land Transp01tation Office under a 'vintage
# vehicle' subclassification;
# k. Registered vintage vehicle - refers to a vintage vehicle registered with a 'vintage
# vehicle' subclassification that benefits from the exemptions and privileges under
# Republic Act No. I 1698 and these Rules~ -----_ ·' __ ·-··· __ --· . __
# I l r'. LA lfw f~ t£ ~; '( f~ ~-=-
# . t
# . >
# _ •
# · · ~
# •(,: :• ·,c
# , :• H
# •1 1 :1~
# , -..·F
# { I_ f'\ , • •
# I
# Implementing Rules and Regulations
# ~l n .
# .
# .
# 1'r Page 3 o" 26
# Republic Act No. 11698 - Vintage Vehicle Regulation Ac~
# 1.1 (
# JAN 3 0 202j
# I ) '.:
# ' l ~ \ IT' ([l ~ •""" Ii 'V ·:~ I i I ) '
# 1:-1~. Lfr,it ~ l {~_,~ ~-- y I
# . -------------- ----··~- -<br>
# **Node ID:** 87ff145f-1051-4bee-9474-e959b516cc40<br>**Similarity:** 0.29999953508377075<br>**Text:** .. 1·\
# I
# cr)tional Motor Vehicle Special Plates (OMVSP)
# ·
# Application Form
# . -
# Registered Owner Information:
# 0
# Name:
# Last Name
# First Name
# Middle Name
# Address:
# No.
# Street
# Province/City
# Zip Code
# Telephone/Mobile: No. :
# Email Address:
# ~
# OMVSP Requirements:
# ~
# 1.
# Duly accomplished OMVSP application form by the Owner or its duly Authorized Representative;
# 2.
# Certificate of Registration and official Receipt
# 3.
# Certificate of No Plate Issued;
# 4.
# Identification Card of the Authorized Representative;
# 5.
# Authorization Letter form the Owner (if applicable).
# -
# Motor Vehicle Information:
# [I]
# MV File No.:
# MVType:
# Chassis No. :
# Make:
# Engine! No. :
# OR No. :
# Year Model:
# CR No. :
# Plate Request
# List plate request in order of preference. First available preference will· be ordered. THE ORDER CANNOT BE CHANGED.
# CANCELLATION OF THIS ORDER WILL NOT ENTITLE YOU TO A REFUND .. ·
# • ANY THREE (ll Al.PH°A. COMBINATIUN +TRIPLE (l) NUMERIC EXCEPT 00
# ANY THREE (3) ALPHA...<br>
# **Node ID:** 223e9b01-3f15-42cd-8751-078791c50b66<br>**Similarity:** 0.302068829536438<br>**Text:** 2
#
#
# DOCUMENTARY REQUIREMENTS
#  FOR REGISTRATION
#
# I. INITIAL REGISTRATION OF MOTOR VEHICLE
# REQUIREMENTS
# WHERE TO SECURE
#
# General Requirements
#
# • Original Sales invoice
#
#
#
#
#
#
# • Original LTO copy or electronically
# transmitted appropriate insurance
# Certificate of Cover (Third Party Liability)
#
# • Original copy of Philippine National
# Police - Highway Patrol Group (PNP-
# HPG) Motor Vehicle (MV) Clearance
# Certificate and Special Bank Receipt
# (SBR)
#
# • Original Certificate of Stock Reported
# (CSR)
#
#
#
# • Payment Reference Number if payment
# is made through e-PAT
#
#
# - Accredited Manufacturer/
# Assembler/Importer
# /Rebuilder/ Dealer (MAIRD)
#
# - Accredited insurance
# companies by the Insurance
# Commission
#
# - PNP-HPG MV Clearance
# Division
#
#
#
#
# - Accredited Manufacturer/
# Assembler/Importer/Rebuild
# er/ Dealer (MAIRD)
#
# - LANDBANK Link.BizPortal
# Additional Requirements
# 1. Brand New Motorcycle with Sidecar
# (TC)
#
# • Original Affidavit of Attachment for
# sid...<br>
# **Node ID:** 67de5b2b-7d5a-4f2e-9ef2-c69361a4ab7f<br>**Similarity:** 0.3026140332221985<br>**Text:** CHECKLIST
# MANDATORY SUPPORTING DOCUMENTS
# FOR REGISTRATION TRANSACTIONS
# PRIVATE
# I.
# New Registration
# 1. lmpe>tted Mt>tor Vehicle
# 0 Original Invoice
# 0 Certification of Payment of
# taxes
# 0 CSR
# 0 CHPG clearance
# O Insurance Certificate of Cover
# 0 Actual inspection of Motor
# Vehicle & duly accomplished
# MVIR (stencils of motor &
# chassis nos. must be done on
# the space provided for)
# 0 Early Warning Device (EWD)
# 2. Locally Assemble/Rebuilt
# 0 CSR
# O Original Sales Invoice/Commercial
# Invoice of motor/chassis
# 0 CR & OR of motor/chassis,
# if taken from another motor
# vehicle
# O Certification of Payment of
# Taxes from Boe BOC & BIR, if
# motor/chassis are imported.
# 0 CHPG clearance
# 0 Insurance Certificate of Cover
# O Affidavit of Rebuilt of Owner/
# Mechanic
# O Actual Inspection of Motor
# Vehicle & duly accomplished
# MVIR (stencils of motor &
# chassis nos. must be done on
# the space provided for)
# O Early Warning Device (EWD)
# II.
# Renewal of MV Registration
# O Original copy of ...<br>
# **Node ID:** 68afede0-1696-4c83-be8b-e34b73d411a9<br>**Similarity:** 0.3033105134963989<br>**Text:** PERMIT & LICENSES
# Special-purpose Vehicle - Required Training
# School Service<br>
# **Node ID:** 4c0c3f9c-4673-428a-9b48-5b917047b19d<br>**Similarity:** 0.3039371967315674<br>**Text:** Registration of Motor Vehicle
# NUMBER PLATES
# PRIVATE
# FOR HIRE
# GOVERMENT
# DIPLOMATIC<br>
# **Node ID:** bc7de25c-d18d-4401-a86d-a27d7181638e<br>**Similarity:** 0.3083765506744385<br>**Text:** b. Modifications to brakes, suspension, axles, and running gear to improve efficienc) or
# safety;
# c. Use of carburetors, fuel injection systems or emission control devices not original to
# the vintage vehicle to improve efficiency, economy or environmental pe1formance:
# d. Lnstallation of a new, modem engine of the same brand or manufacture and of the same
# general specification (e.g. fuel type, piston displacement, number of cylinders, engine
# configuration or layout, etc.) as the engine original to the vintage vehicle or vehicles
# belonging to the same historic model line or automobile brand lineage as the vintage
# vehicle; and
# e. Installation of after-market accessories and equipment, such as radios, air-conditioning,
# and directional lights, to pennit the convenient or safe use of the vehicle, except those
# which are expressly prohibited by law to be used or attached in any motor vehicle such
# as, but not limited to, sirens, bells, horns, whistles, or other similar gadgets tha...<br>
# **Node ID:** ce4dcdc6-d8a0-4b91-b0a9-2058858ce44a<br>**Similarity:** 0.30905842781066895<br>**Text:** 2. RENEWAL OF MOTOR VEHICLE (MV) REGISTRATION
# Pursuant to Republic Act No. 4136 and other special laws, one of the core mandates of the LTD is to register roadworthy and emission
# compliant motor vehicles for the current year depending on the plate ending
# A. L TO District Offices (OOs) I Extension Offices (EOs) IE-Patrols
# B. For Tax Exempt (Diplomatic, Exempt Private): Authorized District Offices nearest to the Regional Office
# Office or Division:
# C. For Other Exempt Vehicles {OEVs): l TO DO I EO nearest to the Special Economic Zone
# 0 . For ' For-Hire" MVs in NCR: Public Utility Vehicle Registration Center (PUVRC) and Public Utility Vehicle
# Registration Extension Center (PUVREC)
# Classification:
# Simple Transaction
# G28 - Government to Business
# Type of Transaction:
# G2C · Government to Citizen
# G2G - Government to Government
# Who may avail:
# Motor vehicle owners
# CHECKLIST OF REQUIREMENTS
# General Requirements;
# I
# WHERE TO SECURE
# 1. One (1) clear photocopy of latest OR/CR (...<br>
# **Node ID:** e81bca5b-0e21-4955-af14-e5c406cf42b5<br>**Similarity:** 0.31441283226013184<br>**Text:** VIOLATIONS IN CONN ECTION WITH
# REPUBLIC ACT NO. 4136 AND THE JOINT ADMINISTRATIV2 ORDER NO. 2014-01
# RA.4136
# ]AO 2014-01
# Chapter II - REGISTRATION OF MOTOR A.
# DRIVING
# AN
# UNREGISTERED
# MOTOR
# VEHICLESSection 5. All motor vehicles and VEHICLE
# other vehicles must be registered.
# (a) no motor vehicle shall be used on or upon any
# public highway of the Philippines unless the same
# is properly registered for the current year 111
# accordance with the provisions of RA 4136.
# (b) Any registration of motor vehicles not renewed
# on or before the date fixed
# for
# different
# classifications as provided.
# -Operating
# a
# motor
# unregistered/improperly
# with iiwalid registration
# vehicle
# which
# is
# registered/ delinquent or
# This includes driving with an improperly registered motor
# vehicle or a motor vehicle with expired, revoked, suspended or
# invalid
# registration, unregistered
# or fake substirute or
# replacement engine, engine block or chassis.
# -Operating a motor vehicle with unregiste...<br>
# **Node ID:** e47edbb5-3590-4de6-854b-bfbe791875ba<br>**Similarity:** 0.31452977657318115<br>**Text:** under a vintage vehicle subclassification as stated in the preceding
# sections of this Rule shall not be mandatory for eligible vintage vehicles.
# Moreover, an owner of a registered vintage vehicle with a regish·ation that has expired
# or is about to expire may opt to revert to a regular annual regish·ation, which shall subject the
# vehicle to all laws and regulations governing the registration and use of motor vehicles in
# general, including all emission, safety, roadworthiness and other standards.
# U.F'. LAW CENTER
# I
# OFFICE ol lht ~AllONAl ,;DMIN l ~TRAH'/£ REGISTER.
# Implementing Rules and Regulations
# Republic Act No. 11698 - Vintage Vehicle Regulation Act
# Adm1n1sua1" ~ Ru t ~• ~nd Re9ul!l!Ons
# I.
# ~~e 17 of 26
# I
# JAN 3 0 2023
# l ~ I
# \
# \
# r~-· rf' llZ· , -,~
# · 1 'i);''
# .u. J-f.·'h LC.1 .J.
# l L
# T t. E __ J.1 ' {..'Q
# ;· \
# .
# '
# ------ ___
# ;: __ .::..-
# . . -·---<br>
# **Node ID:** 2ed1cd47-e757-4b80-aa62-57b89252d263<br>**Similarity:** 0.3153288960456848<br>**Text:** 3. Original and photocopy of any valid government issued identification document of
# the registered owner with photo and signature;
# 4. Philippine National Police (PNP) - Highway Patrol Group (HPG) Motor Vehicle
# Clearance Certificate;
# 5. Proof of electronically transmitted appropriate Third Party Liability (TPL)
# Insurance Certificate of Cover (COC);
# 6. Certificate of title issued by the country of origin or commercial invoice of motor
# vehicle; and
# 7. Duly accomplished L TO application form for registration as a vintage vehicle under
# Republic Act No. 11698 (attached as "Appendix 1 ').
# b. Motor vehicles that have current or previous records of annual registration with the
# LTO (including those vehicles that were registered but are placed on storage) may be
# specially registered under a vintage vehicle subclassification to avail any exemption or
# privilege under these Rules. This transaction requires the issuance of a new Certific te
# of Registration.
# The following documentary...<br>
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
#
#
# Query: What type of motor vehicles require special registration procedures, and where can they be registered?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}

# %%
eval_results = await evaluator.aevaluate_dataset(qa_dataset)

def display_results(name, eval_results):
    """Display results from evaluate."""

    metric_dicts = []
    for eval_result in eval_results:
        metric_dict = eval_result.metric_vals_dict
        metric_dicts.append(metric_dict)

    full_df = pd.DataFrame(metric_dicts)

    columns = {
        "retrievers": [name],
        **{k: [full_df[k].mean()] for k in metrics},
    }

    metric_df = pd.DataFrame(columns)

    return metric_df


display_results("top-2 eval", eval_results)
# Out:
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.125
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.125
# ndcg: 0.31546487678572877
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.125
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.125
# ndcg: 0.31546487678572877
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.09090909090909091
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.09090909090909091
# ndcg: 0.27894294565112987
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.09090909090909091
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.09090909090909091
# ndcg: 0.27894294565112987
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.08333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.08333333333333333
# ndcg: 0.27023815442731974
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.125
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.125
# ndcg: 0.31546487678572877
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.09090909090909091
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.09090909090909091
# ndcg: 0.27894294565112987
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# ...
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.125
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.125
# ndcg: 0.31546487678572877
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.125
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.125
# ndcg: 0.31546487678572877
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.08333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.08333333333333333
# ndcg: 0.27023815442731974
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
#    retrievers  hit_rate       mrr  precision    recall        ap      ndcg
# 0  top-2 eval  0.420718  0.289973   0.028048  0.420718  0.289973  0.320798

# %%
#indexing
index = FaissIndexer()
index.build_index(nodes_embed)
faiss_index = index.get_index()

faiss_retriever = FAISSVectorStoreRetriever(faiss_index=faiss_index,documents=nodes_embed)

# %% [markdown]
# ## 5.D Sparse Embedding via BM25

# %%
bm25_retriever = BM25Retriever.from_defaults(
   nodes=nodes,
   similarity_top_k=5,
   stemmer=Stemmer.Stemmer("english"),
   language="english",
)

# %% [markdown]
# ## 5.E Hybrid Retrieval via Reciprocal Rank

# %%
def hybrid_embedding(results: dict, top_k: int):
    x = QueryFusionRetriever
    ranked_results = QueryFusionRetriever._reciprocal_rerank_fusion(x, results)
    return ranked_results[:top_k]

# %% [markdown]
# ## 5.F Hybrid Retrieval Evaluator

# %%
from typing import List, Tuple, Any, Dict
from pydantic import Field, ConfigDict
from llama_index.core.evaluation.retrieval.base import (
    BaseRetrievalEvaluator,
    RetrievalEvalMode,
    RetrievalEvalResult
)
from llama_index.core.evaluation.retrieval.metrics import resolve_metrics
from llama_index.core.response.notebook_utils import display_source_node

class HybridRetrievalEvaluator(BaseRetrievalEvaluator):
    faiss_retriever: "FAISSVectorStoreRetriever" = Field(..., description="FAISS Retriever instance")
    bm25_retriever: "BM25Retriever" = Field(..., description="BM25 Retriever instance")
    Print_Results: bool = Field(default=False, description="Whether to print retrieved results")

    model_config = ConfigDict(extra="forbid")  

    @classmethod
    def from_metric_names(
        cls,
        metric_names: List[str],
        faiss_retriever: "FAISSVectorStoreRetriever",
        bm25_retriever: "BM25Retriever",
        Print_Results: bool = False,
        **kwargs: Any,
    ) -> "HybridRetrievalEvaluator":
        metric_types = resolve_metrics(metric_names)
        metrics = [metric() for metric in metric_types]
        return cls(metrics=metrics, faiss_retriever=faiss_retriever, bm25_retriever=bm25_retriever, Print_Results=Print_Results, **kwargs)

    async def _aget_retrieved_ids_and_texts(
        self,
        query: str,
        mode: RetrievalEvalMode = RetrievalEvalMode.TEXT,
        top_k: int = 15
    ) -> Tuple[List[str], List[str]]:
        response = client.embeddings(prompt=query, model="mxbai-embed-large")
        query_embedding = response["embedding"]

        # FAISS retrieval
        faiss_docs = self.faiss_retriever._retrieve(query_embedding, top_k=top_k)

        # BM25 retrieval
        bm25_docs = self.bm25_retriever.retrieve(query)

        # Combine results
        results = {'faiss': faiss_docs, 'bm25': bm25_docs}
        ranked_results = QueryFusionRetriever._reciprocal_rerank_fusion(None, results)
        ranked_results = ranked_results[:top_k]

        # Optionally display results
        if self.Print_Results:
            for doc in ranked_results:
                display_source_node(doc, source_length=1000)

        retrieved_ids = [doc.id_ for doc in ranked_results]
        retrieved_texts = [doc.text for doc in ranked_results]
        return retrieved_ids, retrieved_texts

    async def aevaluate(
        self,
        query: str,
        expected_ids: List[str],
        expected_texts: List[str] = [],
        mode: RetrievalEvalMode = RetrievalEvalMode.TEXT,
        **kwargs: Any,
    ) -> RetrievalEvalResult:
        retrieved_ids, retrieved_texts = await self._aget_retrieved_ids_and_texts(query, mode)
        metric_dict = {}
        
        for metric in self.metrics:
            # Call compute instead of evaluate
            result = metric.compute(
                query=query,
                expected_ids=expected_ids,
                retrieved_ids=retrieved_ids,
                expected_texts=expected_texts,
                retrieved_texts=retrieved_texts,
                **kwargs
            )
            metric_dict[metric.metric_name] = result  # Store the whole RetrievalMetricResult object
            print(f"{metric.metric_name}: {result.score}")  # Print each metric result
        
        # Return RetrievalEvalResult with all required fields
        return RetrievalEvalResult(
            query=query,
            retrieved_ids=retrieved_ids,
            retrieved_texts=retrieved_texts,
            expected_ids=expected_ids,
            expected_texts=expected_texts,
            metric_dict=metric_dict
        )

# %% [markdown]
# ## 5.G BM25 Retreival Evaluation

# %%
evaluator = HybridRetrievalEvaluator.from_metric_names(
    metric_names=metrics,
    faiss_retriever=faiss_retriever,
    bm25_retriever=bm25_retriever,
    Print_Results=True  # Toggle as needed
)

sample_id, sample_query = list(qa_dataset.queries.items())[1]
sample_expected = qa_dataset.relevant_docs[sample_id]

print("Sample Problem:")
print(f"sample id: {sample_id}, text: {sample_query}")
print(f"sample exp: {sample_expected}")

print("\nRetrieval results:")

result = await evaluator.aevaluate(
    query=sample_query,
    expected_ids=sample_expected
)

print("\n")
print(result)
# Out:
# Sample Problem:
# sample id: 2dbe10ff-a3d8-49b1-8d9f-bf6642834340, text: What type of motor vehicles require special registration procedures, and where can they be registered?
# sample exp: ['a647ee3e-c2ec-4d75-8e0c-827748e58bcc']
#
# Retrieval results:
# **Node ID:** ce4dcdc6-d8a0-4b91-b0a9-2058858ce44a<br>**Similarity:** 0.032266458495966696<br>**Text:** 2. RENEWAL OF MOTOR VEHICLE (MV) REGISTRATION
# Pursuant to Republic Act No. 4136 and other special laws, one of the core mandates of the LTD is to register roadworthy and emission
# compliant motor vehicles for the current year depending on the plate ending
# A. L TO District Offices (OOs) I Extension Offices (EOs) IE-Patrols
# B. For Tax Exempt (Diplomatic, Exempt Private): Authorized District Offices nearest to the Regional Office
# Office or Division:
# C. For Other Exempt Vehicles {OEVs): l TO DO I EO nearest to the Special Economic Zone
# 0 . For ' For-Hire" MVs in NCR: Public Utility Vehicle Registration Center (PUVRC) and Public Utility Vehicle
# Registration Extension Center (PUVREC)
# Classification:
# Simple Transaction
# G28 - Government to Business
# Type of Transaction:
# G2C · Government to Citizen
# G2G - Government to Government
# Who may avail:
# Motor vehicle owners
# CHECKLIST OF REQUIREMENTS
# General Requirements;
# I
# WHERE TO SECURE
# 1. One (1) clear photocopy of latest OR/CR (...<br>
# **Node ID:** 2ed1cd47-e757-4b80-aa62-57b89252d263<br>**Similarity:** 0.016666666666666666<br>**Text:** 3. Original and photocopy of any valid government issued identification document of
# the registered owner with photo and signature;
# 4. Philippine National Police (PNP) - Highway Patrol Group (HPG) Motor Vehicle
# Clearance Certificate;
# 5. Proof of electronically transmitted appropriate Third Party Liability (TPL)
# Insurance Certificate of Cover (COC);
# 6. Certificate of title issued by the country of origin or commercial invoice of motor
# vehicle; and
# 7. Duly accomplished L TO application form for registration as a vintage vehicle under
# Republic Act No. 11698 (attached as "Appendix 1 ').
# b. Motor vehicles that have current or previous records of annual registration with the
# LTO (including those vehicles that were registered but are placed on storage) may be
# specially registered under a vintage vehicle subclassification to avail any exemption or
# privilege under these Rules. This transaction requires the issuance of a new Certific te
# of Registration.
# The following documentary...<br>
# **Node ID:** 8c86b879-de45-4059-af0a-bebcb81a183b<br>**Similarity:** 0.016666666666666666<br>**Text:** Office or Division:
# Classification:
# Type of Transaction:
# Who may avail:
# WHERE TO SECURE
# LTO
# LTO
# New Registration Unit, District Office, Extension Office
# Simple
# 9. REQUEST FOR CONFIRMATION OF MOTOR VEHICLE REGISTRATION
# Procedure for miscellaneous transaction where the subject motor vehicle is initially registered at a New Registration Unit (NRU) /District Office (DO)/ Extension Office
# (EO) located in a different Region to that of the transacting DO/EO.
# 2. Other applicable documents depending on the type of  miscellaneous motor vehicle
# transaction
# G2G - Government to Government
# Records Officer of the transacting NRU/DO/EO
# CHECKLIST OF REQUIREMENTS
# 1. Request for Confirmation Form
# REQUEST FOR CONFIRMATION OF MOTOR VEHICLE REGISTRATION
# 193<br>
# **Node ID:** e47edbb5-3590-4de6-854b-bfbe791875ba<br>**Similarity:** 0.01639344262295082<br>**Text:** under a vintage vehicle subclassification as stated in the preceding
# sections of this Rule shall not be mandatory for eligible vintage vehicles.
# Moreover, an owner of a registered vintage vehicle with a regish·ation that has expired
# or is about to expire may opt to revert to a regular annual regish·ation, which shall subject the
# vehicle to all laws and regulations governing the registration and use of motor vehicles in
# general, including all emission, safety, roadworthiness and other standards.
# U.F'. LAW CENTER
# I
# OFFICE ol lht ~AllONAl ,;DMIN l ~TRAH'/£ REGISTER.
# Implementing Rules and Regulations
# Republic Act No. 11698 - Vintage Vehicle Regulation Act
# Adm1n1sua1" ~ Ru t ~• ~nd Re9ul!l!Ons
# I.
# ~~e 17 of 26
# I
# JAN 3 0 2023
# l ~ I
# \
# \
# r~-· rf' llZ· , -,~
# · 1 'i);''
# .u. J-f.·'h LC.1 .J.
# l L
# T t. E __ J.1 ' {..'Q
# ;· \
# .
# '
# ------ ___
# ;: __ .::..-
# . . -·---<br>
# **Node ID:** e81bca5b-0e21-4955-af14-e5c406cf42b5<br>**Similarity:** 0.016129032258064516<br>**Text:** VIOLATIONS IN CONN ECTION WITH
# REPUBLIC ACT NO. 4136 AND THE JOINT ADMINISTRATIV2 ORDER NO. 2014-01
# RA.4136
# ]AO 2014-01
# Chapter II - REGISTRATION OF MOTOR A.
# DRIVING
# AN
# UNREGISTERED
# MOTOR
# VEHICLESSection 5. All motor vehicles and VEHICLE
# other vehicles must be registered.
# (a) no motor vehicle shall be used on or upon any
# public highway of the Philippines unless the same
# is properly registered for the current year 111
# accordance with the provisions of RA 4136.
# (b) Any registration of motor vehicles not renewed
# on or before the date fixed
# for
# different
# classifications as provided.
# -Operating
# a
# motor
# unregistered/improperly
# with iiwalid registration
# vehicle
# which
# is
# registered/ delinquent or
# This includes driving with an improperly registered motor
# vehicle or a motor vehicle with expired, revoked, suspended or
# invalid
# registration, unregistered
# or fake substirute or
# replacement engine, engine block or chassis.
# -Operating a motor vehicle with unregiste...<br>
# **Node ID:** 311f52bd-e806-440f-a52d-baa27246b917<br>**Similarity:** 0.016129032258064516<br>**Text:** problem of depleting alpha-numeric combinations,
# the letter “I”, “O”, and “Q” shall have a different font to distinguish it from
# zero (0).
#
# B.
# Nature and Coverage of Special Plates
#
# The OMVSP is considered as a regular MV plate.  As such it shall be
# issued in pairs and it shall be permanently assigned to a specified motor
# vehicle during its lifetime.  Moreover, it is optional and shall be issued only
# upon direct application by the owner of a brand new private motor vehicle
# which is for initial or first-time registration with the LTO.  The MV’s
# covered herein are as follows:
#
# a.
# Cars
# b.
# Sports Utility Vehicles (SUV)
# c.
# Asian Utility Vehicles (AUV)
# d.
# Sports Pick-up
# e.
# Commuter Vans
#
# The following MV types shall be excluded from the coverage of those
# which can be issued special plates:
#
# a.
# Public Utility Vehicles
# b.
# Cargo Trucks (private/for hire)
# c.
# Service
# Vehicle
# (hotel
# limousines,
# tourist
# vehicles,    rent-a-car, ambulance and funeral
# hearse)...<br>
# **Node ID:** 44576740-d648-4d0f-9961-f94187623d92<br>**Similarity:** 0.015873015873015872<br>**Text:** coordinate with the present owners and the PSG, in applicable cases, to validate the truthfulness
# of the information submitted.
# Section 3. Valuation for Taliffs, Import Duties and Other Taxes.
# The Bureau of Customs (BOC), for purposes of valuation for tariffs, import duties and
# other taxes of impo1ted vintage vehicle, shall differentiate concours, RESTOMOD and for
# restoration vintage vehicle, subject to the provisions of Sections 700 to 707 of Republic Act
# No. 10863, otherwise known as the Customs Modernization and Tariff Act. Restoration mode
# and for restoration shall have a lower valuation against concours for the same make and model
# of vintage vehicle.
# RULE VI
# PROCEDURES FOR REGISTRATION
# Section 1. Creation of a Registration Subclassification for Vintage Vehicles; Applicable
# Motor Vehicle User's Charge.
# In consonance with Section 7 of Republic Act No. 4136, as amended by Batas
# Pambansa Blg. 74, a 'Vintage Vehicle' subclassification is hereby created under the Privat...<br>
# **Node ID:** bc7de25c-d18d-4401-a86d-a27d7181638e<br>**Similarity:** 0.015625<br>**Text:** b. Modifications to brakes, suspension, axles, and running gear to improve efficienc) or
# safety;
# c. Use of carburetors, fuel injection systems or emission control devices not original to
# the vintage vehicle to improve efficiency, economy or environmental pe1formance:
# d. Lnstallation of a new, modem engine of the same brand or manufacture and of the same
# general specification (e.g. fuel type, piston displacement, number of cylinders, engine
# configuration or layout, etc.) as the engine original to the vintage vehicle or vehicles
# belonging to the same historic model line or automobile brand lineage as the vintage
# vehicle; and
# e. Installation of after-market accessories and equipment, such as radios, air-conditioning,
# and directional lights, to pennit the convenient or safe use of the vehicle, except those
# which are expressly prohibited by law to be used or attached in any motor vehicle such
# as, but not limited to, sirens, bells, horns, whistles, or other similar gadgets tha...<br>
# **Node ID:** 42aa82b1-49e2-44d0-b8f9-8822e3740450<br>**Similarity:** 0.015625<br>**Text:** WHERE TO SECURE
# Registered Motor Vehicle owner
# F. For “For-Hire” MVs in NCR: Public Utility Vehicle Registration Center (PUVRC) and Public Utility Vehicle Registration Extension
# Center (PUVREC)
# Classification:
# Simple Transaction
# Type of Transaction:
# G2B - Government to Business
# G2C - Government to Citizen
# G2G - Government to Government
# Office or Division:
# 2. VEHICLE ENCODING/LINKING
# The process wherein the portal account of a client is linked to the record of his/her motor vehicle.
# B. LTO District Offices (DOs) / Extension Offices (EOs) / E-Patrols
# C. For Tax Exempt (Diplomatic): Authorized District Offices nearest to the Regional Office
# E. For Other Exempt Vehicles (OEVs): LTO DO / EO nearest to the Special Economic Zone
# A. Registration Section, Central Office (Government, Diplomatic, Vehicles owned by Government Employees/OFW, or Other
# Vehicles as may be deemed necessary)
# D. For Tax Exempt (Exempt Private or Government) and for Stolen and Recovered Vehicles: Authorized Distri...<br>
# **Node ID:** 4c0c3f9c-4673-428a-9b48-5b917047b19d<br>**Similarity:** 0.015384615384615385<br>**Text:** Registration of Motor Vehicle
# NUMBER PLATES
# PRIVATE
# FOR HIRE
# GOVERMENT
# DIPLOMATIC<br>
# **Node ID:** 68afede0-1696-4c83-be8b-e34b73d411a9<br>**Similarity:** 0.015151515151515152<br>**Text:** PERMIT & LICENSES
# Special-purpose Vehicle - Required Training
# School Service<br>
# **Node ID:** 67de5b2b-7d5a-4f2e-9ef2-c69361a4ab7f<br>**Similarity:** 0.014925373134328358<br>**Text:** CHECKLIST
# MANDATORY SUPPORTING DOCUMENTS
# FOR REGISTRATION TRANSACTIONS
# PRIVATE
# I.
# New Registration
# 1. lmpe>tted Mt>tor Vehicle
# 0 Original Invoice
# 0 Certification of Payment of
# taxes
# 0 CSR
# 0 CHPG clearance
# O Insurance Certificate of Cover
# 0 Actual inspection of Motor
# Vehicle & duly accomplished
# MVIR (stencils of motor &
# chassis nos. must be done on
# the space provided for)
# 0 Early Warning Device (EWD)
# 2. Locally Assemble/Rebuilt
# 0 CSR
# O Original Sales Invoice/Commercial
# Invoice of motor/chassis
# 0 CR & OR of motor/chassis,
# if taken from another motor
# vehicle
# O Certification of Payment of
# Taxes from Boe BOC & BIR, if
# motor/chassis are imported.
# 0 CHPG clearance
# 0 Insurance Certificate of Cover
# O Affidavit of Rebuilt of Owner/
# Mechanic
# O Actual Inspection of Motor
# Vehicle & duly accomplished
# MVIR (stencils of motor &
# chassis nos. must be done on
# the space provided for)
# O Early Warning Device (EWD)
# II.
# Renewal of MV Registration
# O Original copy of ...<br>
# **Node ID:** 223e9b01-3f15-42cd-8751-078791c50b66<br>**Similarity:** 0.014705882352941176<br>**Text:** 2
#
#
# DOCUMENTARY REQUIREMENTS
#  FOR REGISTRATION
#
# I. INITIAL REGISTRATION OF MOTOR VEHICLE
# REQUIREMENTS
# WHERE TO SECURE
#
# General Requirements
#
# • Original Sales invoice
#
#
#
#
#
#
# • Original LTO copy or electronically
# transmitted appropriate insurance
# Certificate of Cover (Third Party Liability)
#
# • Original copy of Philippine National
# Police - Highway Patrol Group (PNP-
# HPG) Motor Vehicle (MV) Clearance
# Certificate and Special Bank Receipt
# (SBR)
#
# • Original Certificate of Stock Reported
# (CSR)
#
#
#
# • Payment Reference Number if payment
# is made through e-PAT
#
#
# - Accredited Manufacturer/
# Assembler/Importer
# /Rebuilder/ Dealer (MAIRD)
#
# - Accredited insurance
# companies by the Insurance
# Commission
#
# - PNP-HPG MV Clearance
# Division
#
#
#
#
# - Accredited Manufacturer/
# Assembler/Importer/Rebuild
# er/ Dealer (MAIRD)
#
# - LANDBANK Link.BizPortal
# Additional Requirements
# 1. Brand New Motorcycle with Sidecar
# (TC)
#
# • Original Affidavit of Attachment for
# sid...<br>
# **Node ID:** 87ff145f-1051-4bee-9474-e959b516cc40<br>**Similarity:** 0.014492753623188406<br>**Text:** .. 1·\
# I
# cr)tional Motor Vehicle Special Plates (OMVSP)
# ·
# Application Form
# . -
# Registered Owner Information:
# 0
# Name:
# Last Name
# First Name
# Middle Name
# Address:
# No.
# Street
# Province/City
# Zip Code
# Telephone/Mobile: No. :
# Email Address:
# ~
# OMVSP Requirements:
# ~
# 1.
# Duly accomplished OMVSP application form by the Owner or its duly Authorized Representative;
# 2.
# Certificate of Registration and official Receipt
# 3.
# Certificate of No Plate Issued;
# 4.
# Identification Card of the Authorized Representative;
# 5.
# Authorization Letter form the Owner (if applicable).
# -
# Motor Vehicle Information:
# [I]
# MV File No.:
# MVType:
# Chassis No. :
# Make:
# Engine! No. :
# OR No. :
# Year Model:
# CR No. :
# Plate Request
# List plate request in order of preference. First available preference will· be ordered. THE ORDER CANNOT BE CHANGED.
# CANCELLATION OF THIS ORDER WILL NOT ENTITLE YOU TO A REFUND .. ·
# • ANY THREE (ll Al.PH°A. COMBINATIUN +TRIPLE (l) NUMERIC EXCEPT 00
# ANY THREE (3) ALPHA...<br>
# **Node ID:** f1cad40a-af4b-4131-a052-252bdf1025bd<br>**Similarity:** 0.014285714285714285<br>**Text:** and technology;
# J.
# Registration - refers to the act of compliance to the documentary requirements,
# standards and procedures of Republic Act No. 11698 and these Rules in order for a
# vintage vehicle to be classified by the Land Transp01tation Office under a 'vintage
# vehicle' subclassification;
# k. Registered vintage vehicle - refers to a vintage vehicle registered with a 'vintage
# vehicle' subclassification that benefits from the exemptions and privileges under
# Republic Act No. I 1698 and these Rules~ -----_ ·' __ ·-··· __ --· . __
# I l r'. LA lfw f~ t£ ~; '( f~ ~-=-
# . t
# . >
# _ •
# · · ~
# •(,: :• ·,c
# , :• H
# •1 1 :1~
# , -..·F
# { I_ f'\ , • •
# I
# Implementing Rules and Regulations
# ~l n .
# .
# .
# 1'r Page 3 o" 26
# Republic Act No. 11698 - Vintage Vehicle Regulation Ac~
# 1.1 (
# JAN 3 0 202j
# I ) '.:
# ' l ~ \ IT' ([l ~ •""" Ii 'V ·:~ I i I ) '
# 1:-1~. Lfr,it ~ l {~_,~ ~-- y I
# . -------------- ----··~- -<br>
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
#
#
# Query: What type of motor vehicles require special registration procedures, and where can they be registered?
# Metrics: {'hit_rate': 0.0, 'mrr': 0.0, 'precision': 0.0, 'recall': 0.0, 'ap': 0.0, 'ndcg': 0.0}

# %%
evaluator = HybridRetrievalEvaluator.from_metric_names(
    metric_names=metrics,
    faiss_retriever=faiss_retriever,
    bm25_retriever=bm25_retriever,
    Print_Results=False  
)

eval_results = await evaluator.aevaluate_dataset(qa_dataset)

def display_results(name, eval_results):
    """Display results from evaluate."""

    metric_dicts = []
    for eval_result in eval_results:
        metric_dict = eval_result.metric_vals_dict
        metric_dicts.append(metric_dict)

    full_df = pd.DataFrame(metric_dicts)

    columns = {
        "retrievers": [name],
        **{k: [full_df[k].mean()] for k in metrics},
    }

    metric_df = pd.DataFrame(columns)

    return metric_df

display_results("top-2 eval", eval_results)
# Out:
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.08333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.08333333333333333
# ndcg: 0.27023815442731974
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.08333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.08333333333333333
# ndcg: 0.27023815442731974
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.08333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.08333333333333333
# ndcg: 0.27023815442731974
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.09090909090909091
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.09090909090909091
# ndcg: 0.27894294565112987
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.09090909090909091
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.09090909090909091
# ndcg: 0.27894294565112987
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.14285714285714285
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.14285714285714285
# ndcg: 0.3333333333333333
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.06666666666666667
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.06666666666666667
# ndcg: 0.25
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.16666666666666666
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.16666666666666666
# ndcg: 0.3562071871080222
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# ...
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1
# ndcg: 0.2890648263178879
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 1.0
# mrr: 0.125
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.125
# ndcg: 0.31546487678572877
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.08333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.08333333333333333
# ndcg: 0.27023815442731974
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.2
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.2
# ndcg: 0.38685280723454163
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07142857142857142
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07142857142857142
# ndcg: 0.2559580248098155
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.25
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.25
# ndcg: 0.43067655807339306
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.07692307692307693
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.07692307692307693
# ndcg: 0.26264953503719357
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.1111111111111111
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.1111111111111111
# ndcg: 0.3010299956639812
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.5
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.5
# ndcg: 0.6309297535714575
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 1.0
# precision: 0.06666666666666667
# recall: 1.0
# ap: 1.0
# ndcg: 1.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 1.0
# mrr: 0.3333333333333333
# precision: 0.06666666666666667
# recall: 1.0
# ap: 0.3333333333333333
# ndcg: 0.5
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
# hit_rate: 0.0
# mrr: 0.0
# precision: 0.0
# recall: 0.0
# ap: 0.0
# ndcg: 0.0
#    retrievers  hit_rate       mrr  precision    recall        ap      ndcg
# 0  top-2 eval  0.409722  0.212541   0.027315  0.409722  0.212541  0.260592

# %% [markdown]
# # 6. Post Retrieval

# %% [markdown]
# ## 6.A Summarization

# %%
def summarize_each_chunk(nodes, client, query, model="llama3.3", parent=False):
    if parent:
        chunks = [doc.text for doc in nodes]
    else:
        chunks = [doc.node.text for doc in nodes]
    summaries = []
    
    for i, chunk in enumerate(chunks):
        prompt = f"""
        Summarize the following text in one concise paragraph, focusing on key points relevant to the query: "{query}".
        
        - Emphasize information directly related to the query.
        - Exclude unrelated, redundant, or speculative details.
        - Do NOT introduce new information or answer the query itself. 
        
        Text:
        {chunk}
        
        Summary:
        """
        
        response = client.generate(model=model, prompt=prompt)
        summary = response['response'].strip()
        summaries.append(summary)

    return summaries

# %% [markdown]
# # 6.B Evaluation Generation

# %%
def generate_response_with_notice(summaries, query, client, model="llama3.3"):
    # Combine summaries into context block
    context = "\n".join(summaries)
    
    # Create prompt to answer based on summarized text
    prompt = f"""
    Use the following summarized information to answer the query accurately and concisely. 
    DO NOT USE BACKGROUND KNOWLEDGE OUTSIDE THE CONTEXT PROVIDED.
    If the information is not sufficient to fully address the query, respond ONLY with:
    "The available information is insufficient to provide a complete answer to this query."

    Summarized Context:
    {context}
    
    Query:
    {query}
    
    Response:
    """
    
    # Send the prompt to Ollama
    response = client.generate(
        model=model,
        prompt=prompt
    )
    
    return response['response'].strip()

# %% [markdown]
# # 7. Querying

# %% [markdown]
# ## 7.A Query Transforms

# %% [markdown]
# # 8. Query Generation

# %%
docstore = {}

# Store documents using full metadata as the key
for doc in documents:
    key = tuple(doc.metadata.items())  # Convert metadata to tuple for hashable key
    docstore[key] = doc

# %%
def get_document_by_chunk_metadata(chunk_node):
    # Convert chunk metadata to tuple for matching
    metadata_key = tuple(chunk_node.metadata.items())

    # Retrieve document from docstore
    document = docstore.get(metadata_key)
    return document

# %%
def remove_duplicate_documents(doc_list):
    seen_ids = set()
    unique_docs = []

    for doc in doc_list:
        if doc.doc_id not in seen_ids:
            seen_ids.add(doc.doc_id)
            unique_docs.append(doc)

    return unique_docs

# %%
def gen_query(query, top_k, client, mode='dense', summary=False, model="llama3.3", chunks_only=False):
    response = client.embeddings(prompt=query, model="mxbai-embed-large")
    query_embedding = response["embedding"]

    top_k_docs = faiss_retriever._retrieve(query_embedding, top_k=top_k)

    bm25_retriever = BM25Retriever.from_defaults(
    nodes=nodes,
    similarity_top_k=top_k,
    stemmer=Stemmer.Stemmer("english"),
    language="english",
    )
    retrieved_nodes = bm25_retriever.retrieve(query)

    results = {'faiss': top_k_docs, 'bm25':retrieved_nodes}
    ranked_results = hybrid_embedding(results, top_k=top_k)

    if mode == 'dense':
        print('using FAISS')
        ans_nodes =top_k_docs
    elif mode == 'sparse':
        print('using BM25')
        ans_nodes = retrieved_nodes
    else:
        print('using Hybrid')
        ans_nodes = ranked_results

    parent_flag = True
    context = set([get_document_by_chunk_metadata(docs).text for docs in ans_nodes])
    if chunks_only:
        parent_flag = False
        print('using chunks only')
        context = [docs.node.text for docs in ans_nodes]
        
    if summary:
        print('using summaries')
        context_nodes = remove_duplicate_documents([get_document_by_chunk_metadata(docs) for docs in ans_nodes])

        if chunks_only:
            context_nodes=ans_nodes
        summaries = summarize_each_chunk(context_nodes, client, model='llama3.3', query=query,parent=parent_flag)
        context = summaries

    answer = generate_response_with_notice(context, query, client, model=model)

    # Format the references
    references = []
    for i, doc in enumerate(ranked_results[:top_k], start=1):
        metadata = doc.metadata
        source_info = f"Source {i}: {metadata['title']} (Page {metadata['page']}, Folder: {metadata['folder']})"
        references.append(source_info)

    return answer, "\n".join(references), "\n".join(context)

# %% [markdown]
# # 9. TDC Exam Evaluation

# %%
# Generate prompts dynamically
def generate_prompt(row):
    options = []
    for choice in ['A', 'B', 'C', 'D', 'E']:
        # Check for NaN or blank values
        if pd.notna(row[choice]) and row[choice] != '':
            options.append(f"{choice}. {row[choice]}")
    
    # Construct the prompt with few-shot examples
    prompt = f"\nActual Question: {row['Question']}\n" + "\n".join(options)
    prompt += "\nPlease answer only in letters and put them inside a bracket '[]'. If the question contains the statement 'Check all that apply' then add comma separator if there are multiple answers ONLY IF ALLOWED."
    
    return prompt

# %%
# Load the Excel file
file_path = '/mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/LTO_EXAM.csv'
df = pd.read_csv(file_path)
df['Prompt'] = df.apply(generate_prompt, axis=1)
display(df.head())
# Out:
#                                             Question  \
# 0  What should you do in case your vehicle breaks...
# 1   What will happen when your front tire blows out?
# 2  What should you do when an ambulance comes up ...
# 3  While driving the hood of your car lifts up bl...
# 4  In case of an accident, the first duty of the ...
#
#                                                    A  \
# 0                           Open your trunk and hood
# 1  The back end will sway towards the side of the...
# 2                            Stop as soon as you can
# 3  Look through the gap underneath the hood or ou...
# 4  pick-up the injured person and take him to the...
#
#                                                    B  \
# 0  Stand on the expressway and flag down passing ...
# 1       The back end will sway away from the blowout
# 2  Maintain your speed, let the ambulance driver ...
# 3         Brake suddenly so you don't leave the road
# 4        report the accident to the nearest hospital
#
#                                                    C  \
# 0  Call for help using a mobile phone or an expre...
# 1  The front end will pull towards the side of th...
# 2      Speed up so that you don't hold the ambulance
# 3  Pull to the side of the road and refasten the ...
# 4  report the accident to the nearest police station
#
#                                                    D  \
# 0               Park as far to the right as possible
# 1  The front end will pull to the opposite side o...
# 2  Pull over to the right and slow down or even s...
# 3  Turn your headlights on and look out of the si...
# 4                                                NaN
#
#                                   E      Answer  \
# 0  Put your hazard warning light on  A, C, D, E
# 1                               NaN           C
# 2                               NaN           D
# 3                               NaN         A,C
# 4                               NaN           A
#
#                                               Prompt
# 0  \nActual Question: What should you do in case ...
# 1  \nActual Question: What will happen when your ...
# 2  \nActual Question: What should you do when an ...
# 3  \nActual Question: While driving the hood of y...
# 4  \nActual Question: In case of an accident, the...

# %%
qr_range = (0,60)
df["AI"] = np.nan
ai_answer = []
for i in tqdm(range(*qr_range)):
    ai_answer.append(gen_query(df.loc[i,"Prompt"], top_k=15, client=client, mode='hybrid', model="llama3.3"))

df.loc[qr_range[0]:qr_range[1]-1, "AI"] = [answ[0] for answ in ai_answer]
df.loc[qr_range[0]:qr_range[1]-1, "Context"] = [answ[2] for answ in ai_answer]
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# using Hybrid
#   2%|▏         | 1/60 [00:20<19:44, 20.08s/it]
# using Hybrid
#   3%|▎         | 2/60 [01:20<42:08, 43.59s/it]
# using Hybrid
#   5%|▌         | 3/60 [01:41<31:39, 33.32s/it]
# using Hybrid
#   7%|▋         | 4/60 [02:17<32:00, 34.30s/it]
# using Hybrid
#   8%|▊         | 5/60 [02:56<33:06, 36.12s/it]
# using Hybrid
#  10%|█         | 6/60 [03:32<32:25, 36.03s/it]
# using Hybrid
#  12%|█▏        | 7/60 [04:08<31:57, 36.19s/it]
# using Hybrid
#  13%|█▎        | 8/60 [04:48<32:21, 37.35s/it]
# using Hybrid
#  15%|█▌        | 9/60 [05:26<31:52, 37.49s/it]
# using Hybrid
#  17%|█▋        | 10/60 [06:01<30:41, 36.84s/it]
# using Hybrid
#  18%|█▊        | 11/60 [06:40<30:26, 37.29s/it]
# using Hybrid
#  20%|██        | 12/60 [07:14<29:12, 36.51s/it]
# using Hybrid
#  22%|██▏       | 13/60 [07:55<29:41, 37.90s/it]
# using Hybrid
#  23%|██▎       | 14/60 [08:34<29:07, 37.99s/it]
# using Hybrid
#  25%|██▌       | 15/60 [09:07<27:28, 36.63s/it]
# using Hybrid
#  27%|██▋       | 16/60 [09:48<27:51, 37.98s/it]
# using Hybrid
#  28%|██▊       | 17/60 [10:25<26:55, 37.57s/it]
# using Hybrid
#  30%|███       | 18/60 [11:03<26:21, 37.66s/it]
# using Hybrid
#  32%|███▏      | 19/60 [11:40<25:42, 37.63s/it]
# using Hybrid
#  33%|███▎      | 20/60 [12:19<25:13, 37.83s/it]
# using Hybrid
#  35%|███▌      | 21/60 [12:56<24:25, 37.59s/it]
# using Hybrid
#  37%|███▋      | 22/60 [13:35<24:07, 38.10s/it]
# using Hybrid
#  38%|███▊      | 23/60 [14:11<23:05, 37.44s/it]
# using Hybrid
#  40%|████      | 24/60 [14:51<22:53, 38.17s/it]
# using Hybrid
#  42%|████▏     | 25/60 [15:27<21:53, 37.53s/it]
# using Hybrid
#  43%|████▎     | 26/60 [16:02<20:50, 36.77s/it]
# using Hybrid
#  45%|████▌     | 27/60 [16:43<20:57, 38.09s/it]
# using Hybrid
#  47%|████▋     | 28/60 [17:22<20:27, 38.37s/it]
# using Hybrid
#  48%|████▊     | 29/60 [18:00<19:44, 38.22s/it]
# using Hybrid
#  50%|█████     | 30/60 [18:38<19:09, 38.33s/it]
# using Hybrid
#  52%|█████▏    | 31/60 [19:12<17:50, 36.91s/it]
# using Hybrid
#  53%|█████▎    | 32/60 [19:49<17:19, 37.11s/it]
# using Hybrid
#  55%|█████▌    | 33/60 [20:29<17:03, 37.91s/it]
# using Hybrid
#  57%|█████▋    | 34/60 [21:08<16:31, 38.14s/it]
# using Hybrid
#  58%|█████▊    | 35/60 [21:46<15:53, 38.16s/it]
# using Hybrid
#  60%|██████    | 36/60 [22:22<14:57, 37.41s/it]
# using Hybrid
#  62%|██████▏   | 37/60 [22:56<13:58, 36.48s/it]
# using Hybrid
#  63%|██████▎   | 38/60 [23:35<13:37, 37.15s/it]
# using Hybrid
#  65%|██████▌   | 39/60 [24:14<13:13, 37.79s/it]
# using Hybrid
#  67%|██████▋   | 40/60 [24:52<12:38, 37.93s/it]
# using Hybrid
#  68%|██████▊   | 41/60 [25:31<12:01, 38.00s/it]
# using Hybrid
#  70%|███████   | 42/60 [26:08<11:23, 37.99s/it]
# using Hybrid
#  72%|███████▏  | 43/60 [26:44<10:32, 37.21s/it]
# using Hybrid
#  73%|███████▎  | 44/60 [27:22<09:59, 37.47s/it]
# using Hybrid
#  75%|███████▌  | 45/60 [27:56<09:07, 36.47s/it]
# using Hybrid
#  77%|███████▋  | 46/60 [28:38<08:53, 38.11s/it]
# using Hybrid
#  78%|███████▊  | 47/60 [29:12<07:57, 36.76s/it]
# using Hybrid
#  80%|████████  | 48/60 [29:49<07:23, 36.99s/it]
# using Hybrid
#  82%|████████▏ | 49/60 [30:26<06:45, 36.89s/it]
# using Hybrid
#  83%|████████▎ | 50/60 [31:03<06:09, 36.99s/it]
# using Hybrid
#  85%|████████▌ | 51/60 [31:42<05:39, 37.73s/it]
# using Hybrid
#  87%|████████▋ | 52/60 [32:17<04:54, 36.83s/it]
# using Hybrid
#  88%|████████▊ | 53/60 [32:56<04:22, 37.54s/it]
# using Hybrid
#  90%|█████████ | 54/60 [33:32<03:41, 36.90s/it]
# using Hybrid
#  92%|█████████▏| 55/60 [34:11<03:08, 37.69s/it]
# using Hybrid
#  93%|█████████▎| 56/60 [34:49<02:30, 37.74s/it]
# using Hybrid
#  95%|█████████▌| 57/60 [35:27<01:53, 37.70s/it]
# using Hybrid
#  97%|█████████▋| 58/60 [36:02<01:14, 37.09s/it]
# using Hybrid
#  98%|█████████▊| 59/60 [36:40<00:37, 37.07s/it]
# using Hybrid
# 100%|██████████| 60/60 [37:16<00:00, 37.27s/it]
# /tmp/ipykernel_274048/3447998644.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['[CDxE]', '[C]', '[D]', '[A, C]', '[C]', '[C]', '[A]', '[A]', '[C]', '[B]', '[A]', '[A]', '[A]', '[C]', '[B]', '[C]', '[B]', '[A, C]', '[A]', '[C]', '[C]', '[A]', '[C]', '[B]', '[C]', '[C]', '[A]', '[A]', '[A]', '[C]', '[B]', '[C]', '[A]', '[C]', '[C]', '[B]', '[B]', '[B]', '[A]', '[C]', '[B]', '[A]', '[A]', '[A]', '[B]', '[B]', '[A]', '[A]', '[A]', '[C]', '[B]', '[A]', '[A]', '[C]', '[A]', '[A]', '[C]', '[A]', '[B]', '[C]']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[qr_range[0]:qr_range[1]-1, "AI"] = [answ[0] for answ in ai_answer]

# %%
import re


def process_answers(answers):
    formatted_answers = []
    
    for a in answers:
        
        matches = re.findall(r'\[?\s*([A-E](?:\s*,\s*[A-E])*)\s*\]?', str(a)) # Extract answers like [A, C, D] or [A] or [B, D]
        answers = []
        for match in matches:
            answers.extend(re.split(r'\s*,\s*', match))  # Split by comma and remove spaces
        unique_sorted_answers = sorted(set(answers), key=lambda x: ['A', 'B', 'C', 'D', 'E'].index(x))
        if not unique_sorted_answers:
            formatted_answers.append(None)
        else:
            formatted_answers.append(unique_sorted_answers)
    return formatted_answers

df_results = df.loc[qr_range[0]:qr_range[1]-1, ["Question","Answer","AI"]]
df_results['Answer'] = df_results['Answer'].apply(lambda x: x.split(', '))
df_results['AI'] = process_answers(df_results["AI"])
df_results['Answer'] = process_answers(df_results["Answer"])



def calculate_scores(df):
    scores = []
    for index, row in df.iterrows():
        correct_answers = set(row['Answer'] if row['Answer'] is not None else [])
        ai_answers = set(row['AI'] if row['AI'] is not None else [])
        if ai_answers == correct_answers:
            score = 1.0
        else:
            score = 0.0
        scores.append(score)
    
    df['Score'] = scores
    accuracy = scores.count(1.0) / len(scores)
    print(f'Final Score: {scores.count(1.0):.2f}/{len(scores):.2f}')
    print(f'Accuracy: {accuracy:.2f}%')
    return df

# Apply the scoring function
scored_df = calculate_scores(df_results)

# Display the dataframe to verify the results
display(scored_df[['Question', 'Answer', 'AI', 'Score']])
# Out:
# Final Score: 48.00/60.00
# Accuracy: 0.80%
#                                              Question        Answer  \
# 0   What should you do in case your vehicle breaks...  [A, C, D, E]
# 1    What will happen when your front tire blows out?           [C]
# 2   What should you do when an ambulance comes up ...           [D]
# 3   While driving the hood of your car lifts up bl...        [A, C]
# 4   In case of an accident, the first duty of the ...           [A]
# 5   When a vehicle starts to skid, what should the...           [B]
# 6   In case of injuries caused by an accident, the...           [A]
# 7     What will happen when your rear tire blows out?           [B]
# 8   When a vehicle is stalled or disabled, the dri...           [C]
# 9   If you are the first to arrive at the scene of...           [B]
# 10  As per RA 4136, the brakes on every vehicle (o...           [A]
# 11              What is not a good trait of a driver?           [A]
# 12  A safe speed to drive your car under adverse c...           [A]
# 13                Night driving is dangerous because:           [C]
# 14  What habit will help you prevent getting a fix...           [B]
# 15           Seatbelts must be worn by children aged:           [B]
# 16  Which of the following is the maximum speed li...           [C]
# 17  Graft and corruption in the traffic enforcemen...           [C]
# 18  Eating, drinking, reading, or doing anything t...           [A]
# 19  Before a private motor vehicle owner can apply...           [C]
# 20  According to the Philippine Clean Air Act of 1...           [C]
# 21  To avoid suspension or revocation, how many da...           [A]
# 22  To have one's driver's license suspended means...           [C]
# 23  To aobtain one's driver's license, one must be...           [B]
# 24         A pre-trip inspection should be completed:           [C]
# 25  It is not conidered safe driving on an express...           [C]
# 26  When you do not see the wheels of the vehicles...           [A]
# 27  Your speed while driving at night should keep on:           [A]
# 28                  When driving at night, you should           [C]
# 29  How close should another car be before you dim...           [A]
# 30  If you are backing up in a straight line, turn...           [A]
# 31  The blind spot is the area to your right or le...           [C]
# 32  At an intrsection with traffic signals, if you...           [A]
# 33  When approaching a flooded area and you have t...           [C]
# 34  While driving with maximum speed and you have ...           [C]
# 35                           On a wet road, you must:           [B]
# 36  When planning to overtake a slower vehicle in ...           [B]
# 37  You are preparing to exit an expressway, when ...           [B]
# 38  While driving with a maximum speed and you hav...           [A]
# 39  When driving on mountain roads during daytime,...           [C]
# 40  What light shall be used when vehicles are par...           [B]
# 41  When loading or unloading passengers, we usual...           [A]
# 42  If you are parking uphill without a curb, turn...           [A]
# 43  A driver ____ park or stop at the side fo the ...           [A]
# 44                    Whenever you park, remember to:           [B]
# 45  Never park or stop at the side of the road wit...           [C]
# 46                          The vehicle is parked if:           [A]
# 47  When parking downhill, you should turn your fr...           [A]
# 48  When you are parked at the side of the road at...           [A]
# 49  A driver must not park or stop at the side of ...           [C]
# 50                        Parking lights may be used:           [B]
# 51                                You may never park:           [A]
# 52  Parking is considered as a violation when a mo...           [A]
# 53         What is considered as a parking violation?           [C]
# 54             When are you permitted to double park?           [A]
# 55  On a two-lane road, overtaking is only allowed...           [A]
# 56  Which of the following hand signals must a dri...           [C]
# 57  When oncoming vehicle (car A) deliberately cro...           [A]
# 58  When two vehicles meet on a gradient road wher...           [A]
# 59  When driving on the highway at night, you shou...           [C]
#
#            AI  Score
# 0   [C, D, E]    0.0
# 1         [C]    1.0
# 2         [D]    1.0
# 3      [A, C]    1.0
# 4         [C]    0.0
# 5         [C]    0.0
# 6         [A]    1.0
# 7         [A]    0.0
# 8         [C]    1.0
# 9         [B]    1.0
# 10        [A]    1.0
# 11        [A]    1.0
# 12        [A]    1.0
# 13        [C]    1.0
# 14        [B]    1.0
# 15        [C]    0.0
# 16        [B]    0.0
# 17     [A, C]    0.0
# 18        [A]    1.0
# 19        [C]    1.0
# 20        [C]    1.0
# 21        [A]    1.0
# 22        [C]    1.0
# 23        [B]    1.0
# 24        [C]    1.0
# 25        [C]    1.0
# 26        [A]    1.0
# 27        [A]    1.0
# 28        [A]    0.0
# 29        [C]    0.0
# 30        [B]    0.0
# 31        [C]    1.0
# 32        [A]    1.0
# 33        [C]    1.0
# 34        [C]    1.0
# 35        [B]    1.0
# 36        [B]    1.0
# 37        [B]    1.0
# 38        [A]    1.0
# 39        [C]    1.0
# 40        [B]    1.0
# 41        [A]    1.0
# 42        [A]    1.0
# 43        [A]    1.0
# 44        [B]    1.0
# 45        [B]    0.0
# 46        [A]    1.0
# 47        [A]    1.0
# 48        [A]    1.0
# 49        [C]    1.0
# 50        [B]    1.0
# 51        [A]    1.0
# 52        [A]    1.0
# 53        [C]    1.0
# 54        [A]    1.0
# 55        [A]    1.0
# 56        [C]    1.0
# 57        [A]    1.0
# 58        [B]    0.0
# 59        [C]    1.0

# %%
# Generate prompts dynamically
def generate_prompt(row):
    
    # Construct the prompt with few-shot examples
    prompt = f"\nActual Question: {row['Question']}\n" 
    prompt += "\nPlease answer the question based on the given context."
    
    return prompt

# %%
# Load the Excel file
file_path = '/mnt/c/Users/Jeryl Salas/Documents/AI 351/Project/LTO_EXAM_QnA.csv'
df = pd.read_csv(file_path, encoding='ISO-8859-1')
df['Prompt'] = df.apply(generate_prompt, axis=1)
display(df.head())
# Out:
#                                             Question  \
# 0                Traffic Jam can be prevented if you
# 1                When making a right turn you should
# 2  When you intend to turn right or left, signal ...
# 3  At an intersection with a traffic light, make ...
# 4  Graft and corruption in the traffic enforcemen...
#
#                                               Answer  \
# 0                           Keep opposing lanes open
# 1  Stay on the outermost lane of the road then si...
# 2      25 meters before you intend to make your turn
# 3  The green light is on and there is a left turn...
# 4  Self disciplined by drivers and obeying traffi...
#
#                                               Prompt
# 0  \nActual Question: Traffic Jam can be prevente...
# 1  \nActual Question: When making a right turn yo...
# 2  \nActual Question: When you intend to turn rig...
# 3  \nActual Question: At an intersection with a t...
# 4  \nActual Question: Graft and corruption in the...

# %%
qr_range = (0,60)
df["AI"] = np.nan
ai_answer = []
for i in tqdm(range(*qr_range)):
    ai_answer.append(gen_query(df.loc[i,"Prompt"], top_k=15, client=client, mode='hybrid', model="llama3.3"))

df.loc[qr_range[0]:qr_range[1]-1, "AI"] = [answ[0] for answ in ai_answer]
df.loc[qr_range[0]:qr_range[1]-1, "Context"] = [answ[2] for answ in ai_answer]
df_new = df.loc[qr_range[0]:qr_range[1]-1].copy()
df = df_new.copy()
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# using Hybrid
#   2%|▏         | 1/60 [00:42<41:44, 42.45s/it]
# using Hybrid
#   3%|▎         | 2/60 [01:46<53:31, 55.36s/it]
# using Hybrid
#   5%|▌         | 3/60 [02:30<47:42, 50.21s/it]
# using Hybrid
#   7%|▋         | 4/60 [03:11<43:13, 46.31s/it]
# using Hybrid
#   8%|▊         | 5/60 [04:00<43:15, 47.19s/it]
# using Hybrid
#  10%|█         | 6/60 [04:43<41:22, 45.97s/it]
# using Hybrid
#  12%|█▏        | 7/60 [05:26<39:44, 44.99s/it]
# using Hybrid
#  13%|█▎        | 8/60 [06:18<40:56, 47.24s/it]
# using Hybrid
#  15%|█▌        | 9/60 [06:59<38:21, 45.14s/it]
# using Hybrid
#  17%|█▋        | 10/60 [07:38<36:10, 43.41s/it]
# using Hybrid
#  18%|█▊        | 11/60 [08:46<41:26, 50.75s/it]
# using Hybrid
#  20%|██        | 12/60 [09:29<38:52, 48.60s/it]
# using Hybrid
#  22%|██▏       | 13/60 [10:16<37:43, 48.16s/it]
# using Hybrid
#  23%|██▎       | 14/60 [11:06<37:16, 48.61s/it]
# using Hybrid
#  25%|██▌       | 15/60 [11:52<35:50, 47.80s/it]
# using Hybrid
#  27%|██▋       | 16/60 [12:38<34:44, 47.38s/it]
# using Hybrid
#  28%|██▊       | 17/60 [13:18<32:19, 45.11s/it]
# using Hybrid
#  30%|███       | 18/60 [14:20<35:09, 50.23s/it]
# using Hybrid
#  32%|███▏      | 19/60 [15:08<33:43, 49.35s/it]
# using Hybrid
#  33%|███▎      | 20/60 [15:50<31:30, 47.26s/it]
# using Hybrid
#  35%|███▌      | 21/60 [16:33<29:56, 46.06s/it]
# using Hybrid
#  37%|███▋      | 22/60 [17:24<30:01, 47.41s/it]
# using Hybrid
#  38%|███▊      | 23/60 [18:39<34:26, 55.85s/it]
# using Hybrid
#  40%|████      | 24/60 [19:26<31:45, 52.93s/it]
# using Hybrid
#  42%|████▏     | 25/60 [20:18<30:45, 52.74s/it]
# using Hybrid
#  43%|████▎     | 26/60 [21:02<28:30, 50.31s/it]
# using Hybrid
#  45%|████▌     | 27/60 [21:52<27:28, 49.94s/it]
# using Hybrid
#  47%|████▋     | 28/60 [22:39<26:14, 49.19s/it]
# using Hybrid
#  48%|████▊     | 29/60 [23:28<25:25, 49.22s/it]
# using Hybrid
#  50%|█████     | 30/60 [24:18<24:45, 49.50s/it]
# using Hybrid
#  52%|█████▏    | 31/60 [25:05<23:31, 48.67s/it]
# using Hybrid
#  53%|█████▎    | 32/60 [25:45<21:26, 45.95s/it]
# using Hybrid
#  55%|█████▌    | 33/60 [26:43<22:23, 49.77s/it]
# using Hybrid
#  57%|█████▋    | 34/60 [27:23<20:10, 46.55s/it]
# using Hybrid
#  58%|█████▊    | 35/60 [28:10<19:30, 46.82s/it]
# using Hybrid
#  60%|██████    | 36/60 [29:10<20:20, 50.87s/it]
# using Hybrid
#  62%|██████▏   | 37/60 [29:54<18:38, 48.65s/it]
# using Hybrid
#  63%|██████▎   | 38/60 [30:55<19:16, 52.55s/it]
# using Hybrid
#  65%|██████▌   | 39/60 [31:38<17:24, 49.72s/it]
# using Hybrid
#  67%|██████▋   | 40/60 [32:16<15:21, 46.09s/it]
# using Hybrid
#  68%|██████▊   | 41/60 [33:03<14:40, 46.33s/it]
# using Hybrid
#  70%|███████   | 42/60 [33:49<13:52, 46.28s/it]
# using Hybrid
#  72%|███████▏  | 43/60 [34:40<13:30, 47.67s/it]
# using Hybrid
#  73%|███████▎  | 44/60 [35:34<13:12, 49.54s/it]
# using Hybrid
#  75%|███████▌  | 45/60 [36:21<12:10, 48.72s/it]
# using Hybrid
#  77%|███████▋  | 46/60 [37:05<11:03, 47.37s/it]
# using Hybrid
#  78%|███████▊  | 47/60 [38:06<11:09, 51.53s/it]
# using Hybrid
#  80%|████████  | 48/60 [38:45<09:32, 47.68s/it]
# using Hybrid
#  82%|████████▏ | 49/60 [39:25<08:20, 45.52s/it]
# using Hybrid
#  83%|████████▎ | 50/60 [40:15<07:47, 46.74s/it]
# using Hybrid
#  85%|████████▌ | 51/60 [41:02<07:01, 46.87s/it]
# using Hybrid
#  87%|████████▋ | 52/60 [41:48<06:13, 46.68s/it]
# using Hybrid
#  88%|████████▊ | 53/60 [42:50<05:58, 51.22s/it]
# using Hybrid
#  90%|█████████ | 54/60 [43:35<04:56, 49.35s/it]
# using Hybrid
#  92%|█████████▏| 55/60 [44:18<03:56, 47.34s/it]
# using Hybrid
#  93%|█████████▎| 56/60 [44:58<03:00, 45.11s/it]
# using Hybrid
#  95%|█████████▌| 57/60 [45:39<02:11, 43.79s/it]
# using Hybrid
#  97%|█████████▋| 58/60 [46:22<01:27, 43.74s/it]
# using Hybrid
#  98%|█████████▊| 59/60 [47:04<00:43, 43.17s/it]
# using Hybrid
# 100%|██████████| 60/60 [47:44<00:00, 47.73s/it]
# /tmp/ipykernel_274048/3974852099.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '["follow traffic rules and regulations, such as not overtaking in areas where it's prohibited, yielding to other vehicles or pedestrians when necessary, and avoiding actions that can cause obstruction or congestion on the road.", "Based on the provided context, the specific steps for making a right turn are not detailed. However, general guidelines for turns and safety precautions while driving are mentioned. To make a right turn safely, follow these general principles that can be inferred from safe driving practices:\n\n1. **Signal Your Intent**: Before making any turn, it's crucial to signal your intention to other road users. This helps in avoiding confusion and potential collisions.\n\n2. **Check Your Mirrors and Blind Spots**: Always check your rearview mirror and blind spots to be aware of the traffic behind you.\n\n3. **Slow Down**: Reduce your speed as you approach the turn. This will give you better control over your vehicle and allow you to react to any unexpected situations.\n\n4. **Follow Traffic Signs and Signals**: Adhere to all traffic signs and signals. If there's a stop sign or a red light, come to a complete halt before proceeding with your turn when it's safe and legal to do so.\n\n5. **Yield to Others**: Be prepared to yield to pedestrians, cyclists, or other vehicles that may have the right of way.\n\n6. **Execute the Turn**: Once you've checked for safety and yielded as necessary, smoothly turn your vehicle to the right. Avoid sudden movements that could lose traction or surprise other road users.\n\n7. **Cancel Your Signal**: After completing the turn, cancel your turn signal to indicate to others that the maneuver is complete.\n\nRemember, safe driving involves being attentive to your surroundings, following traffic laws, and respecting the space of other road users. Always drive defensively and anticipate the actions of others to minimize risks on the road.", 'Based on the provided text, it is not explicitly stated how far in advance one should signal their intention to turn right or left. However, according to standard driving practices and guidelines, it is generally recommended to signal your intention to turn at least 100 feet before turning, or about 3-5 seconds before making the turn. This allows other drivers to be aware of your intentions and react accordingly.', 'At an intersection with a traffic light, make a left turn only when the traffic light is green and it is safe to do so, or if allowed by a specific left-turn arrow or signal. Additionally, always yield to pedestrians, bicyclists, and other vehicles that may have the right of way.', "Based on the provided context, graft and corruption in the traffic enforcement system can be eliminated by implementing technologies such as body-worn cameras, electronic temporary operator's permits (e-TOP), and electronic impounding receipts of motor vehicles (e-IRMV). These digital solutions can help reduce human intervention and increase transparency, making it more difficult for corrupt practices to occur. Additionally, providing refresher hands-on training on using the Law Enforcement Management Information System (LEMHD) and ensuring that traffic enforcement officers are aware of and adhere to guidelines and protocols can also contribute to minimizing corruption.", 'On a four-lane road with a single white line, you can overtake or pass another vehicle from either side, as long as it is safe to do so. The single white line is used to separate traffic flowing in opposite directions and does not prohibit overtaking. However, always ensure that the maneuver is done safely and according to local traffic regulations.', 'No, according to the text, a double solid yellow line means no passing or overtaking is allowed from either side. However, it does not mention a double solid yellow line wit ...
#   df.loc[qr_range[0]:qr_range[1]-1, "AI"] = [answ[0] for answ in ai_answer]

# %% [markdown]
# # 10. Similarity Evaluation

# %%
from llama_index.core.evaluation import SemanticSimilarityEvaluator
from llama_index.core.base.embeddings.base import BaseEmbedding
import asyncio
from llama_index.core.embeddings import resolve_embed_model
from pydantic import PrivateAttr

class OllamaEmbeddingModel(BaseEmbedding):
    _client: Client = PrivateAttr()

    def __init__(self, model_name: str = "mxbai-embed-large", timeout: int = 300):
        super().__init__()
        self.model_name = model_name
        self._client = Client() 

    async def _aget_query_embedding(self, query: str) -> list[float]:
        return await self._aget_text_embedding(query)

    async def _aget_text_embedding(self, text: str) -> list[float]:
        loop = asyncio.get_event_loop()
        embedding_response = await loop.run_in_executor(
            None, self._client.embeddings, self.model_name, text
        )
        return embedding_response['embedding']  

    def _get_query_embedding(self, query: str) -> list[float]:
        return self._get_text_embedding(query)

    def _get_text_embedding(self, text: str) -> list[float]:
        embedding_response = self._client.embeddings(
            model=self.model_name,
            prompt=text
        )
        return embedding_response['embedding']


embed_model = OllamaEmbeddingModel(model_name="mxbai-embed-large")
evaluator = SemanticSimilarityEvaluator(
    embed_model=embed_model,
    similarity_threshold=0.6
)

results_scores = []
results_passing = []
for i in tqdm(range(len(df))):
    response = df.loc[i, "AI"]
    reference = df.loc[i, "Answer"]

    result = await evaluator.aevaluate(
    response=response,
    reference=reference,
    )
    results_scores.append(result.score)
    results_passing.append(result.passing)
    
df['Score'] = results_scores
df['Passing'] = results_passing

average_score = df['Score'].mean()
total_items = len(df)
passing_items = df['Passing'].sum()  
print(f"Average Score: {average_score:.4f}")
print(f"Passing: {passing_items}/{total_items}")
display(df[['Question', 'Answer', 'AI', 'Score', 'Passing']])
# Out:
# 100%|██████████| 60/60 [00:42<00:00,  1.41it/s]
# Average Score: 0.6461
# Passing: 44/60
#                                              Question  \
# 0                 Traffic Jam can be prevented if you
# 1                 When making a right turn you should
# 2   When you intend to turn right or left, signal ...
# 3   At an intersection with a traffic light, make ...
# 4   Graft and corruption in the traffic enforcemen...
# 5   On a four(4) lane road with single white line,...
# 6   A double solid yellow line with broken white l...
# 7                    When making a U-Turn, you should
# 8   Signs that are triangular in shape and with a ...
# 9   Signs that are round, inverted triangle or oct...
# 10  Signs that are round, rectangular with white a...
# 11   Single with broken line on a two-lane road means
# 12  What to do when you approach a crosswalk or pe...
# 13  Driving an unregistered motor vehicle is a vio...
# 14                    Considered a parking violation?
# 15               Green light at an intersection means
# 16          Steady red light at an intersection means
# 17  The penalty of driving a motor vehicle while u...
# 18  When a driver of PUV refuses to render service...
# 19  If the driver is using a motor vehicle in comm...
# 20  The minimum distance away from the vehicle are...
# 21             When do you have a complete/full stop?
# 22  On a two-lane road, overtaking is only allowed...
# 23  Parking is considered as a violation when a mo...
# 24                              Parking is prohibited
# 25  When the traffic light is steady green and ste...
# 26  What is the maximum penalty for driving under ...
# 27                            On a wet road, you must
# 28  While driving with a maximum speed and you hav...
# 29  When another vehicle is following you too clos...
# 30  The driver of the vehicle behind you should al...
# 31  When parking uphill without a curb, turn your ...
# 32                    When parking downhill, you must
# 33                      When parking uphill, you must
# 34  When you make an abrupt move especially when y...
# 35  Whenever you are driving, especially when over...
# 36  When driving on a highway, do not stare at the...
# 37  When driving on a mountain roads during daytim...
# 38    When driving downhill on a mountain road always
# 39   The headlights should be used often as needed to
# 40  At an intersection, if two (2) vehicles arrive...
# 41  When negotiating a curve on a highway at a rel...
# 42  When planning to overtake a slower vehicle in ...
# 43  Driving in heavy rains can be extremely danger...
# 44                         A flashing red light means
# 45   Your speed while driving at night should keep on
# 46                  One that affects your visibility?
# 47                  When driving at night, you should
# 48  Being passed is normal part of driving and sho...
# 49  When oncoming vehicle deliberately crosses the...
# 50  When approaching a flooded area and you have t...
# 51          A single solid yellow or white line means
# 52                      Passing/overtaking is allowed
# 53  A driver on a highway shall yield the right of...
# 54  A driver on a highway shall yield the right of...
# 55  This traffic signs warns you that school child...
# 56                 The signal warns of a hazard ahead
# 57   This traffic sign states direction and distances
# 58                    The mark for a railway crossing
# 59  Children must be held in approved child restra...
#
#                                                Answer  \
# 0                            Keep opposing lanes open
# 1   Stay on the outermost lane of the road then si...
# 2       25 meters before you intend to make your turn
# 3   The green light is on and there is a left turn...
# 4   Self disciplined by drivers and obeying traffi...
# 5       Overtake by passing over the solid white line
# 6                            Absolutely no overtaking
# 7   Check for traffic behind you and indicate your...
# 8                            Caution or warning signs
# 9                                    Regulatory signs
# 10                                  Informative signs
# 11  It separates traffic moving in opposite direct...
# 12                       Stop and yield to pedestrian
# 13                                    Fine of P10,000
# 14  Parking within five(5) meters from a signalize...
# 15  Pedestrian are not allowed to cross the pedest...
# 16                        Stop at the designated line
# 17  Driver's license shall be confiscated and susp...
# 18                                     Fine of P1,000
# 19                        Revoked and will pay a fine
# 20                                       1 car length
# 21                             At a red traffic light
# 22                                          Left lane
# 23  Park at the entrance and exit of hospital and ...
# 24                             Within an intersection
# 25  Vehicles can go straight or vehicles on the ri...
# 26                              Revocation of license
# 27                                          Slow down
# 28       Apply your brake gently with steady pressure
# 29  Slow down gradually and give him the signal to...
# 30                                   Rear end crashes
# 31                       Towards the edge of the road
# 32                           Turn your wheels to curb
# 33               Turn your wheels aways from the curb
# 34                                   Improper braking
# 35   Never overtake another vehicle from a tailgat...
# 36  Extend your scanning distance to about 12 seco...
# 37      Blow your horn when approaching a blind curve
# 38  Shift to lower gear so the engine braking acti...
# 39   Make your intentions known to drivers around you
# 40                               Vehicle on the right
# 41  Decrease your speed further as you enter the c...
# 42  Flick your dimmer, switch two or three times t...
# 43  When you cannot see more than 20 meters in fro...
# 44  You must stop and then go only when it is safe...
# 45  The distance that you can see where you come t...
# 46                      Defective or dirty headlights
# 47                     Always turn your headlights on
# 48                 Slow down and make it easy to stop
# 49  Alert and be ready to slow down or stop if nec...
# 50                       Proceed at a very slow speed
# 51                  Passing/overtaking is not allowed
# 52                  On highway with two or more lanes
# 53  Police / fire department vehicles and ambulanc...
# 54            Pedestrians crossing within a crosswalk
# 55                                           Pentagon
# 56                                      Diamond shape
# 57                               Horizontal rectangle
# 58                                         Cross-buck
# 59                              6 years old and below
#
#                                                    AI     Score  Passing
# 0   follow traffic rules and regulations, such as ...  0.696892     True
# 1   Based on the provided context, the specific st...  0.742046     True
# 2   Based on the provided text, it is not explicit...  0.765621     True
# 3   At an intersection with a traffic light, make ...  0.769149     True
# 4   Based on the provided context, graft and corru...  0.646904     True
# 5   On a four-lane road with a single white line, ...  0.821234     True
# 6   No, according to the text, a double solid yell...  0.584989    False
# 7   Unfortunately, there is no information provide...  0.620563     True
# 8   Based on the context, the signs that are trian...  0.656201     True
# 9                                    Regulatory Signs  1.000000     True
# 10  Based on the provided context, the signs that ...  0.702078     True
# 11  No overtaking or passing is allowed on the sid...  0.666535     True
# 12  When approaching a crosswalk or pedestrian lan...  0.757015     True
# 13  According to the text, driving an unregistered...  0.615429     True
# 14  Based on the provided text, the following are ...  0.734964     True
# 15  Based on the provided context, which discusses...  0.496426    False
# 16  A steady red light at an intersection means th...  0.694736     True
# 17  According to the provided text, specifically S...  0.644711     True
# 18  Based on the provided context, when a driver o...  0.614214     True
# 19  Confiscated and revoked, and the driver shall ...  0.688210     True
# 20  The minimum distance is not explicitly stated ...  0.593017    False
# 21  According to the text, you are required to mak...  0.679151     True
# 22  On a two-lane road, overtaking is not allowed ...  0.680524     True
# 23  Based on the given context, parking is conside...  0.566320    False
# 24  According to the provided context, parking is ...  0.607400     True
# 25  When the traffic light is steady green and a s...  0.734357     True
# 26  Based on the given context, the maximum penalt...  0.673796     True
# 27  Based on the provided context, it appears that...  0.605521     True
# 28  Based on the given context, it appears that th...  0.567605    False
# 29  When another vehicle is following you too clos...  0.735085     True
# 30  The driver of the vehicle behind you should al...  0.541629    False
# 31  towards the right (or away from the road) to p...  0.724157     True
# 32  Never park downhill. According to the text, wh...  0.617965     True
# 33  When parking uphill, you must turn your wheels...  0.754033     True
# 34  When you make an abrupt move, especially when ...  0.715444     True
# 35  When driving, especially when overtaking, it's...  0.664597     True
# 36  According to the provided text, when driving o...  0.593864    False
# 37  Based on the provided context, it seems that t...  0.556461    False
# 38  When driving downhill on a mountain road, you ...  0.778665     True
# 39        dim when approaching another motor vehicle.  0.602453     True
# 40  According to the text, "Failure to yield the r...  0.622413     True
# 41  When negotiating a curve on a highway at a rel...  0.743477     True
# 42  When planning to overtake a slower vehicle in ...  0.694787     True
# 43  According to the context, when driving in heav...  0.601163     True
# 44  Based on the provided text, it appears that a ...  0.573821    False
# 45  a safe distance from other vehicles to avoid c...  0.659464     True
# 46  Based on the provided text, which appears to b...  0.511077    False
# 47  dim your headlights when approaching another m...  0.748685     True
# 48  remain calm and give way to the passing vehicl...  0.637612     True
# 49  When an oncoming vehicle deliberately crosses ...  0.636136     True
# 50  When approaching a flooded area and you have t...  0.635265     True
# 51  A single solid yellow line means no passing or...  0.648337     True
# 52  Based on the provided context, passing or over...  0.602309     True
# 53  A driver on a highway shall yield the right of...  0.570259    False
# 54  A driver on a highway shall yield the right of...  0.733578     True
# 55  The traffic sign that warns you that school ch...  0.345266    False
# 56  The signal warns of a hazard ahead, such as a ...  0.398943    False
# 57  The traffic sign you are referring to is likel...  0.484330    False
# 58  The mark for a railway crossing is a sign that...  0.454257    False
# 59  less than 150 cm or 59 inches in height and no...  0.556167    False

# %% [markdown]
# # 11. Relevancy Evaluation

# %%
from llama_index.core.evaluation import RelevancyEvaluator

ollama_llm = Ollama(model="llama3.2", request_timeout=300)
evaluator = RelevancyEvaluator(llm=ollama_llm)

eval_results = []

for i in tqdm(range(len(df))):
    eval_result = await evaluator.aevaluate(
        query=df.loc[i, "Question"],
        response=df.loc[i, "AI"],
        contexts=[df.loc[i, "Context"]]  
    )
    eval_results.append(eval_result.passing)

df['Eval'] = eval_results

total_items = len(df)
passing_items = df['Eval'].sum()
score = f"Score: {passing_items}/{total_items}"
percentage = passing_items / total_items if total_items > 0 else 0
print(score)
print(f"Percentage: {percentage:.2%}")
display(df[['Question', 'Answer', 'AI', 'Eval']])
# Out:
# 100%|██████████| 60/60 [26:32<00:00, 26.55s/it]
# Score: 48/60
# Percentage: 80.00%
#                                              Question  \
# 0                 Traffic Jam can be prevented if you
# 1                 When making a right turn you should
# 2   When you intend to turn right or left, signal ...
# 3   At an intersection with a traffic light, make ...
# 4   Graft and corruption in the traffic enforcemen...
# 5   On a four(4) lane road with single white line,...
# 6   A double solid yellow line with broken white l...
# 7                    When making a U-Turn, you should
# 8   Signs that are triangular in shape and with a ...
# 9   Signs that are round, inverted triangle or oct...
# 10  Signs that are round, rectangular with white a...
# 11   Single with broken line on a two-lane road means
# 12  What to do when you approach a crosswalk or pe...
# 13  Driving an unregistered motor vehicle is a vio...
# 14                    Considered a parking violation?
# 15               Green light at an intersection means
# 16          Steady red light at an intersection means
# 17  The penalty of driving a motor vehicle while u...
# 18  When a driver of PUV refuses to render service...
# 19  If the driver is using a motor vehicle in comm...
# 20  The minimum distance away from the vehicle are...
# 21             When do you have a complete/full stop?
# 22  On a two-lane road, overtaking is only allowed...
# 23  Parking is considered as a violation when a mo...
# 24                              Parking is prohibited
# 25  When the traffic light is steady green and ste...
# 26  What is the maximum penalty for driving under ...
# 27                            On a wet road, you must
# 28  While driving with a maximum speed and you hav...
# 29  When another vehicle is following you too clos...
# 30  The driver of the vehicle behind you should al...
# 31  When parking uphill without a curb, turn your ...
# 32                    When parking downhill, you must
# 33                      When parking uphill, you must
# 34  When you make an abrupt move especially when y...
# 35  Whenever you are driving, especially when over...
# 36  When driving on a highway, do not stare at the...
# 37  When driving on a mountain roads during daytim...
# 38    When driving downhill on a mountain road always
# 39   The headlights should be used often as needed to
# 40  At an intersection, if two (2) vehicles arrive...
# 41  When negotiating a curve on a highway at a rel...
# 42  When planning to overtake a slower vehicle in ...
# 43  Driving in heavy rains can be extremely danger...
# 44                         A flashing red light means
# 45   Your speed while driving at night should keep on
# 46                  One that affects your visibility?
# 47                  When driving at night, you should
# 48  Being passed is normal part of driving and sho...
# 49  When oncoming vehicle deliberately crosses the...
# 50  When approaching a flooded area and you have t...
# 51          A single solid yellow or white line means
# 52                      Passing/overtaking is allowed
# 53  A driver on a highway shall yield the right of...
# 54  A driver on a highway shall yield the right of...
# 55  This traffic signs warns you that school child...
# 56                 The signal warns of a hazard ahead
# 57   This traffic sign states direction and distances
# 58                    The mark for a railway crossing
# 59  Children must be held in approved child restra...
#
#                                                Answer  \
# 0                            Keep opposing lanes open
# 1   Stay on the outermost lane of the road then si...
# 2       25 meters before you intend to make your turn
# 3   The green light is on and there is a left turn...
# 4   Self disciplined by drivers and obeying traffi...
# 5       Overtake by passing over the solid white line
# 6                            Absolutely no overtaking
# 7   Check for traffic behind you and indicate your...
# 8                            Caution or warning signs
# 9                                    Regulatory signs
# 10                                  Informative signs
# 11  It separates traffic moving in opposite direct...
# 12                       Stop and yield to pedestrian
# 13                                    Fine of P10,000
# 14  Parking within five(5) meters from a signalize...
# 15  Pedestrian are not allowed to cross the pedest...
# 16                        Stop at the designated line
# 17  Driver's license shall be confiscated and susp...
# 18                                     Fine of P1,000
# 19                        Revoked and will pay a fine
# 20                                       1 car length
# 21                             At a red traffic light
# 22                                          Left lane
# 23  Park at the entrance and exit of hospital and ...
# 24                             Within an intersection
# 25  Vehicles can go straight or vehicles on the ri...
# 26                              Revocation of license
# 27                                          Slow down
# 28       Apply your brake gently with steady pressure
# 29  Slow down gradually and give him the signal to...
# 30                                   Rear end crashes
# 31                       Towards the edge of the road
# 32                           Turn your wheels to curb
# 33               Turn your wheels aways from the curb
# 34                                   Improper braking
# 35   Never overtake another vehicle from a tailgat...
# 36  Extend your scanning distance to about 12 seco...
# 37      Blow your horn when approaching a blind curve
# 38  Shift to lower gear so the engine braking acti...
# 39   Make your intentions known to drivers around you
# 40                               Vehicle on the right
# 41  Decrease your speed further as you enter the c...
# 42  Flick your dimmer, switch two or three times t...
# 43  When you cannot see more than 20 meters in fro...
# 44  You must stop and then go only when it is safe...
# 45  The distance that you can see where you come t...
# 46                      Defective or dirty headlights
# 47                     Always turn your headlights on
# 48                 Slow down and make it easy to stop
# 49  Alert and be ready to slow down or stop if nec...
# 50                       Proceed at a very slow speed
# 51                  Passing/overtaking is not allowed
# 52                  On highway with two or more lanes
# 53  Police / fire department vehicles and ambulanc...
# 54            Pedestrians crossing within a crosswalk
# 55                                           Pentagon
# 56                                      Diamond shape
# 57                               Horizontal rectangle
# 58                                         Cross-buck
# 59                              6 years old and below
#
#                                                    AI   Eval
# 0   follow traffic rules and regulations, such as ...   True
# 1   Based on the provided context, the specific st...   True
# 2   Based on the provided text, it is not explicit...   True
# 3   At an intersection with a traffic light, make ...   True
# 4   Based on the provided context, graft and corru...   True
# 5   On a four-lane road with a single white line, ...   True
# 6   No, according to the text, a double solid yell...   True
# 7   Unfortunately, there is no information provide...   True
# 8   Based on the context, the signs that are trian...  False
# 9                                    Regulatory Signs  False
# 10  Based on the provided context, the signs that ...  False
# 11  No overtaking or passing is allowed on the sid...   True
# 12  When approaching a crosswalk or pedestrian lan...  False
# 13  According to the text, driving an unregistered...   True
# 14  Based on the provided text, the following are ...   True
# 15  Based on the provided context, which discusses...  False
# 16  A steady red light at an intersection means th...  False
# 17  According to the provided text, specifically S...   True
# 18  Based on the provided context, when a driver o...   True
# 19  Confiscated and revoked, and the driver shall ...   True
# 20  The minimum distance is not explicitly stated ...   True
# 21  According to the text, you are required to mak...   True
# 22  On a two-lane road, overtaking is not allowed ...  False
# 23  Based on the given context, parking is conside...   True
# 24  According to the provided context, parking is ...   True
# 25  When the traffic light is steady green and a s...   True
# 26  Based on the given context, the maximum penalt...  False
# 27  Based on the provided context, it appears that...   True
# 28  Based on the given context, it appears that th...   True
# 29  When another vehicle is following you too clos...   True
# 30  The driver of the vehicle behind you should al...  False
# 31  towards the right (or away from the road) to p...   True
# 32  Never park downhill. According to the text, wh...   True
# 33  When parking uphill, you must turn your wheels...   True
# 34  When you make an abrupt move, especially when ...   True
# 35  When driving, especially when overtaking, it's...   True
# 36  According to the provided text, when driving o...   True
# 37  Based on the provided context, it seems that t...   True
# 38  When driving downhill on a mountain road, you ...  False
# 39        dim when approaching another motor vehicle.   True
# 40  According to the text, "Failure to yield the r...   True
# 41  When negotiating a curve on a highway at a rel...   True
# 42  When planning to overtake a slower vehicle in ...   True
# 43  According to the context, when driving in heav...   True
# 44  Based on the provided text, it appears that a ...   True
# 45  a safe distance from other vehicles to avoid c...   True
# 46  Based on the provided text, which appears to b...  False
# 47  dim your headlights when approaching another m...   True
# 48  remain calm and give way to the passing vehicl...   True
# 49  When an oncoming vehicle deliberately crosses ...   True
# 50  When approaching a flooded area and you have t...   True
# 51  A single solid yellow line means no passing or...   True
# 52  Based on the provided context, passing or over...   True
# 53  A driver on a highway shall yield the right of...  False
# 54  A driver on a highway shall yield the right of...   True
# 55  The traffic sign that warns you that school ch...   True
# 56  The signal warns of a hazard ahead, such as a ...   True
# 57  The traffic sign you are referring to is likel...   True
# 58  The mark for a railway crossing is a sign that...   True
# 59  less than 150 cm or 59 inches in height and no...   True
